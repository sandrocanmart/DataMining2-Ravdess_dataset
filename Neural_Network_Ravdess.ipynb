# %%
# !pip install scikit-plot
# Out:
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.10.1)
# Requirement already satisfied: joblib>=0.10 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->scikit-plot) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)
# Installing collected packages: scikit-plot
# Successfully installed scikit-plot-0.3.7

# %% [markdown]
# ##UTILITIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from collections import defaultdict
from yellowbrick.contrib.classifier import DecisionViz
from sklearn.decomposition import PCA
from itertools import product
from imblearn.datasets import make_imbalance
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from yellowbrick.datasets import load_credit
from yellowbrick.features import PCA as yPCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from scikitplot.metrics import plot_precision_recall, plot_roc, plot_cumulative_gain, plot_lift_curve
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import KFold
from sklearn import tree
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score, classification_report

from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.datasets import load_digits
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
def print_confMatrix(y_test,y_test_pred):
    cm=confusion_matrix(y_test, y_test_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap="Greens")
    plt.show()

# %%
df_train=pd.read_csv("ravdess_train.csv")
df_test=pd.read_csv("Ravdess_test.csv")

# %%
df_train
# Out:
#       Vocal_channel_  Emotion  Emotional_intensity  Statement  Repetition  \
# 0                  1        5                    0          1           0
# 1                  1        5                    0          1           1
# 2                  1        5                    0          0           0
# 3                  1        5                    0          0           1
# 4                  1        1                    0          1           0
# ...              ...      ...                  ...        ...         ...
# 1823               1        7                    0          0           1
# 1824               1        7                    1          1           0
# 1825               1        7                    1          1           1
# 1826               1        7                    1          0           0
# 1827               1        7                    1          0           1
#
#       Sex      mean       q50      q75       kur  ...  sc_q99_w4  sc_kur_w4  \
# 0       1  0.018034 -0.063106 -0.76930  0.553248  ...   1.332275  11.020083
# 1       1  0.013950 -0.063106 -0.76930  0.770118  ...   1.315989  -0.107613
# 2       1  0.018855 -0.063106 -0.76930  0.851346  ...   1.369021   7.023345
# 3       1  0.018087 -0.063106 -0.76930  1.562804  ...   1.206493  -0.211628
# 4       1  0.015921 -0.063106 -0.76930  0.286970  ...   1.361250  -0.040910
# ...   ...       ...       ...      ...       ...  ...        ...        ...
# 1823    0 -0.019175 -0.063106 -0.74864 -0.713004  ...   1.296552   0.333745
# 1824    0 -0.016770 -0.063106 -0.74864 -0.237333  ...   1.376251   0.352433
# 1825    0 -0.025751 -0.063106 -0.74864 -0.806583  ...   1.421183   1.039254
# 1826    0 -0.009914 -0.063106 -0.70732 -1.013416  ...   1.305472  -0.074024
# 1827    0 -0.023237 -0.063106 -0.70732 -1.005610  ...   1.295370  -0.228074
#
#       sc_skew_w4  stft_sum_w4  stft_q05_w4  stft_q75_w4  stft_q95_w4  \
# 0      -4.354785     0.161158     2.167997     0.690192     0.036057
# 1      -0.659640    -0.173413     1.610931     0.409754     0.036057
# 2      -3.086640    -0.286208     1.285119     0.722854     0.036057
# 3      -0.396009    -0.588962     1.176485     0.560400     0.036057
# 4      -0.624456     0.170902     1.346235     0.452031     0.036057
# ...          ...          ...          ...          ...          ...
# 1823   -1.106246    -0.612427    -1.198817     0.647428     0.036057
# 1824   -0.901054    -0.871550    -1.198817     0.734806     0.036057
# 1825   -1.106898    -0.894085    -0.618677     0.624605     0.036057
# 1826   -0.732249    -0.424644    -1.198817     0.343780     0.036057
# 1827    0.117040    -0.801925    -0.223396     0.178220     0.036057
#
#       stft_kur_w4  stft_skew_w4  actor
# 0        9.400360     -3.035005      1
# 1       -0.186504      0.434538      1
# 2        2.891302     -1.463754      1
# 3       -0.049566     -0.052845      1
# 4        0.878701     -0.532241      1
# ...           ...           ...    ...
# 1823     1.054354     -1.526104     18
# 1824    -0.389173     -0.504115     18
# 1825    -0.130100     -0.454243     18
# 1826     0.072917     -1.058564     18
# 1827    -0.524661      0.261556     18
#
# [1828 rows x 163 columns]

# %%
df_test_new=df_test.drop("Unnamed: 0", axis=1, inplace=True)
#La funzione drop() è utilizzata per rimuovere una o più colonne (o righe) da un dataframe.
#Nel caso specifico, la colonna "Unnamed: 0" viene rimossa dal dataframe df_test.
#L'opzione axis=1 indica che la colonna deve essere rimossa e non una riga, mentre l'opzione
#inplace=True indica che la modifica deve essere effettuata direttamente sul dataframe df_test,
#senza creare un nuovo dataframe. Il risultato del comando viene assegnato alla variabile df_test_new,
#ma in realtà questa variabile non è necessaria in quanto il dataframe originale df_test è stato modificato direttamente.

# %%
df_test
# Out:
#      Vocal_channel_  Emotion  Emotional_intensity  Statement  Repetition  Sex  \
# 0                 1        5                    0          1           0    1
# 1                 1        5                    0          1           1    1
# 2                 1        5                    0          0           0    1
# 3                 1        5                    0          0           1    1
# 4                 1        1                    0          1           0    1
# ..              ...      ...                  ...        ...         ...  ...
# 619               0        3                    0          0           1    0
# 620               0        3                    1          1           0    0
# 621               0        3                    1          1           1    0
# 622               0        3                    1          0           0    0
# 623               0        3                    1          0           1    0
#
#          mean       q50       q75       kur  ...  sc_q99_w4  sc_kur_w4  \
# 0    0.471300  0.040064 -0.739874  0.077772  ...   0.713432  -0.190379
# 1    0.126584  0.040064 -0.739874  0.434766  ...   0.859202  -0.618751
# 2   -0.591735  0.040064 -0.785476 -0.516932  ...   0.964382  -0.268520
# 3   -0.077100  0.040064 -0.762675  0.577221  ...   0.512538  -0.474050
# 4    0.141006  0.040064 -0.762675 -0.314121  ...   0.783936   1.144458
# ..        ...       ...       ...       ...  ...        ...        ...
# 619  0.310354  0.040064 -0.283859 -0.702275  ...  -0.782914  -0.112144
# 620 -1.001327  0.040064 -0.101452  0.589876  ...  -0.826903  -0.100709
# 621  0.445345  0.040064 -0.078652 -0.633855  ...  -1.280200  -0.269630
# 622  0.623436  0.040064 -0.124253 -0.768437  ...  -1.340317  -0.316858
# 623  0.269074  0.040064  0.035352 -0.596732  ...  -0.604388  -0.355055
#
#      sc_skew_w4  stft_sum_w4  stft_q05_w4  stft_q75_w4  stft_q95_w4  \
# 0      0.251836    -0.162595     1.952153     1.254304     0.049581
# 1      0.361906    -1.207090     0.699988     0.545470     0.049581
# 2      0.616067    -0.799392     0.874587     0.940008     0.049581
# 3      1.146812    -0.431005     1.740569     1.191764     0.049581
# 4     -1.285417     0.456053     1.462546     1.232346     0.049581
# ..          ...          ...          ...          ...          ...
# 619   -0.762158     0.589910    -1.073992    -0.015243     0.049581
# 620    1.306729    -0.616468    -1.103223    -1.388961     0.049581
# 621    0.169706    -1.416799    -1.064193    -1.818966     0.049581
# 622    0.328066    -0.312474    -0.724931    -0.636175     0.049581
# 623   -0.361029     0.274598    -0.924025    -0.216222     0.049581
#
#      stft_kur_w4  stft_skew_w4  actor
# 0       0.652919     -0.493238     19
# 1       0.350178     -0.551086     19
# 2       2.245793     -1.380431     19
# 3      -0.361240      0.018907     19
# 4       0.156689     -0.439458     19
# ..           ...           ...    ...
# 619     0.230264     -0.995984     24
# 620    -0.455872      0.666612     24
# 621    -0.671121      1.085149     24
# 622    -0.083593      0.182546     24
# 623     0.154279     -0.624532     24
#
# [624 rows x 163 columns]

# %%
attributes1=[col for col in df_train.columns if col !="Emotion"]
#la prima riga crea una lista attributes1 contenente i nomi di tutte le colonne del dataframe df_train
#che non corrispondono alla colonna "Vocal_channel_". In altre parole, vengono selezionate tutte le colonne che rappresentano le caratteristiche o feature degli esempi.
attributes2=[col for col in df_test.columns if col !="Emotion"]
#La seconda riga crea una lista attributes2 con lo stesso principio della prima, ma questa volta per il dataframe di test df_test_new.
X_train=df_train[attributes1].values
#La terza riga seleziona i valori di tutte le colonne elencate nella lista attributes1 del dataframe di train e li assegna alla variabile X_train.
y_train=np.array(df_train["Emotion"])
#La quarta riga seleziona i valori di tutte le colonne elencate nella lista attributes2 del dataframe di test e li assegna alla variabile X_test.
X_test=df_test[attributes2].values
#La quinta riga seleziona i valori della colonna "Vocal_channel_" del dataframe di train e li assegna alla variabile y_train.
y_test=np.array(df_test["Emotion"])
#La sesta riga seleziona i valori della colonna "Vocal_channel_" del dataframe di test e li assegna alla variabile y_test.

X_train.shape, y_train.shape, X_test.shape, y_test.shape
#L'ultima riga restituisce le dimensioni di X_train, y_train, X_test e y_test.

# il codice seleziona le feature e le etichette (o target) dal dataframe di train e dal dataframe di test, in modo da creare un insieme di dati di training
#e un insieme di dati di test, che possono essere utilizzati per addestrare e valutare un modello di apprendimento automatico.
# Out:
# ((1828, 162), (1828,), (624, 162), (624,))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle

def plot_res(y_pred, y_score, y_test):
    #ROC CURVE: implementazione legata esclusivamente all'attività di classificazione binaria
    #false positive rate, true positive rate
    print("****** ROC CURVE + AUC?: passo passo *******")


    # Genera alcuni dati di esempio per tre classi
    n_classes = 8


    # Binariaza le etichette
    y_true_bin = label_binarize(y_test, classes=np.arange(n_classes))

    # Calcola la curva ROC aggregata
    fpr, tpr, _ = roc_curve(y_true_bin.ravel(), y_score.ravel())
    roc_auc = auc(fpr, tpr)

    # Plotta la curva ROC
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2,
            label='Curva ROC (AUC = {0:0.2f})'
            ''.format(roc_auc))

    plt.plot([0, 1], [0, 1], 'k--', lw=2)  # Linea di riferimento diagonale
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Tasso di falsi positivi')
    plt.ylabel('Tasso di veri positivi')
    plt.title('Curva ROC per la classificazione multi-classe')
    plt.legend(loc="lower right")
    plt.show()

    print("____________________________________")
    print("****** VALORE DI AUC *******")
    print("____________________________________")
    print("****** VALORE DI AUC *******")
    micro_roc_auc_ovr = roc_auc_score(
        y_test,
        y_score,
        multi_class="ovr",
        average="micro",
)

    print(f"Micro-averaged One-vs-Rest ROC AUC score:\n{micro_roc_auc_ovr:.2f}")

    print("____________________________________")
    print("****** ROC CURVE: con metodo diretto *******")
    plot_roc(y_test, y_score)
    plt.show()

    print("____________________________________")
    print("****** Precision recall: con metodo diretto *******")
    plot_precision_recall(y_test, y_score)
    plt.show()

# %%
def result_pred(y_true, y_pred):
    print("**** Matrice di Confusione *****")
    # Calcola la matrice di confusione
    confusion_mat = confusion_matrix(y_true, y_pred)

    # Plotta la matrice di confusione
    plt.figure(figsize=(8, 6))
    sns.heatmap(confusion_mat, annot=True, fmt="d", cmap="Blues")
    plt.title("Matrice di confusione")
    plt.xlabel("Etichetta predetta")
    plt.ylabel("Etichetta vera")
    plt.show()


    # Calcolo dell'accuracy
    print("***** Calcolo dell'accuracy *****")
    accuracy = accuracy_score(y_true, y_pred)
    print('Accuracy: %0.4f' % accuracy)
    print("____________________________________________")

    # Calcolo della precision
    print("**** Calcolo della precisione *****")
    #Percentuale di classificazioni positive che sono corrette
    #se dico "positivo" dico giusto?
    precision = precision_score(y_true, y_pred, average ="macro")
    print('Percentuale di classificazioni positive che sono corrette: %0.4f' % precision)
    print("____________________________________________")

    # Calcolo della recall
    print("**** Calcolo della recall (sensitivity) *****")
    recall = recall_score(y_true, y_pred, average="macro")
    print('Percentuale di elementi positivi del testing set che sono stati classificati come positivi: %0.4f' % recall)
    print("____________________________________________")

    # Calcolo della specificity
    print("**** Calcolo della specificity *****")
   # Calcola la matrice di confusione
    confusion_mat = confusion_matrix(y_true, y_pred)

    # Calcola la specificità per ciascuna classe
    specificity_scores = []
    for i in range(n_classes):
        tn = np.sum(np.delete(np.delete(confusion_mat, i, axis=0), i, axis=1))
        fp_fn = np.sum(np.delete(confusion_mat, i, axis=0)[:, i]) + np.sum(confusion_mat[i, np.arange(n_classes) != i])
        specificity = tn / (tn + fp_fn)
        specificity_scores.append(specificity)

    # Stampa la specificità per ciascuna classe
    print("Specificità per classe:")
    for i, specificity in enumerate(specificity_scores):
        print("Classe {}: {:.2f}".format(i, specificity))
        print('Percentuale di elementi negativi del testing set che sono stati classificati come negativi: %0.4f' % specificity)
        print("-----")

    # Calcolo dell'F1 score
    print("**** Calcolo della F1 score *****")
    f1 = f1_score(y_true, y_pred, average="macro")
    #Il punteggio F1 può essere interpretato come una media ponderata della precisione e della recall,
    #in cui un punteggio F1 raggiunge il suo valore migliore a 1 e il punteggio peggiore a 0.
    print('F1 scores: %0.4f' % f1)
    print("____________________________________________")

    # Stampiamo le stesse statistiche dalla funzione report
    print(classification_report(y_test, y_pred))

    print("Con le tecniche viste finora non viene fornita nessuna informazione sulla “gravità” degli errori (“errore lieve” oppure “errore grave)")
    print("per questo si usano la curva CMC, la curva ROC")

# %%
def plt_single_perceptron(name_csv, pnl):
    df = pd.read_csv(name_csv)
    fig = plt.figure(figsize=(16,8))
    fig.canvas.manager.full_screen_toggle()

    fig.suptitle('Single Perceptron', fontsize=15, fontweight='bold')
    penalty = pnl
    df = df.loc[(df.penalty == penalty)][['f1','std_dev', 'alpha','tol']]
    pivot = df.pivot('alpha','tol', 'f1')
    labels = pivot.as_matrix().astype(str)

    x = 0
    for i in range(0, pivot.shape[0]):
        for j in range(0, pivot.shape[1]):
            labels[i,j] = str(labels[i,j])[:5] + "\n+/- " + "{0:.3f}".format(df['std_dev'].iloc[x])
            x += 1

    sns.heatmap(pivot, cmap="YlGnBu", annot=labels, fmt="", cbar=False, square=True, linewidths=.5, cbar_kws={"shrink": .5})

    plt.show()

# %% [markdown]
# Le righe di codice che hai fornito creano un training set e un test set, prendendo come input i dati originali contenuti nei dataframe df_train e df_test_new

# %% [markdown]
# ##SKLEARN MULTILAYER PERCEPTRON

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
hidden_layer_sizes = (100,200,)

# %% [markdown]
# Il codice hidden_layer_sizes = (100, 200,) definisce una tupla di dimensioni (100, 200) che rappresenta il numero di neuroni presenti in ciascuno strato nascosto di una rete neurale. In particolare, la tupla indica che la rete neurale ha due strati nascosti, uno con 100 neuroni e uno con 200 neuroni.
#
# Le reti neurali sono composte da una serie di strati di neuroni, in cui ogni neurone è connesso a tutti gli altri neuroni dello strato precedente e di quello successivo. Ogni strato di neuroni può avere un numero variabile di neuroni, che dipende dal problema specifico e dalla complessità della funzione da apprendere.
# Nella tupla (100, 200,) i numeri indicano il numero di neuroni nei rispettivi strati nascosti. Ad esempio, la tupla (50, 30, 20,) indica che la rete neurale ha tre strati nascosti, rispettivamente con 50, 30 e 20 neuroni.
#
# La scelta del numero di strati e di neuroni in ciascuno strato è un aspetto fondamentale nella progettazione delle reti neurali, poiché ha un impatto significativo sulle prestazioni e sulla capacità di generalizzazione del modello.

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV

k_fold = StratifiedKFold(n_splits=4)


# Definizione dei parametri da testare
parameters = {
    'hidden_layer_sizes': [(12, 23, 11), (23, 43, 32), (128, 64, 32)],
    'activation': ['logistic', 'relu'],
    'learning_rate': ['constant', 'invscaling', 'adaptive'],
    'tol': [1e-2, 1e-3, 1e-4],

    #'alpha': 10.0 ** -np.arange(1, 7),
    'early_stopping': [True, False]
}

# Creazione dell'oggetto della rete neurale
neural_net = MLPClassifier()

# Creazione dell'oggetto GridSearchCV
grid_search = GridSearchCV(neural_net, parameters, cv=5)

# Addestramento della rete neurale con la grid search
grid_search.fit(X_train, y_train)

# Stampare i risultati
print("Best parameters set found on development set:")
print()
print(grid_search.best_params_)
print()
print("Grid scores on development set:")
print()
means = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, grid_search.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
          % (mean, std * 2, params))
print()

# Valutazione finale del modello
print("Best score achieved: %0.3f" % grid_search.best_score_)
print()
print("Detailed classification report:")
print()
print("The model is trained on the full development set.")
print("The scores are computed on the full evaluation set.")
print()
y_true, y_pred = y_test, grid_search.predict(X_test)
result_pred(y_test, y_pred)
y_score = clf.predict_proba(X_test)
plot_res(y_pred, y_score, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best parameters set found on development set:
#
# {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'tol': 0.0001}
#
# Grid scores on development set:
#
# 0.215 (+/-0.094) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'tol': 0.01}
# 0.261 (+/-0.152) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'tol': 0.001}
# 0.206 (+/-0.130) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'tol': 0.0001}
# 0.217 (+/-0.105) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'tol': 0.01}
# 0.239 (+/-0.129) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'tol': 0.001}
# 0.187 (+/-0.086) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'tol': 0.0001}
# 0.203 (+/-0.091) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'tol': 0.01}
# 0.241 (+/-0.088) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'tol': 0.001}
# 0.254 (+/-0.046) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'tol': 0.0001}
# 0.271 (+/-0.126) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'tol': 0.01}
# 0.304 (+/-0.167) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'tol': 0.001}
# 0.321 (+/-0.144) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'tol': 0.0001}
# 0.283 (+/-0.146) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'tol': 0.01}
# 0.258 (+/-0.106) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'tol': 0.001}
# 0.321 (+/-0.072) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'tol': 0.0001}
# 0.324 (+/-0.047) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'tol': 0.01}
# 0.282 (+/-0.142) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'tol': 0.001}
# 0.223 (+/-0.139) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'tol': 0.0001}
# 0.358 (+/-0.119) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'tol': 0.01}
# 0.397 (+/-0.055) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'tol': 0.001}
# 0.347 (+/-0.146) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'tol': 0.0001}
# 0.331 (+/-0.117) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'tol': 0.01}
# 0.405 (+/-0.053) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'tol': 0.001}
# 0.386 (+/-0.072) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'tol': 0.0001}
# 0.347 (+/-0.144) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'tol': 0.01}
# 0.414 (+/-0.036) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'tol': 0.001}
# 0.374 (+/-0.047) for {'activation': 'logistic', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'tol': 0.0001}
# 0.206 (+/-0.064) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'tol': 0.01}
# 0.353 (+/-0.046) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'tol': 0.001}
# 0.365 (+/-0.044) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'tol': 0.0001}
# 0.232 (+/-0.086) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'tol': 0.01}
# 0.374 (+/-0.037) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'tol': 0.001}
# 0.350 (+/-0.060) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'tol': 0.0001}
# 0.239 (+/-0.127) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'tol': 0.01}
# 0.349 (+/-0.099) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'tol': 0.001}
# 0.370 (+/-0.056) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'tol': 0.0001}
# 0.275 (+/-0.065) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'tol': 0.01}
# 0.369 (+/-0.060) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'tol': 0.001}
# 0.384 (+/-0.031) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'tol': 0.0001}
# 0.305 (+/-0.112) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'tol': 0.01}
# 0.388 (+/-0.074) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'tol': 0.001}
# 0.381 (+/-0.035) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'tol': 0.0001}
# 0.330 (+/-0.085) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'tol': 0.01}
# 0.383 (+/-0.056) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'tol': 0.001}
# 0.383 (+/-0.040) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'tol': 0.0001}
# 0.418 (+/-0.032) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'tol': 0.01}
# 0.422 (+/-0.058) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'tol': 0.001}
# 0.424 (+/-0.030) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'tol': 0.0001}
# 0.410 (+/-0.028) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'tol': 0.01}
# 0.415 (+/-0.069) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'tol': 0.001}
# 0.416 (+/-0.032) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'tol': 0.0001}
# 0.415 (+/-0.064) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'tol': 0.01}
# 0.413 (+/-0.048) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'tol': 0.001}
# 0.427 (+/-0.037) for {'activation': 'logistic', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'tol': 0.0001}
# 0.369 (+/-0.091) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'tol': 0.01}
# 0.381 (+/-0.071) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'tol': 0.001}
# 0.356 (+/-0.064) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'tol': 0.0001}
# 0.386 (+/-0.064) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'tol': 0.01}
# 0.356 (+/-0.081) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'tol': 0.001}
# 0.360 (+/-0.062) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'tol': 0.0001}
# 0.343 (+/-0.029) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'tol': 0.01}
# 0.385 (+/-0.056) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'tol': 0.001}
# 0.376 (+/-0.073) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'tol': 0.0001}
# 0.401 (+/-0.041) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'tol': 0.01}
# 0.402 (+/-0.032) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'tol': 0.001}
# 0.383 (+/-0.071) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'tol': 0.0001}
# 0.397 (+/-0.026) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'tol': 0.01}
# 0.392 (+/-0.036) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'tol': 0.001}
# 0.395 (+/-0.050) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'tol': 0.0001}
# 0.406 (+/-0.091) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'tol': 0.01}
# 0.376 (+/-0.058) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'tol': 0.001}
# 0.378 (+/-0.056) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'tol': 0.0001}
# 0.416 (+/-0.069) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'tol': 0.01}
# 0.441 (+/-0.044) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'tol': 0.001}
# 0.434 (+/-0.069) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'tol': 0.0001}
# 0.411 (+/-0.096) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'tol': 0.01}
# 0.408 (+/-0.034) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'tol': 0.001}
# 0.407 (+/-0.051) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'tol': 0.0001}
# 0.416 (+/-0.025) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'tol': 0.01}
# 0.411 (+/-0.062) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'tol': 0.001}
# 0.431 (+/-0.091) for {'activation': 'relu', 'early_stopping': True, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'tol': 0.0001}
# 0.417 (+/-0.056) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'tol': 0.01}
# 0.389 (+/-0.029) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'tol': 0.001}
# 0.394 (+/-0.030) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'tol': 0.0001}
# 0.406 (+/-0.042) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'tol': 0.01}
# 0.396 (+/-0.019) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'tol': 0.001}
# 0.406 (+/-0.029) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'tol': 0.0001}
# 0.403 (+/-0.044) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'tol': 0.01}
# 0.403 (+/-0.046) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'tol': 0.001}
# 0.395 (+/-0.081) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'tol': 0.0001}
# 0.394 (+/-0.059) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'tol': 0.01}
# 0.386 (+/-0.044) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'tol': 0.001}
# 0.405 (+/-0.054) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'tol': 0.0001}
# 0.405 (+/-0.072) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'tol': 0.01}
# 0.384 (+/-0.067) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'tol': 0.001}
# 0.394 (+/-0.044) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'tol': 0.0001}
# 0.411 (+/-0.054) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'tol': 0.01}
# 0.401 (+/-0.059) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'tol': 0.001}
# 0.400 (+/-0.063) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'tol': 0.0001}
# 0.426 (+/-0.063) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'tol': 0.01}
# 0.428 (+/-0.070) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'tol': 0.001}
# 0.421 (+/-0.052) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'tol': 0.0001}
# 0.428 (+/-0.062) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'tol': 0.01}
# 0.434 (+/-0.076) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'tol': 0.001}
# 0.404 (+/-0.053) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'tol': 0.0001}
# 0.439 (+/-0.077) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'tol': 0.01}
# 0.425 (+/-0.077) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'tol': 0.001}
# 0.444 (+/-0.075) for {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'tol': 0.0001}
#
# Best score achieved: 0.444
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
# **** Matrice di Confusione *****
# ***** Calcolo dell'accuracy *****
# Accuracy: 0.4840
# ____________________________________________
# **** Calcolo della precisione *****
# Percentuale di classificazioni positive che sono corrette: 0.5078
# ____________________________________________
# **** Calcolo della recall (sensitivity) *****
# Percentuale di elementi positivi del testing set che sono stati classificati come positivi: 0.4557
# ____________________________________________
# **** Calcolo della specificity *****
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-5ef93f2ff2d0> in <cell line: 49>()
#      47 print()
#      48 y_true, y_pred = y_test, grid_search.predict(X_test)
# ---> 49 result_pred(y_test, y_pred)
#      50 y_score = clf.predict_proba(X_test)
#      51 plot_res(y_pred, y_score, y_test)
#
# <ipython-input-9-f53857ecb3b3> in result_pred(y_true, y_pred)
#      42     for i in range(n_classes):
#      43         tn = np.sum(np.delete(np.delete(confusion_mat, i, axis=0), i, axis=1))
# ---> 44         fp_fn = np.sum(np.delete(confusion_mat, i, axis=0)[:, i]) + np.sum(confusion_mat[i, np.arange(n_classes) != i])
#      45         specificity = tn / (tn + fp_fn)
#      46         specificity_scores.append(specificity)
#
# IndexError: boolean index did not match indexed array along dimension 1; dimension is 8 but corresponding boolean dimension is 2

# %% [markdown]
# {'activation': 'relu', 'early_stopping': False, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'tol': 0.0001}

# %%
clf = MLPClassifier(solver = 'adam', momentum = 0.9, learning_rate = 'adaptive' , hidden_layer_sizes=(128, 64, 32),early_stopping= False, activation= "relu")
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
y_score = clf.predict_proba(X_test)
plot_res(y_pred, y_score, y_test)
# Out:
# ****** ROC CURVE + AUC?: passo passo *******
# ____________________________________
# ****** VALORE DI AUC *******
# ____________________________________
# ****** VALORE DI AUC *******
# Micro-averaged One-vs-Rest ROC AUC score:
# 0.85
# ____________________________________
# ****** ROC CURVE: con metodo diretto *******
# ____________________________________
# ****** Precision recall: con metodo diretto *******

# %%
#PLOT LEARNING CURVE

from sklearn.model_selection import learning_curve
# Calcola la learning curve
train_sizes, train_scores, test_scores = learning_curve(
    clf, X_train, y_train, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)

# Calcola le medie e gli errori standard delle prestazioni
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plotta la learning curve
plt.figure(figsize=(8, 6))
plt.title('Learning Curve - Random Forest + GridSeardch')
plt.xlabel('Training examples')
plt.ylabel('Score')
plt.grid(True)
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.1,
                 color='b')
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.1,
                 color='r')
plt.plot(train_sizes, train_scores_mean, 'o-', color='b',
         label='Training score')
plt.plot(train_sizes, test_scores_mean, 'o-', color='r',
         label='Cross-validation score')
plt.legend(loc='best')
plt.show()

# %%
clf1 = MLPClassifier(solver = 'adam', momentum = 0.9, learning_rate = 'adaptive' , hidden_layer_sizes=(128, 64, 32),early_stopping= False, activation= "relu")
#-hidden_layer_sizes=(128, 64, 32,) definisce la struttura della rete neurale artificiale: in questo caso,
#si tratta di una rete a tre strati, con il primo strato contenente 128 neuroni, il secondo strato contenente 64 neuroni e il terzo strato contenente 32 neuroni.
#-alpha=0.1 specifica la regolarizzazione L2, che viene utilizzata per prevenire l'overfitting dei dati di addestramento
#-learning_rate='adaptive' indica che la dimensione del passo di apprendimento deve essere adattata automaticamente in base alla convergenza del modello.
#-activation='tanh' specifica la funzione di attivazione del neurone, che viene utilizzata per introdurre non-linearità nella rete neurale.
#-early_stopping=True utilizza la tecnica di early stopping, ovvero interrompe l'addestramento del modello quando la performance sul set di validazione smette di migliorare.
#-momentum=0.9 indica il valore del momentum, che viene utilizzato per aggiornare i pesi del modello in modo da evitare minimi locali durante l'addestramento.
#-random_state=0 imposta il seed per la generazione di numeri casuali, in modo da rendere riproducibili i risultati.

clf1.fit(X_train, y_train)

y_pred=clf1.predict(X_test)
#Le righe successive addestrano il modello sulla base dei dati di addestramento X_train e y_train, utilizzando il metodo fit della classe MLPClassifier.
#Successivamente, il modello viene utilizzato per effettuare la predizione sui dati di test X_test utilizzando il metodo predict, e le predizioni risultanti vengono assegnate alla variabile y_pred

print("Accuracy %s", accuracy_score(y_test, y_pred))
print("F1-score %s", f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy %s 0.4567307692307692
# F1-score %s [0.58653846 0.47887324 0.42477876 0.50515464 0.47567568 0.23529412
#  0.36458333 0.34666667]
#               precision    recall  f1-score   support
#
#            0       0.54      0.64      0.59        96
#            1       0.44      0.53      0.48        96
#            2       0.37      0.50      0.42        48
#            3       0.50      0.51      0.51        96
#            4       0.49      0.46      0.48        96
#            5       0.40      0.17      0.24        48
#            6       0.36      0.36      0.36        96
#            7       0.48      0.27      0.35        48
#
#     accuracy                           0.46       624
#    macro avg       0.45      0.43      0.43       624
# weighted avg       0.46      0.46      0.45       624

# %% [markdown]
# Questo codice crea un'istanza della classe MLPClassifier dal modulo sklearn.neural_network e addestra il modello utilizzando i dati di addestramento X_train e y_train. In particolare, MLPClassifier è un algoritmo di rete neurale artificiale con struttura multistrato, che utilizza la retropropagazione per apprendere dai dati.
#
# Dopo l'addestramento, il modello viene utilizzato per effettuare la predizione sui dati di test X_test utilizzando il metodo predict, e le predizioni risultanti vengono assegnate alla variabile y_pred. In altre parole, si sta usando la rete neurale artificiale addestrata per fare delle previsioni sui dati di test.
#
# La classe MLPClassifier offre diverse opzioni per personalizzare il modello, come ad esempio il numero di strati, il numero di neuroni per strato, la funzione di attivazione, il solver per l'ottimizzazione, la regolarizzazione, e molte altre opzioni.

# %%
plt.plot(clf1.loss_curve_)
plt.show()

# %%
#PLOT ROC

y_score = clf1.predict_proba(X_test)
plot_res(y_pred, y_score, y_test)

#PLOT LEARNING CURVE

from sklearn.model_selection import learning_curve
# Calcola la learning curve
train_sizes, train_scores, test_scores = learning_curve(
    clf1, X_train, y_train, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)

# Calcola le medie e gli errori standard delle prestazioni
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plotta la learning curve
plt.figure(figsize=(8, 6))
plt.title('Learning Curve - Random Forest + GridSeardch')
plt.xlabel('Training examples')
plt.ylabel('Score')
plt.grid(True)
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.1,
                 color='b')
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.1,
                 color='r')
plt.plot(train_sizes, train_scores_mean, 'o-', color='b',
         label='Training score')
plt.plot(train_sizes, test_scores_mean, 'o-', color='r',
         label='Cross-validation score')
plt.legend(loc='best')
plt.show()
# Out:
# ****** ROC CURVE + AUC?: passo passo *******
# ____________________________________
# ****** VALORE DI AUC *******
# ____________________________________
# ****** VALORE DI AUC *******
# Micro-averaged One-vs-Rest ROC AUC score:
# 0.85
# ____________________________________
# ****** ROC CURVE: con metodo diretto *******
# ____________________________________
# ****** Precision recall: con metodo diretto *******

# %%
clf2 = MLPClassifier(hidden_layer_sizes=(128, 64, 32,), alpha=0.1, learning_rate='adaptive',
                    activation='tanh', early_stopping=True, momentum=0.9, random_state=0)
#-hidden_layer_sizes=(128, 64, 32,) definisce la struttura della rete neurale artificiale: in questo caso,
#si tratta di una rete a tre strati, con il primo strato contenente 128 neuroni, il secondo strato contenente 64 neuroni e il terzo strato contenente 32 neuroni.
#-alpha=0.1 specifica la regolarizzazione L2, che viene utilizzata per prevenire l'overfitting dei dati di addestramento
#-learning_rate='adaptive' indica che la dimensione del passo di apprendimento deve essere adattata automaticamente in base alla convergenza del modello.
#-activation='tanh' specifica la funzione di attivazione del neurone, che viene utilizzata per introdurre non-linearità nella rete neurale.
#-early_stopping=True utilizza la tecnica di early stopping, ovvero interrompe l'addestramento del modello quando la performance sul set di validazione smette di migliorare.
#-momentum=0.9 indica il valore del momentum, che viene utilizzato per aggiornare i pesi del modello in modo da evitare minimi locali durante l'addestramento.
#-random_state=0 imposta il seed per la generazione di numeri casuali, in modo da rendere riproducibili i risultati.

clf2.fit(X_train, y_train)

y_pred=clf2.predict(X_test)
#Le righe successive addestrano il modello sulla base dei dati di addestramento X_train e y_train, utilizzando il metodo fit della classe MLPClassifier.
#Successivamente, il modello viene utilizzato per effettuare la predizione sui dati di test X_test utilizzando il metodo predict, e le predizioni risultanti vengono assegnate alla variabile y_pred

print("Accuracy %s", accuracy_score(y_test, y_pred))
print("F1-score %s", f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

#L'accuracy, ovvero la percentuale di predizioni corrette, calcolata utilizzando la funzione accuracy_score della libreria sklearn.metrics.
#L'F1-score, ovvero una metrica di valutazione del modello che tiene conto di precisione e recall per ogni classe, calcolata utilizzando la funzione f1_score della libreria sklearn.metrics.
# Out:
# Accuracy %s 0.4342948717948718
# F1-score %s [0.54074074 0.49473684 0.46666667 0.41618497 0.33519553 0.25396825
#  0.47058824 0.20253165]
#               precision    recall  f1-score   support
#
#            0       0.42      0.76      0.54        96
#            1       0.50      0.49      0.49        96
#            2       0.50      0.44      0.47        48
#            3       0.47      0.38      0.42        96
#            4       0.36      0.31      0.34        96
#            5       0.53      0.17      0.25        48
#            6       0.44      0.50      0.47        96
#            7       0.26      0.17      0.20        48
#
#     accuracy                           0.43       624
#    macro avg       0.44      0.40      0.40       624
# weighted avg       0.44      0.43      0.42       624

# %%
#PLOT ROC

y_score = clf2.predict_proba(X_test)
plot_res(y_pred, y_score, y_test)

#PLOT LEARNING CURVE

from sklearn.model_selection import learning_curve
# Calcola la learning curve
train_sizes, train_scores, test_scores = learning_curve(
    clf2, X_train, y_train, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)

# Calcola le medie e gli errori standard delle prestazioni
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plotta la learning curve
plt.figure(figsize=(8, 6))
plt.title('Learning Curve - Random Forest + GridSeardch')
plt.xlabel('Training examples')
plt.ylabel('Score')
plt.grid(True)
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.1,
                 color='b')
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.1,
                 color='r')
plt.plot(train_sizes, train_scores_mean, 'o-', color='b',
         label='Training score')
plt.plot(train_sizes, test_scores_mean, 'o-', color='r',
         label='Cross-validation score')
plt.legend(loc='best')
plt.show()
# Out:
# ****** ROC CURVE + AUC?: passo passo *******
# ____________________________________
# ****** VALORE DI AUC *******
# ____________________________________
# ****** VALORE DI AUC *******
# Micro-averaged One-vs-Rest ROC AUC score:
# 0.84
# ____________________________________
# ****** ROC CURVE: con metodo diretto *******
# ____________________________________
# ****** Precision recall: con metodo diretto *******

# %%
#Con i codi ci qui sotto vado a calcolare l'accuracy sui dati di train e
#di test er vedere se abbiamo overfitting

clf21 = MLPClassifier(hidden_layer_sizes=(128, 64, 32,), alpha=0.1, learning_rate='adaptive',
                    activation='tanh', early_stopping=True, momentum=0.9, random_state=0)
clf21.fit(X_train, y_train)
y_train_pred=clf21.predict(X_train)
train_acc=accuracy_score(y_train, y_train_pred)
print("Accuracy sul training", train_acc)
error_train=(1-train_acc)
print("L'errore sul train ottenuto equivale a: %", error_train)
print("______________________________________")

print()

clf22 = MLPClassifier(activation= 'relu', hidden_layer_sizes= (128, 64, 32), learning_rate= 'adaptive', momentum= 0.4, tol= 0.001)
clf22.fit(X_test, y_test)
y_test_pred=clf22.predict(X_test)
test_acc=accuracy_score(y_test, y_test_pred)
print("Accuracy sul test", test_acc)
error_test=(1-test_acc)
print("L'errore sul train ottenuto equivale a: %", error_test)
# Out:
# Accuracy sul training 0.7226477024070022
# L'errore sul train ottenuto equivale a: % 0.27735229759299784
# ______________________________________
#
# Accuracy sul test 1.0
# L'errore sul train ottenuto equivale a: % 0.0

# %%
plt.plot(clf2.loss_curve_)
plt.show()

# %% [markdown]
# ##MULTILAYER PERCEPTRON + OVERSAMPLING

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning


ros = RandomOverSampler(random_state=42)
X_res, y_res = ros.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({5: 280, 1: 280, 4: 280, 6: 280, 0: 280, 3: 280, 2: 280, 7: 280})

# %%
# %%time
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV

k_fold = StratifiedKFold(n_splits=4)


# Definizione dei parametri da testare
parameters = {
    'hidden_layer_sizes': [(12, 23, 11), (23, 43, 32), (128, 64, 32)],
    'activation': ['logistic', 'relu'],
    'learning_rate': ['constant', 'invscaling', 'adaptive'],
    'tol': [1e-2, 1e-3, 1e-4],
    #'alpha': 10.0 ** -np.arange(1, 7),
    'momentum' : [ 0.1, 0.2, 0.3, 0.4]

}

# Creazione dell'oggetto della rete neurale
neural_net = MLPClassifier()

# Creazione dell'oggetto GridSearchCV
grid_search = GridSearchCV(neural_net, parameters, cv=5)

# Addestramento della rete neurale con la grid search
grid_search.fit(X_res, y_res)

# Stampare i risultati
print("Best parameters set found on development set:")
print()
print(grid_search.best_params_)
print()
print("Grid scores on development set:")
print()
means = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, grid_search.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
          % (mean, std * 2, params))
print()

# Valutazione finale del modello
print("Best score achieved: %0.3f" % grid_search.best_score_)
print()
print("Detailed classification report:")
print()
print("The model is trained on the full development set.")
print("The scores are computed on the full evaluation set.")
print()
y_true, y_pred = y_test, grid_search.predict(X_test)
result_pred(y_test, y_pred)
y_score = clf.predict_proba(X_test)
plot_res(y_pred, y_score, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...
# 0.555 (+/-0.066) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.001}
# 0.552 (+/-0.082) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.0001}
# 0.534 (+/-0.061) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.01}
# 0.561 (+/-0.061) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.001}
# 0.568 (+/-0.068) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.0001}
# 0.515 (+/-0.073) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.01}
# 0.549 (+/-0.090) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.001}
# 0.570 (+/-0.072) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.0001}
# 0.523 (+/-0.072) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.01}
# 0.544 (+/-0.080) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.001}
# 0.559 (+/-0.076) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.0001}
# 0.505 (+/-0.048) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.01}
# 0.552 (+/-0.070) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.001}
# 0.538 (+/-0.076) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.0001}
# 0.517 (+/-0.071) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.01}
# 0.544 (+/-0.045) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.001}
# 0.569 (+/-0.045) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.0001}
# 0.514 (+/-0.071) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.01}
# 0.557 (+/-0.098) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.001}
# 0.562 (+/-0.087) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.0001}
# 0.508 (+/-0.064) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.01}
# 0.557 (+/-0.058) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.001}
# 0.543 (+/-0.079) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.0001}
# 0.512 (+/-0.103) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.01}
# 0.542 (+/-0.103) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.001}
# 0.567 (+/-0.052) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.0001}
# 0.501 (+/-0.092) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.01}
# 0.559 (+/-0.088) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.001}
# 0.570 (+/-0.109) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.0001}
# 0.487 (+/-0.070) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.01}
# 0.551 (+/-0.068) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.001}
# 0.552 (+/-0.084) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.0001}
# 0.557 (+/-0.064) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.1, 'tol': 0.01}
# 0.567 (+/-0.041) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.1, 'tol': 0.001}
# 0.563 (+/-0.079) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.1, 'tol': 0.0001}
# 0.550 (+/-0.046) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.01}
# 0.567 (+/-0.055) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.001}
# 0.561 (+/-0.067) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.0001}
# 0.551 (+/-0.053) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.01}
# 0.578 (+/-0.064) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.001}
# 0.556 (+/-0.058) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.0001}
# 0.553 (+/-0.088) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.01}
# 0.561 (+/-0.061) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.001}
# 0.562 (+/-0.085) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.0001}
# 0.549 (+/-0.071) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.01}
# 0.578 (+/-0.073) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.001}
# 0.562 (+/-0.027) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.0001}
# 0.560 (+/-0.044) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.01}
# 0.580 (+/-0.046) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.001}
# 0.571 (+/-0.086) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.0001}
# 0.559 (+/-0.071) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.01}
# 0.567 (+/-0.074) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.001}
# 0.573 (+/-0.062) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.0001}
# 0.563 (+/-0.059) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.01}
# 0.563 (+/-0.074) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.001}
# 0.578 (+/-0.060) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.0001}
# 0.562 (+/-0.062) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.01}
# 0.579 (+/-0.056) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.001}
# 0.581 (+/-0.093) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.0001}
# 0.557 (+/-0.062) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.01}
# 0.562 (+/-0.034) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.001}
# 0.567 (+/-0.081) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.0001}
# 0.558 (+/-0.045) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.01}
# 0.565 (+/-0.054) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.001}
# 0.563 (+/-0.077) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.0001}
# 0.546 (+/-0.057) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.01}
# 0.568 (+/-0.045) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.001}
# 0.578 (+/-0.091) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.0001}
# 0.579 (+/-0.042) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.1, 'tol': 0.01}
# 0.573 (+/-0.053) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.1, 'tol': 0.001}
# 0.582 (+/-0.060) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.1, 'tol': 0.0001}
# 0.576 (+/-0.062) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.01}
# 0.580 (+/-0.081) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.001}
# 0.588 (+/-0.066) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.0001}
# 0.558 (+/-0.084) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.01}
# 0.574 (+/-0.074) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.001}
# 0.578 (+/-0.069) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.0001}
# 0.578 (+/-0.064) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.01}
# 0.571 (+/-0.058) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.001}
# 0.571 (+/-0.063) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.0001}
# 0.565 (+/-0.051) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.01}
# 0.567 (+/-0.055) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.001}
# 0.582 (+/-0.047) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.0001}
# 0.569 (+/-0.062) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.01}
# 0.568 (+/-0.090) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.001}
# 0.580 (+/-0.074) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.0001}
# 0.567 (+/-0.068) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.01}
# 0.562 (+/-0.048) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.001}
# 0.579 (+/-0.044) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.0001}
# 0.569 (+/-0.039) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.01}
# 0.565 (+/-0.053) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.001}
# 0.583 (+/-0.042) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.0001}
# 0.569 (+/-0.061) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.01}
# 0.575 (+/-0.056) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.001}
# 0.575 (+/-0.053) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.0001}
# 0.563 (+/-0.060) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.01}
# 0.586 (+/-0.086) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.001}
# 0.578 (+/-0.045) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.0001}
# 0.562 (+/-0.051) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.01}
# 0.565 (+/-0.055) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.001}
# 0.564 (+/-0.052) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.0001}
# 0.581 (+/-0.074) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.01}
# 0.573 (+/-0.083) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.001}
# 0.576 (+/-0.039) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.0001}
#
# Best score achieved: 0.611
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
# **** Matrice di Confusione *****
# ***** Calcolo dell'accuracy *****
# Accuracy: 0.4359
# ____________________________________________
# **** Calcolo della precisione *****
# Percentuale di classificazioni positive che sono corrette: 0.4268
# ____________________________________________
# **** Calcolo della recall (sensitivity) *****
# Percentuale di elementi positivi del testing set che sono stati classificati come positivi: 0.4336
# ____________________________________________
# **** Calcolo della specificity *****
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-9-f53857ecb3b3> in result_pred(y_true, y_pred)
#      40     # Calcola la specificità per ciascuna classe
#      41     specificity_scores = []
# ---> 42     for i in range(n_classes):
#      43         tn = np.sum(np.delete(np.delete(confusion_mat, i, axis=0), i, axis=1))
#      44         fp_fn = np.sum(np.delete(confusion_mat, i, axis=0)[:, i]) + np.sum(confusion_mat[i, np.arange(n_classes) != i])
#
# NameError: name 'n_classes' is not defined

# %% [markdown]
# Target variable: emotion
# {'activation': 'logistic', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.001}

# %%
clf3 = MLPClassifier(hidden_layer_sizes=(128, 64, 32,), alpha=0.1, learning_rate='constant',
                    activation='logistic', early_stopping=False, momentum=0.2, random_state=0)
#-hidden_layer_sizes=(128, 64, 32,) definisce la struttura della rete neurale artificiale: in questo caso,
#si tratta di una rete a tre strati, con il primo strato contenente 128 neuroni, il secondo strato contenente 64 neuroni e il terzo strato contenente 32 neuroni.
#-alpha=0.1 specifica la regolarizzazione L2, che viene utilizzata per prevenire l'overfitting dei dati di addestramento
#-learning_rate='adaptive' indica che la dimensione del passo di apprendimento deve essere adattata automaticamente in base alla convergenza del modello.
#-activation='tanh' specifica la funzione di attivazione del neurone, che viene utilizzata per introdurre non-linearità nella rete neurale.
#-early_stopping=True utilizza la tecnica di early stopping, ovvero interrompe l'addestramento del modello quando la performance sul set di validazione smette di migliorare.
#-momentum=0.9 indica il valore del momentum, che viene utilizzato per aggiornare i pesi del modello in modo da evitare minimi locali durante l'addestramento.
#-random_state=0 imposta il seed per la generazione di numeri casuali, in modo da rendere riproducibili i risultati.

clf3.fit(X_train, y_train)

y_pred=clf.predict(X_test)
#Le righe successive addestrano il modello sulla base dei dati di addestramento X_train e y_train, utilizzando il metodo fit della classe MLPClassifier.
#Successivamente, il modello viene utilizzato per effettuare la predizione sui dati di test X_test utilizzando il metodo predict, e le predizioni risultanti vengono assegnate alla variabile y_pred

print("Accuracy %s", accuracy_score(y_test, y_pred))
print("F1-score %s", f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy %s 0.46153846153846156
# F1-score %s [0.60465116 0.52444444 0.37735849 0.48051948 0.47488584 0.28571429
#  0.37254902 0.25806452]
#               precision    recall  f1-score   support
#
#            0       0.55      0.68      0.60        96
#            1       0.46      0.61      0.52        96
#            2       0.34      0.42      0.38        48
#            3       0.64      0.39      0.48        96
#            4       0.42      0.54      0.47        96
#            5       0.60      0.19      0.29        48
#            6       0.35      0.40      0.37        96
#            7       0.57      0.17      0.26        48
#
#     accuracy                           0.46       624
#    macro avg       0.49      0.42      0.42       624
# weighted avg       0.49      0.46      0.45       624
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# VALUTIAMO L'OVERFITTING

# %%
#Con i codi ci qui sotto vado a calcolare l'accuracy sui dati di train e
#di test er vedere se abbiamo overfitting

clf = MLPClassifier(hidden_layer_sizes=(128, 64, 32,), alpha=0.1, learning_rate='constant',
                    activation='logistic', early_stopping=False, momentum=0.2, random_state=0)
clf.fit(X_train, y_train)
y_train_pred=clf.predict(X_train)
train_acc=accuracy_score(y_train, y_train_pred)
print("Accuracy sul training", train_acc)
error_train=(1-train_acc)
print("L'errore sul train ottenuto equivale a: %", error_train)
print("______________________________________")

print()

clf = MLPClassifier(hidden_layer_sizes=(128, 64, 32,), alpha=0.1, learning_rate='constant',
                    activation='logistic', early_stopping=False, momentum=0.2, random_state=0)
clf.fit(X_test, y_test)
y_test_pred=clf.predict(X_test)
test_acc=accuracy_score(y_test, y_test_pred)
print("Accuracy sul test", test_acc)
error_test=(1-test_acc)
print("L'errore sul train ottenuto equivale a: %", error_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Accuracy sul training 0.8468271334792122
# L'errore sul train ottenuto equivale a: % 0.15317286652078776
# ______________________________________
#
# Accuracy sul test 0.6426282051282052
# L'errore sul train ottenuto equivale a: % 0.3573717948717948
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
#PLOT ROC

y_score = clf3.predict_proba(X_test)
plot_res(y_pred, y_score, y_test)

#PLOT LEARNING CURVE

from sklearn.model_selection import learning_curve
# Calcola la learning curve
train_sizes, train_scores, test_scores = learning_curve(
    clf3, X_train, y_train, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)

# Calcola le medie e gli errori standard delle prestazioni
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plotta la learning curve
plt.figure(figsize=(8, 6))
plt.title('Learning Curve - Random Forest + GridSeardch')
plt.xlabel('Training examples')
plt.ylabel('Score')
plt.grid(True)
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.1,
                 color='b')
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.1,
                 color='r')
plt.plot(train_sizes, train_scores_mean, 'o-', color='b',
         label='Training score')
plt.plot(train_sizes, test_scores_mean, 'o-', color='r',
         label='Cross-validation score')
plt.legend(loc='best')
plt.show()
# Out:
# ****** ROC CURVE + AUC?: passo passo *******
# ____________________________________
# ****** VALORE DI AUC *******
# ____________________________________
# ****** VALORE DI AUC *******
# Micro-averaged One-vs-Rest ROC AUC score:
# 0.86
# ____________________________________
# ****** ROC CURVE: con metodo diretto *******
# ____________________________________
# ****** Precision recall: con metodo diretto *******
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# ##MULTILAYER + UNDERSAMPLING

# %% [markdown]
# è UN ESPERIMENTO: PROVO A RIDURRE CON PCA PER VEDERE SE CAMBIANO LE PERFORMANCE

# %%
ros = RandomUnderSampler(random_state=42)
X_res1, y_res1 = ros.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res1))
# Out:
# Resampled dataset shape Counter({0: 140, 1: 140, 2: 140, 3: 140, 4: 140, 5: 140, 6: 140, 7: 140})

# %%
neural_net1 = MLPClassifier(activation= 'relu', hidden_layer_sizes= (128, 64, 32), learning_rate= 'adaptive', momentum= 0.4, tol= 0.001)
neural_net1.fit(X_res1,y_res1)
y_pred = neural_net1.predict(X_res1)
print(classification_report(y_res1, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       140
#            1       1.00      1.00      1.00       140
#            2       1.00      1.00      1.00       140
#            3       1.00      1.00      1.00       140
#            4       1.00      1.00      1.00       140
#            5       1.00      1.00      1.00       140
#            6       1.00      1.00      1.00       140
#            7       1.00      1.00      1.00       140
#
#     accuracy                           1.00      1120
#    macro avg       1.00      1.00      1.00      1120
# weighted avg       1.00      1.00      1.00      1120

# %%
#PLOT ROC

y_score = neural_net1.predict_proba(X_test)
plot_res(y_pred, y_score, y_test)

#PLOT LEARNING CURVE

from sklearn.model_selection import learning_curve
# Calcola la learning curve
train_sizes, train_scores, test_scores = learning_curve(
    neural_net1, X_res1, y_res1, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)

# Calcola le medie e gli errori standard delle prestazioni
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plotta la learning curve
plt.figure(figsize=(8, 6))
plt.title('Learning Curve - Random Forest + GridSeardch')
plt.xlabel('Training examples')
plt.ylabel('Score')
plt.grid(True)
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.1,
                 color='b')
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.1,
                 color='r')
plt.plot(train_sizes, train_scores_mean, 'o-', color='g',
         label='Training score')
plt.plot(train_sizes, test_scores_mean, 'o-', color='r',
         label='Cross-validation score')
plt.legend(loc='best')
plt.show()
# Out:
# ****** ROC CURVE + AUC?: passo passo *******
# ____________________________________
# ****** VALORE DI AUC *******
# ____________________________________
# ****** VALORE DI AUC *******
# Micro-averaged One-vs-Rest ROC AUC score:
# 0.85
# ____________________________________
# ****** ROC CURVE: con metodo diretto *******
# ____________________________________
# ****** Precision recall: con metodo diretto *******

# %% [markdown]
# NON FUNZIONA BENE, QUINDI PROSEGUO SEMPLICEMNTE CON MULTILAYER + IMBALANCED NORMALE

# %%
ros = RandomUnderSampler(random_state=42)
X_res2, y_res2 = ros.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res2))
# Out:
# Resampled dataset shape Counter({0: 140, 1: 140, 2: 140, 3: 140, 4: 140, 5: 140, 6: 140, 7: 140})

# %%
# %%time
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV

k_fold = StratifiedKFold(n_splits=4)


# Definizione dei parametri da testare
parameters = {
    'hidden_layer_sizes': [(12, 23, 11), (23, 43, 32), (128, 64, 32)],
    'activation': ['logistic', 'relu'],
    'learning_rate': ['constant', 'invscaling', 'adaptive'],
    'tol': [1e-2, 1e-3, 1e-4],
    #'alpha': 10.0 ** -np.arange(1, 7),
    'momentum' : [ 0.1, 0.2, 0.3, 0.4]

}

# Creazione dell'oggetto della rete neurale
neural_net2 = MLPClassifier()

# Creazione dell'oggetto GridSearchCV
grid_search = GridSearchCV(neural_net2, parameters, cv=5)

# Addestramento della rete neurale con la grid search
grid_search.fit(X_res2, y_res2)

# Stampare i risultati
print("Best parameters set found on development set:")
print()
print(grid_search.best_params_)
print()
print("Grid scores on development set:")
print()
means = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, grid_search.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
          % (mean, std * 2, params))
print()

# Valutazione finale del modello
print("Best score achieved: %0.3f" % grid_search.best_score_)
print()
print("Detailed classification report:")
print()
print("The model is trained on the full development set.")
print("The scores are computed on the full evaluation set.")
print()
y_true, y_pred = y_test, grid_search.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...
# 0.521 (+/-0.034) for {'activation': 'logistic', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.001}
# 0.504 (+/-0.053) for {'activation': 'logistic', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.0001}
# 0.458 (+/-0.030) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.1, 'tol': 0.01}
# 0.454 (+/-0.035) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.1, 'tol': 0.001}
# 0.452 (+/-0.073) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.1, 'tol': 0.0001}
# 0.453 (+/-0.094) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.01}
# 0.455 (+/-0.085) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.001}
# 0.462 (+/-0.035) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.0001}
# 0.445 (+/-0.045) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.01}
# 0.451 (+/-0.080) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.001}
# 0.451 (+/-0.085) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.0001}
# 0.450 (+/-0.040) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.01}
# 0.470 (+/-0.051) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.001}
# 0.452 (+/-0.095) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.0001}
# 0.445 (+/-0.062) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.01}
# 0.473 (+/-0.040) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.001}
# 0.471 (+/-0.087) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.0001}
# 0.452 (+/-0.052) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.01}
# 0.446 (+/-0.042) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.001}
# 0.449 (+/-0.074) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.0001}
# 0.436 (+/-0.043) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.01}
# 0.463 (+/-0.080) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.001}
# 0.458 (+/-0.095) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.0001}
# 0.422 (+/-0.072) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.01}
# 0.465 (+/-0.088) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.001}
# 0.449 (+/-0.045) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.0001}
# 0.441 (+/-0.054) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.01}
# 0.438 (+/-0.087) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.001}
# 0.455 (+/-0.051) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.0001}
# 0.461 (+/-0.077) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.01}
# 0.437 (+/-0.078) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.001}
# 0.442 (+/-0.062) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.0001}
# 0.435 (+/-0.041) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.01}
# 0.451 (+/-0.105) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.001}
# 0.438 (+/-0.040) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.0001}
# 0.467 (+/-0.048) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.01}
# 0.459 (+/-0.053) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.001}
# 0.450 (+/-0.027) for {'activation': 'relu', 'hidden_layer_sizes': (12, 23, 11), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.0001}
# 0.477 (+/-0.042) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.1, 'tol': 0.01}
# 0.492 (+/-0.067) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.1, 'tol': 0.001}
# 0.475 (+/-0.057) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.1, 'tol': 0.0001}
# 0.479 (+/-0.079) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.01}
# 0.476 (+/-0.047) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.001}
# 0.493 (+/-0.103) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.0001}
# 0.471 (+/-0.051) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.01}
# 0.489 (+/-0.058) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.001}
# 0.487 (+/-0.066) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.0001}
# 0.476 (+/-0.043) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.01}
# 0.476 (+/-0.065) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.001}
# 0.461 (+/-0.035) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.0001}
# 0.454 (+/-0.059) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.01}
# 0.475 (+/-0.055) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.001}
# 0.485 (+/-0.074) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.0001}
# 0.506 (+/-0.028) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.01}
# 0.487 (+/-0.077) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.001}
# 0.476 (+/-0.049) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.0001}
# 0.486 (+/-0.030) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.01}
# 0.495 (+/-0.103) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.001}
# 0.476 (+/-0.044) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.0001}
# 0.480 (+/-0.047) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.01}
# 0.455 (+/-0.073) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.001}
# 0.482 (+/-0.084) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.0001}
# 0.467 (+/-0.054) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.01}
# 0.481 (+/-0.031) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.001}
# 0.469 (+/-0.083) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.0001}
# 0.497 (+/-0.067) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.01}
# 0.477 (+/-0.048) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.001}
# 0.472 (+/-0.048) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.0001}
# 0.476 (+/-0.078) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.01}
# 0.445 (+/-0.064) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.001}
# 0.485 (+/-0.067) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.0001}
# 0.483 (+/-0.059) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.01}
# 0.486 (+/-0.074) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.001}
# 0.487 (+/-0.055) for {'activation': 'relu', 'hidden_layer_sizes': (23, 43, 32), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.0001}
# 0.508 (+/-0.101) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.1, 'tol': 0.01}
# 0.490 (+/-0.090) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.1, 'tol': 0.001}
# 0.525 (+/-0.049) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.1, 'tol': 0.0001}
# 0.512 (+/-0.045) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.01}
# 0.528 (+/-0.043) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.001}
# 0.516 (+/-0.063) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.2, 'tol': 0.0001}
# 0.504 (+/-0.074) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.01}
# 0.512 (+/-0.047) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.001}
# 0.516 (+/-0.055) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.3, 'tol': 0.0001}
# 0.488 (+/-0.049) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.01}
# 0.499 (+/-0.095) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.001}
# 0.498 (+/-0.052) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'constant', 'momentum': 0.4, 'tol': 0.0001}
# 0.527 (+/-0.046) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.01}
# 0.503 (+/-0.069) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.001}
# 0.510 (+/-0.069) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.1, 'tol': 0.0001}
# 0.511 (+/-0.068) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.01}
# 0.511 (+/-0.052) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.001}
# 0.517 (+/-0.042) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.2, 'tol': 0.0001}
# 0.519 (+/-0.063) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.01}
# 0.513 (+/-0.057) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.001}
# 0.515 (+/-0.066) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.3, 'tol': 0.0001}
# 0.514 (+/-0.073) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.01}
# 0.520 (+/-0.056) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.001}
# 0.516 (+/-0.066) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'invscaling', 'momentum': 0.4, 'tol': 0.0001}
# 0.521 (+/-0.060) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.01}
# 0.502 (+/-0.047) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.001}
# 0.514 (+/-0.107) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.1, 'tol': 0.0001}
# 0.519 (+/-0.035) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.01}
# 0.488 (+/-0.017) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.001}
# 0.517 (+/-0.069) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.2, 'tol': 0.0001}
# 0.504 (+/-0.030) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.01}
# 0.512 (+/-0.077) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.001}
# 0.520 (+/-0.048) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.3, 'tol': 0.0001}
# 0.506 (+/-0.060) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.01}
# 0.504 (+/-0.076) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.001}
# 0.510 (+/-0.055) for {'activation': 'relu', 'hidden_layer_sizes': (128, 64, 32), 'learning_rate': 'adaptive', 'momentum': 0.4, 'tol': 0.0001}
#
# Best score achieved: 0.530
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
# CPU times: user 36min 17s, sys: 21min 39s, total: 57min 57s
# Wall time: 34min 40s
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.60      0.59        96
#            1       0.50      0.58      0.54        96
#            2       0.36      0.79      0.49        48
#            3       0.51      0.32      0.39        96
#            4       0.36      0.23      0.28        96
#            5       0.35      0.42      0.38        48
#            6       0.27      0.22      0.24        96
#            7       0.42      0.42      0.42        48
#
#     accuracy                           0.43       624
#    macro avg       0.42      0.45      0.42       624
# weighted avg       0.43      0.43      0.41       624

# %%
#PLOT ROC

y_score = neural_net2.predict_proba(X_test)
plot_res(y_pred, y_score, y_test)

#PLOT LEARNING CURVE

from sklearn.model_selection import learning_curve
# Calcola la learning curve
train_sizes, train_scores, test_scores = learning_curve(
    neural_net2, X_res2, y_res2, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)

# Calcola le medie e gli errori standard delle prestazioni
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plotta la learning curve
plt.figure(figsize=(8, 6))
plt.title('Learning Curve - Random Forest + GridSeardch')
plt.xlabel('Training examples')
plt.ylabel('Score')
plt.grid(True)
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.1,
                 color='b')
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.1,
                 color='r')
plt.plot(train_sizes, train_scores_mean, 'o-', color='b',
         label='Training score')
plt.plot(train_sizes, test_scores_mean, 'o-', color='r',
         label='Cross-validation score')
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-37-8f3bfecfd8b6> in <cell line: 3>()
#       1 #PLOT ROC
#       2
# ----> 3 y_score = neural_net2.predict_proba(X_test)
#       4 plot_res(y_pred, y_score, y_test)
#       5
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py in predict_proba(self, X)
#    1239             model, where classes are ordered as they are in `self.classes_`.
#    1240         """
# -> 1241         check_is_fitted(self)
#    1242         y_pred = self._forward_pass_fast(X)
#    1243
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1388
#    1389     if not fitted:
# -> 1390         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1391
#    1392
#
# NotFittedError: This MLPClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
clf4 = MLPClassifier(activation= 'relu', hidden_layer_sizes= (128, 64, 32), learning_rate= 'adaptive', momentum= 0.4, tol= 0.001)
#-hidden_layer_sizes=(128, 64, 32,) definisce la struttura della rete neurale artificiale: in questo caso,
#si tratta di una rete a tre strati, con il primo strato contenente 128 neuroni, il secondo strato contenente 64 neuroni e il terzo strato contenente 32 neuroni.
#-alpha=0.1 specifica la regolarizzazione L2, che viene utilizzata per prevenire l'overfitting dei dati di addestramento
#-learning_rate='adaptive' indica che la dimensione del passo di apprendimento deve essere adattata automaticamente in base alla convergenza del modello.
#-activation='tanh' specifica la funzione di attivazione del neurone, che viene utilizzata per introdurre non-linearità nella rete neurale.
#-early_stopping=True utilizza la tecnica di early stopping, ovvero interrompe l'addestramento del modello quando la performance sul set di validazione smette di migliorare.
#-momentum=0.9 indica il valore del momentum, che viene utilizzato per aggiornare i pesi del modello in modo da evitare minimi locali durante l'addestramento.
#-random_state=0 imposta il seed per la generazione di numeri casuali, in modo da rendere riproducibili i risultati.

clf4.fit(X_train, y_train)

y_pred=clf4.predict(X_test)
#Le righe successive addestrano il modello sulla base dei dati di addestramento X_train e y_train, utilizzando il metodo fit della classe MLPClassifier.
#Successivamente, il modello viene utilizzato per effettuare la predizione sui dati di test X_test utilizzando il metodo predict, e le predizioni risultanti vengono assegnate alla variabile y_pred

print("Accuracy %s", accuracy_score(y_test, y_pred))
print("F1-score %s", f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy %s 0.4583333333333333
# F1-score %s [0.60606061 0.51741294 0.42696629 0.48314607 0.48958333 0.25806452
#  0.33484163 0.27027027]
#               precision    recall  f1-score   support
#
#            0       0.52      0.73      0.61        96
#            1       0.50      0.54      0.52        96
#            2       0.46      0.40      0.43        48
#            3       0.52      0.45      0.48        96
#            4       0.49      0.49      0.49        96
#            5       0.57      0.17      0.26        48
#            6       0.30      0.39      0.33        96
#            7       0.38      0.21      0.27        48
#
#     accuracy                           0.46       624
#    macro avg       0.47      0.42      0.42       624
# weighted avg       0.47      0.46      0.45       624

# %% [markdown]
# VALUTIAMO L'OVERFITTING

# %%
#Con i codi ci qui sotto vado a calcolare l'accuracy sui dati di train e
#di test er vedere se abbiamo overfitting

clf4 = MLPClassifier(activation= 'relu', hidden_layer_sizes= (128, 64, 32), learning_rate= 'adaptive', momentum= 0.4, tol= 0.001)
clf.fit(X_train, y_train)
y_train_pred=clf4.predict(X_train)
train_acc=accuracy_score(y_train, y_train_pred)
print("Accuracy sul training", train_acc)
error_train=(1-train_acc)
print("L'errore sul train ottenuto equivale a: %", error_train)
print("______________________________________")

print()

clf4 = MLPClassifier(activation= 'relu', hidden_layer_sizes= (128, 64, 32), learning_rate= 'adaptive', momentum= 0.4, tol= 0.001)
clf4.fit(X_test, y_test)
y_test_pred=clf4.predict(X_test)
test_acc=accuracy_score(y_test, y_test_pred)
print("Accuracy sul test", test_acc)
error_test=(1-test_acc)
print("L'errore sul train ottenuto equivale a: %", error_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-32-3784b16c654a> in <cell line: 6>()
#       4 clf4 = MLPClassifier(activation= 'relu', hidden_layer_sizes= (128, 64, 32), learning_rate= 'adaptive', momentum= 0.4, tol= 0.001)
#       5 clf.fit(X_train, y_train)
# ----> 6 y_train_pred=clf4.predict(X_train)
#       7 train_acc=accuracy_score(y_train, y_train_pred)
#       8 print("Accuracy sul training", train_acc)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py in predict(self, X)
#    1153             The predicted classes.
#    1154         """
# -> 1155         check_is_fitted(self)
#    1156         return self._predict(X)
#    1157
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1388
#    1389     if not fitted:
# -> 1390         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1391
#    1392
#
# NotFittedError: This MLPClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
#PLOT ROC

y_score = clf.predict_proba(X_test)
plot_res(y_pred, y_score, y_test)

#PLOT LEARNING CURVE

from sklearn.model_selection import learning_curve
# Calcola la learning curve
train_sizes, train_scores, test_scores = learning_curve(
    clf4, X_train, y_train, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)

# Calcola le medie e gli errori standard delle prestazioni
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plotta la learning curve
plt.figure(figsize=(8, 6))
plt.title('Learning Curve - Random Forest + GridSeardch')
plt.xlabel('Training examples')
plt.ylabel('Score')
plt.grid(True)
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.1,
                 color='b')
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.1,
                 color='r')
plt.plot(train_sizes, train_scores_mean, 'o-', color='g',
         label='Training score')
plt.plot(train_sizes, test_scores_mean, 'o-', color='r',
         label='Cross-validation score')
plt.legend(loc='best')
plt.show()
# Out:
# ****** ROC CURVE + AUC?: passo passo *******
# ____________________________________
# ****** VALORE DI AUC *******
# ____________________________________
# ****** VALORE DI AUC *******
# Micro-averaged One-vs-Rest ROC AUC score:
# 0.86
# ____________________________________
# ****** ROC CURVE: con metodo diretto *******
# ____________________________________
# ****** Precision recall: con metodo diretto *******

# %% [markdown]
# ##KERAS DEEP NEURAL NETWORK

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import SGD
from sklearn.model_selection import GridSearchCV
from keras.regularizers import l2
from keras import backend as K

# %%
def f1(y_true, y_pred):
    prec = precision(y_true, y_pred)
    rec = recall(y_true, y_pred)

    return 2*((prec*rec)/(prec+rec+K.epsilon()))
def recall(y_true, y_pred):
    """Recall metric.

    Only computes a batch-wise average of recall.

    Computes the recall, a metric for multi-label classification of
    how many relevant items are selected.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall
def precision(y_true, y_pred):
    """Precision metric.

    Only computes a batch-wise average of precision.

    Computes the precision, a metric for multi-label classification of
    how many selected items are relevant.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %%
keras.backend.clear_session()

tf.random.set_seed(42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-f73f50bfc2a6> in <cell line: 3>()
#       1 keras.backend.clear_session()
#       2
# ----> 3 tf.random.set_seed(42)
#
# NameError: name 'tf' is not defined

# %%
n_classes = 8
def build_model():

    n_feature = X_train.shape[1]
    model = Sequential()
    model.add(Dense(128, input_dim=n_feature, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(n_classes, activation='softmax'))

    model.compile(loss='sparse_categorical_crossentropy',
                  optimizer="adam", metrics=['accuracy'])
    return model

# %%
def build_model_1(optimizer='SGD'):
    n_feature = X_train.shape[1]
    model = Sequential()
    model.add(Dense(32, input_dim=n_feature, activation='tanh'))
    model.add(Dense(32, activation='tanh'))
    model.add(Dense(32, activation='tanh'))
    model.add(Dense(32, activation='tanh'))
    model.add(Dense(32, activation='tanh'))
    model.add(Dense(32, activation='tanh'))
    model.add(Dense(32, activation='tanh'))
    model.add(Dense(32, activation='tanh'))
    # Linear
    model.add(Dense(8, activation='softmax'))
    model.compile(loss='SparseCategoricalCrossentropy', optimizer=optimizer, metrics=[f1])
    return model

# %%
def build_model_2(optimizer='SGD'):
    n_feature = X_train.shape[1]
    model = Sequential()
    model.add(Dense(128, input_dim=n_feature, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(32, activation='relu'))
    # Linear
    model.add(Dense(8, activation='softmax'))
    model.compile(loss='SparseCategoricalCrossentropy', optimizer=optimizer, metrics=[f1])
    return model

# %%
model1 = build_model_1()
history1 = model1.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=150, batch_size=10).history

# %%
model2 = build_model_2()
history2 = model2.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=10).history

# %%
from keras.utils.vis_utils import plot_model
plot_model(model1, to_file='model1.png', show_shapes=True, show_layer_names=True)

# %%
plot_model(model2, to_file='model2.png', show_shapes=True, show_layer_names=True)

# %%
model = KerasClassifier(build_fn=build_model)
model.fit(X_train, y_train, validation_split=0.2, epochs=300, batch_size=10)

y_pred = model.predict(X_test).astype(int)

y_scores = model.predict_proba(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))

print('F1-score %s' % f1_score(y_test, y_pred, average=None))

print(classification_report(y_test, y_pred))

# %%
model1 = KerasClassifier(build_fn=build_model_1)
model1.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=10)


y_pred = model1.predict(X_test).astype(int)

y_scores = model1.predict_proba(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))

print('F1-score %s' % f1_score(y_test, y_pred, average=None))

print(classification_report(y_test, y_pred))

# %%
model2 = KerasClassifier(build_fn=build_model_2)
model2.fit(X_train, y_train, validation_split=0.2, epochs=30, batch_size=10)


y_pred = model.predict(X_test).astype(int)

y_scores = model.predict_proba(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))

print('F1-score %s' % f1_score(y_test, y_pred, average=None))

print(classification_report(y_test, y_pred))

# %%
# %%time
model = KerasClassifier(build_fn=build_model_1)

# Definizione dei parametri per la grid search
param_grid = {
    'optimizer': ['adam', 'sgd'],
    'batch_size': [10, 20, -1],
    'epochs': [100, 200,300]
}

# Creazione dell'oggetto GridSearchCV
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=3)

# Addestramento del modello con la grid search
grid_result = grid.fit(X_train, y_train)

# Stampa dei risultati
print("Miglior set di parametri: ", grid_result.best_params_)
print("Miglior accuratezza media: ", grid_result.best_score_)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score

# Predizione sui dati di test utilizzando il miglior modello
y_pred = grid_result.best_estimator_.predict(X_test)

# Calcolo della matrice di confusione
cm = confusion_matrix(y_test, y_pred)

# Calcolo dell'accuratezza
accuracy = accuracy_score(y_test, y_pred)

# Calcolo del punteggio F1
#f1 = f1_score(y_test, y_pred)

# Plot della matrice di confusione
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title('Matrice di Confusione')
plt.xlabel('Etichetta Predetta')
plt.ylabel('Etichetta Reale')
plt.show()

# Stampa dell'accuratezza e del punteggio F1
print("Accuratezza: {:.2f}%".format(accuracy * 100))
print("Punteggio F1: {:.2f}".format(f1))

# %%
# %%time
model = KerasClassifier(build_fn=build_model_2)

# Definizione dei parametri per la grid search
param_grid = {
    'optimizer': ['adam', 'sgd'],
    'batch_size': [10, 20, -1],
    'epochs': [50,100,150]
}

# Creazione dell'oggetto GridSearchCV
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=3)

# Addestramento del modello con la grid search
grid_result = grid.fit(X_train, y_train)

# Stampa dei risultati
print("Miglior set di parametri: ", grid_result.best_params_)
print("Miglior accuratezza media: ", grid_result.best_score_)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score

# Predizione sui dati di test utilizzando il miglior modello
y_pred = grid_result.best_estimator_.predict(X_test)

# Calcolo della matrice di confusione
cm = confusion_matrix(y_test, y_pred)

# Calcolo dell'accuratezza
accuracy = accuracy_score(y_test, y_pred)

# Calcolo del punteggio F1
f1 = f1_score(y_test, y_pred)

# Plot della matrice di confusione
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title('Matrice di Confusione')
plt.xlabel('Etichetta Predetta')
plt.ylabel('Etichetta Reale')
plt.show()

# Stampa dell'accuratezza e del punteggio F1
print("Accuratezza: {:.2f}%".format(accuracy * 100))
print("Punteggio F1: {:.2f}".format(f1))

# %%
clf5 = KerasClassifier(build_fn=build_model_2, optimizer='sgd', batch_size= 10, epochs=100)

# %%
clf5.fit(X_train, y_train, epochs=100)

# %%
clf5.model_.summary()

# %%
y_pred = clf5.predict(X_test).astype(int)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# 20/20 [==============================] - 0s 1ms/step
# Accuracy 0.15384615384615385
# F1-score [0.26666667 0.         0.         0.         0.         0.
#  0.         0.        ]
#               precision    recall  f1-score   support
#
#            0       0.15      1.00      0.27        96
#            1       0.00      0.00      0.00        96
#            2       0.00      0.00      0.00        48
#            3       0.00      0.00      0.00        96
#            4       0.00      0.00      0.00        96
#            5       0.00      0.00      0.00        48
#            6       0.00      0.00      0.00        96
#            7       0.00      0.00      0.00        48
#
#     accuracy                           0.15       624
#    macro avg       0.02      0.12      0.03       624
# weighted avg       0.02      0.15      0.04       624
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plt.plot(history1['loss'], label='Loss 10 (batch_size)')
plt.plot(history2['loss'], label='Loss 50 (batch_size)')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy')
plt.legend()
plt.show()

# %%
plt.plot(history1['loss'], label='Train')
plt.plot(history1['val_loss'], label='Val')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy')
plt.legend()
plt.show()

# %%
plt.plot(history2['loss'], label='Train')
plt.plot(history2['val_loss'], label='Val')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy')
plt.legend()
plt.show()

# %%
#y_pred = model1.predict_classes(X_test)
#result_pred(y_test, y_pred)
y_pred = model1.predict(X_test).astype(int)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))


y_pred = model2.predict(X_test).astype(int)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

#plot_res(y_pred, y_score, y_test)
#y_pred = model2.predict_classes(X_test)
#result_pred(y_test, y_pred)
#plot_res(y_pred, y_score, y_test

# %% [markdown]
# ##VALUTAZIONE MODELLI

# %%
test_loss_1, test_acc_1 = model1.evaluate(X_test, y_test)
test_loss_2, test_acc_2 = model2.evaluate(X_test, y_test)

print('Loss %f, Accuracy %f' % (test_loss_1, test_acc_1))
print('Loss %f, Accuracy %f' % (test_loss_2, test_acc_2))

#Questa serie di codice calcola la loss e l'accuracy del modello model1 sui
# dati di test X_test e y_test, che rappresentano rispettivamente le feature
# e le etichette (o target) del dataset di test.
#La funzione evaluate() del modello model1 restituisce la loss e l'accuracy
#calcolate sui dati di test. Questi valori vengono quindi salvati nelle
#variabili test_loss_1 e test_acc_1, che vengono infine stampati a video.

# %%
plt.plot(history1['loss'])
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy')
plt.show()
plt.plot(history1['accuracy'])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# Questo codice plotta due grafici relativi alla storia dell'addestramento del modello di una rete neurale (neural network).
#
# Il primo grafico mostra la perdita (loss) del modello (in questo caso è usata la cross-entropy come funzione di perdita). L'asse x rappresenta il numero di epoche, ovvero il numero di volte in cui il modello è stato addestrato su tutto il set di dati di addestramento, mentre l'asse y rappresenta il valore della funzione di perdita per ogni epoca. L'obiettivo dell'addestramento del modello è di minimizzare la funzione di perdita, quindi il grafico dovrebbe mostrare una tendenza decrescente della perdita all'aumentare del numero di epoche.
#
# Il secondo grafico mostra l'accuratezza (accuracy) del modello, ovvero la percentuale di predizioni corrette rispetto al totale delle predizioni effettuate. Anche in questo caso, l'asse x rappresenta il numero di epoche e l'asse y rappresenta l'accuratezza del modello per ogni epoca. L'obiettivo dell'addestramento è di massimizzare l'accuratezza del modello, quindi il grafico dovrebbe mostrare una tendenza crescente dell'accuratezza all'aumentare del numero di epoche.

# %%
test_loss_1, test_acc_1 = model1.evaluate(X_test, y_test)
print('Loss %f, Accuracy %f' % (test_loss_1, test_acc_1))
#Questa serie di codice calcola la loss e l'accuracy del modello model1 sui
# dati di test X_test e y_test, che rappresentano rispettivamente le feature
# e le etichette (o target) del dataset di test.
#La funzione evaluate() del modello model1 restituisce la loss e l'accuracy
#calcolate sui dati di test. Questi valori vengono quindi salvati nelle
#variabili test_loss_1 e test_acc_1, che vengono infine stampati a video.

# %% [markdown]
# ##REGOLAZIONI

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
es = EarlyStopping(monitor='val_accuracy', patience=50, verbose=True)
mc = ModelCheckpoint('best_model_NOREG.h5', monitor='val_accuracy', save_best_only=True)

clf6 = KerasClassifier(build_model, callbacks=[es, mc])
# Out:
# <ipython-input-27-4cd95eb85397>:4: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   clf = KerasClassifier(build_model, callbacks=[es, mc])

# %%
clf6.fit(X_train, y_train, validation_split=0.2, epochs=500)
# Out:
# Epoch 1/500
# 46/46 [==============================] - 1s 5ms/step - loss: 1.8308 - accuracy: 0.2948 - val_loss: 1.6724 - val_accuracy: 0.3798
# Epoch 2/500
# 46/46 [==============================] - 0s 3ms/step - loss: 1.3713 - accuracy: 0.4945 - val_loss: 1.5691 - val_accuracy: 0.4235
# Epoch 3/500
# 46/46 [==============================] - 0s 2ms/step - loss: 1.1404 - accuracy: 0.5903 - val_loss: 1.6766 - val_accuracy: 0.3552
# Epoch 4/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.9739 - accuracy: 0.6546 - val_loss: 1.6325 - val_accuracy: 0.3962
# Epoch 5/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.8270 - accuracy: 0.7038 - val_loss: 1.7045 - val_accuracy: 0.4262
# Epoch 6/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.7190 - accuracy: 0.7709 - val_loss: 1.7728 - val_accuracy: 0.4071
# Epoch 7/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6112 - accuracy: 0.8174 - val_loss: 1.8656 - val_accuracy: 0.4016
# Epoch 8/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5214 - accuracy: 0.8523 - val_loss: 2.0770 - val_accuracy: 0.3798
# Epoch 9/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4612 - accuracy: 0.8632 - val_loss: 2.0983 - val_accuracy: 0.4016
# Epoch 10/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3859 - accuracy: 0.8988 - val_loss: 2.1859 - val_accuracy: 0.4016
# Epoch 11/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3333 - accuracy: 0.9193 - val_loss: 2.2925 - val_accuracy: 0.4126
# Epoch 12/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2980 - accuracy: 0.9275 - val_loss: 2.4067 - val_accuracy: 0.3634
# Epoch 13/500
# 46/46 [==============================] - 0s 3ms/step - loss: 0.2407 - accuracy: 0.9555 - val_loss: 2.4157 - val_accuracy: 0.4016
# Epoch 14/500
# 46/46 [==============================] - 0s 3ms/step - loss: 0.2090 - accuracy: 0.9576 - val_loss: 2.5701 - val_accuracy: 0.3880
# Epoch 15/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1798 - accuracy: 0.9706 - val_loss: 2.6684 - val_accuracy: 0.3934
# Epoch 16/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1503 - accuracy: 0.9815 - val_loss: 2.6863 - val_accuracy: 0.3989
# Epoch 17/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1265 - accuracy: 0.9836 - val_loss: 2.9660 - val_accuracy: 0.3716
# Epoch 18/500
# 46/46 [==============================] - 0s 4ms/step - loss: 0.1095 - accuracy: 0.9891 - val_loss: 2.8918 - val_accuracy: 0.3989
# Epoch 19/500
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0926 - accuracy: 0.9925 - val_loss: 3.0490 - val_accuracy: 0.3907
# Epoch 20/500
# 46/46 [==============================] - 0s 7ms/step - loss: 0.0788 - accuracy: 0.9945 - val_loss: 3.1260 - val_accuracy: 0.3907
# Epoch 21/500
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0677 - accuracy: 0.9973 - val_loss: 3.2422 - val_accuracy: 0.3907
# Epoch 22/500
# 46/46 [==============================] - 0s 7ms/step - loss: 0.0553 - accuracy: 0.9973 - val_loss: 3.3453 - val_accuracy: 0.3907
# Epoch 23/500
# 46/46 [==============================] - 0s 9ms/step - loss: 0.0506 - accuracy: 0.9973 - val_loss: 3.3901 - val_accuracy: 0.3907
# Epoch 24/500
# 46/46 [==============================] - 0s 7ms/step - loss: 0.0426 - accuracy: 0.9993 - val_loss: 3.5616 - val_accuracy: 0.3907
# Epoch 25/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0370 - accuracy: 1.0000 - val_loss: 3.5699 - val_accuracy: 0.4153
# Epoch 26/500
# 46/46 [==============================] - 0s 8ms/step - loss: 0.0323 - accuracy: 1.0000 - val_loss: 3.7476 - val_accuracy: 0.3989
# Epoch 27/500
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0287 - accuracy: 1.0000 - val_loss: 3.7247 - val_accuracy: 0.4016
# Epoch 28/500
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 3.7560 - val_accuracy: 0.4098
# Epoch 29/500
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 3.8767 - val_accuracy: 0.3907
# Epoch 30/500
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 3.9590 - val_accuracy: 0.4016
# Epoch 31/500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 4.0117 - val_accuracy: 0.3934
# Epoch 32/500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 4.0731 - val_accuracy: 0.3962
# Epoch 33/500
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 4.1100 - val_accuracy: 0.4016
# Epoch 34/500
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 4.2028 - val_accuracy: 0.3962
# Epoch 35/500
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 4.2461 - val_accuracy: 0.4016
# Epoch 36/500
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 4.3064 - val_accuracy: 0.3989
# Epoch 37/500
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 4.3338 - val_accuracy: 0.4071
# Epoch 38/500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 4.4336 - val_accuracy: 0.4071
# Epoch 39/500
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 4.4381 - val_accuracy: 0.3962
# Epoch 40/500
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 4.4644 - val_accuracy: 0.4016
# Epoch 41/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 4.5508 - val_accuracy: 0.3934
# Epoch 42/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 4.5408 - val_accuracy: 0.3962
# Epoch 43/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 4.6002 - val_accuracy: 0.4044
# Epoch 44/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 4.6417 - val_accuracy: 0.3962
# Epoch 45/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 4.7176 - val_accuracy: 0.4016
# Epoch 46/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 4.7044 - val_accuracy: 0.3989
# Epoch 47/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 4.7534 - val_accuracy: 0.3962
# Epoch 48/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 4.7803 - val_accuracy: 0.3989
# Epoch 49/500
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 4.8188 - val_accuracy: 0.3989
# Epoch 50/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 4.8709 - val_accuracy: 0.3962
# Epoch 51/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 4.9140 - val_accuracy: 0.3934
# Epoch 52/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 4.9934 - val_accuracy: 0.3934
# Epoch 53/500
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 4.9688 - val_accuracy: 0.3934
# Epoch 54/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 5.0124 - val_accuracy: 0.4016
# Epoch 55/500
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 5.0492 - val_accuracy: 0.4016
# Epoch 55: early stopping

# %%
y_pred = clf6.predict(X_test).astype(int)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# 20/20 [==============================] - 0s 965us/step
# Accuracy 0.453525641025641
# F1-score [0.63779528 0.47674419 0.41904762 0.48677249 0.38823529 0.31168831
#  0.4        0.13114754]
#               precision    recall  f1-score   support
#
#            0       0.51      0.84      0.64        96
#            1       0.54      0.43      0.48        96
#            2       0.39      0.46      0.42        48
#            3       0.49      0.48      0.49        96
#            4       0.45      0.34      0.39        96
#            5       0.41      0.25      0.31        48
#            6       0.35      0.46      0.40        96
#            7       0.31      0.08      0.13        48
#
#     accuracy                           0.45       624
#    macro avg       0.43      0.42      0.41       624
# weighted avg       0.45      0.45      0.43       624

# %% [markdown]
# ##L2

# %%
from keras.regularizers import l2, l1

def build_L2_model():
    model = Sequential()

    n_feature = X_train.shape[1]
    h_dim=100
    model.add(Dense(h_dim, activation='relu',
                    input_shape=(n_feature,), kernel_regularizer=l2(0.001)))
    model.add(Dense(h_dim, activation='relu'))
    model.add(Dense(h_dim, activation='relu'))
    model.add(Dense(h_dim, activation='relu'))
    model.add(Dense(n_classes))

    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# %%
mc = ModelCheckpoint('best_model_L2.h5', monitor='val_accuracy', save_best_only=True)

L2_model = KerasClassifier(build_L2_model, callbacks=[es,mc])
L2_model.fit(X_train, y_train, validation_split=0.2, epochs=500)
# Out:
# Epoch 1/500
# <ipython-input-33-0858c7534878>:3: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   L2_model = KerasClassifier(build_L2_model, callbacks=[es,mc])
# 46/46 [==============================] - 1s 6ms/step - loss: 3.2160 - accuracy: 0.1580 - val_loss: 2.2013 - val_accuracy: 0.1639
# Epoch 2/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1982 - accuracy: 0.1648 - val_loss: 2.2007 - val_accuracy: 0.1667
# Epoch 3/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1975 - accuracy: 0.1635 - val_loss: 2.1999 - val_accuracy: 0.1639
# Epoch 4/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1967 - accuracy: 0.1628 - val_loss: 2.1990 - val_accuracy: 0.1639
# Epoch 5/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1957 - accuracy: 0.1642 - val_loss: 2.1980 - val_accuracy: 0.1639
# Epoch 6/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1947 - accuracy: 0.1642 - val_loss: 2.1970 - val_accuracy: 0.1639
# Epoch 7/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1936 - accuracy: 0.1662 - val_loss: 2.1959 - val_accuracy: 0.1639
# Epoch 8/500
# 46/46 [==============================] - 0s 2ms/step - loss: 2.1925 - accuracy: 0.1662 - val_loss: 2.1947 - val_accuracy: 0.1639
# Epoch 9/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1913 - accuracy: 0.1669 - val_loss: 2.1935 - val_accuracy: 0.1639
# Epoch 10/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1901 - accuracy: 0.1669 - val_loss: 2.1923 - val_accuracy: 0.1639
# Epoch 11/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1888 - accuracy: 0.1669 - val_loss: 2.1910 - val_accuracy: 0.1639
# Epoch 12/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1876 - accuracy: 0.1676 - val_loss: 2.1898 - val_accuracy: 0.1639
# Epoch 13/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1863 - accuracy: 0.1683 - val_loss: 2.1885 - val_accuracy: 0.1667
# Epoch 14/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1850 - accuracy: 0.1683 - val_loss: 2.1872 - val_accuracy: 0.1639
# Epoch 15/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1837 - accuracy: 0.1689 - val_loss: 2.1859 - val_accuracy: 0.1639
# Epoch 16/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1824 - accuracy: 0.1683 - val_loss: 2.1846 - val_accuracy: 0.1612
# Epoch 17/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1811 - accuracy: 0.1676 - val_loss: 2.1832 - val_accuracy: 0.1612
# Epoch 18/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1798 - accuracy: 0.1676 - val_loss: 2.1819 - val_accuracy: 0.1612
# Epoch 19/500
# 46/46 [==============================] - 0s 2ms/step - loss: 2.1784 - accuracy: 0.1683 - val_loss: 2.1806 - val_accuracy: 0.1612
# Epoch 20/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1771 - accuracy: 0.1662 - val_loss: 2.1793 - val_accuracy: 0.1639
# Epoch 21/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1758 - accuracy: 0.1676 - val_loss: 2.1779 - val_accuracy: 0.1639
# Epoch 22/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1745 - accuracy: 0.1669 - val_loss: 2.1766 - val_accuracy: 0.1639
# Epoch 23/500
# 46/46 [==============================] - 0s 5ms/step - loss: 2.1731 - accuracy: 0.1669 - val_loss: 2.1753 - val_accuracy: 0.1639
# Epoch 24/500
# 46/46 [==============================] - 0s 4ms/step - loss: 2.1718 - accuracy: 0.1662 - val_loss: 2.1740 - val_accuracy: 0.1667
# Epoch 25/500
# 46/46 [==============================] - 0s 2ms/step - loss: 2.1705 - accuracy: 0.1655 - val_loss: 2.1727 - val_accuracy: 0.1639
# Epoch 26/500
# 46/46 [==============================] - 0s 2ms/step - loss: 2.1692 - accuracy: 0.1642 - val_loss: 2.1714 - val_accuracy: 0.1639
# Epoch 27/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1679 - accuracy: 0.1642 - val_loss: 2.1701 - val_accuracy: 0.1639
# Epoch 28/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1666 - accuracy: 0.1655 - val_loss: 2.1688 - val_accuracy: 0.1612
# Epoch 29/500
# 46/46 [==============================] - 0s 2ms/step - loss: 2.1653 - accuracy: 0.1655 - val_loss: 2.1675 - val_accuracy: 0.1612
# Epoch 30/500
# 46/46 [==============================] - 0s 2ms/step - loss: 2.1641 - accuracy: 0.1635 - val_loss: 2.1663 - val_accuracy: 0.1612
# Epoch 31/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1628 - accuracy: 0.1642 - val_loss: 2.1650 - val_accuracy: 0.1612
# Epoch 32/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1616 - accuracy: 0.1635 - val_loss: 2.1638 - val_accuracy: 0.1585
# Epoch 33/500
# 46/46 [==============================] - 0s 2ms/step - loss: 2.1603 - accuracy: 0.1628 - val_loss: 2.1626 - val_accuracy: 0.1585
# Epoch 34/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1591 - accuracy: 0.1635 - val_loss: 2.1613 - val_accuracy: 0.1612
# Epoch 35/500
# 46/46 [==============================] - 0s 4ms/step - loss: 2.1579 - accuracy: 0.1648 - val_loss: 2.1601 - val_accuracy: 0.1612
# Epoch 36/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1567 - accuracy: 0.1655 - val_loss: 2.1589 - val_accuracy: 0.1612
# Epoch 37/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1555 - accuracy: 0.1648 - val_loss: 2.1577 - val_accuracy: 0.1612
# Epoch 38/500
# 46/46 [==============================] - 0s 4ms/step - loss: 2.1543 - accuracy: 0.1662 - val_loss: 2.1566 - val_accuracy: 0.1585
# Epoch 39/500
# 46/46 [==============================] - 0s 4ms/step - loss: 2.1532 - accuracy: 0.1655 - val_loss: 2.1554 - val_accuracy: 0.1585
# Epoch 40/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1520 - accuracy: 0.1648 - val_loss: 2.1543 - val_accuracy: 0.1585
# Epoch 41/500
# 46/46 [==============================] - 0s 4ms/step - loss: 2.1509 - accuracy: 0.1648 - val_loss: 2.1531 - val_accuracy: 0.1585
# Epoch 42/500
# 46/46 [==============================] - 0s 4ms/step - loss: 2.1497 - accuracy: 0.1655 - val_loss: 2.1520 - val_accuracy: 0.1557
# Epoch 43/500
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1486 - accuracy: 0.1669 - val_loss: 2.1509 - val_accuracy: 0.1557
# Epoch 44/500
# 46/46 [==============================] - 0s 5ms/step - loss: 2.1475 - accuracy: 0.1676 - val_loss: 2.1498 - val_accuracy: 0.1557
# Epoch 45/500
# 46/46 [==============================] - 0s 6ms/step - loss: 2.1464 - accuracy: 0.1676 - val_loss: 2.1487 - val_accuracy: 0.1585
# Epoch 46/500
# 46/46 [==============================] - 0s 5ms/step - loss: 2.1453 - accuracy: 0.1696 - val_loss: 2.1476 - val_accuracy: 0.1612
# Epoch 47/500
# 46/46 [==============================] - 0s 5ms/step - loss: 2.1443 - accuracy: 0.1689 - val_loss: 2.1466 - val_accuracy: 0.1612
# Epoch 48/500
# 46/46 [==============================] - 0s 7ms/step - loss: 2.1432 - accuracy: 0.1703 - val_loss: 2.1455 - val_accuracy: 0.1639
# Epoch 49/500
# 46/46 [==============================] - 0s 4ms/step - loss: 2.1422 - accuracy: 0.1683 - val_loss: 2.1445 - val_accuracy: 0.1639
# Epoch 50/500
# 46/46 [==============================] - 0s 4ms/step - loss: 2.1411 - accuracy: 0.1710 - val_loss: 2.1434 - val_accuracy: 0.1612
# Epoch 51/500
# 46/46 [==============================] - 0s 5ms/step - loss: 2.1469 - accuracy: 0.1341 - val_loss: 2.1453 - val_accuracy: 0.0874
# Epoch 52/500
# 46/46 [==============================] - 0s 4ms/step - loss: 2.1453 - accuracy: 0.0766 - val_loss: 2.1450 - val_accuracy: 0.0874
# Epoch 52: early stopping

# %%
y_pred = L2_model.predict(X_test).astype(int)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# 20/20 [==============================] - 0s 1ms/step
# Accuracy 0.07692307692307693
# F1-score [0.         0.         0.14285714 0.         0.         0.
#  0.         0.        ]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        96
#            1       0.00      0.00      0.00        96
#            2       0.08      1.00      0.14        48
#            3       0.00      0.00      0.00        96
#            4       0.00      0.00      0.00        96
#            5       0.00      0.00      0.00        48
#            6       0.00      0.00      0.00        96
#            7       0.00      0.00      0.00        48
#
#     accuracy                           0.08       624
#    macro avg       0.01      0.12      0.02       624
# weighted avg       0.01      0.08      0.01       624
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #SKLEARN WRAPPER

# %%
# !pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.11.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras) (23.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (3.1.0)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.11.0

# %%
from scikeras.wrappers import KerasClassifier

# %% [markdown]
# KerasClassifier è un wrapper che permette di utilizzare modelli di rete neurale creati con Keras all'interno di altre librerie come Scikit-learn. In pratica, permette di usare modelli Keras come se fossero degli estimatori Scikit-learn, con tutti i vantaggi che ne derivano, come ad esempio la possibilità di utilizzare il metodo fit() per addestrare il modello e il metodo predict() per effettuare predizioni su nuovi dati.
#
# KerasClassifier permette inoltre di specificare alcune opzioni come la funzione di perdita, l'ottimizzatore e il numero di epoche di addestramento.
#
# (((In programmazione, un wrapper (letteralmente "incarto" o "avvolgimento") è una funzione o un oggetto che copre o incapsula un'altra funzione o oggetto, fornendo un'interfaccia più semplice o unificata per l'utilizzo di tale funzione o oggetto. Un wrapper può essere utilizzato per adattare una funzione o un oggetto alle esigenze di un particolare contesto o per semplificare l'utilizzo di una funzione o un oggetto complesso. In pratica, un wrapper è una sorta di involucro che fornisce un'interfaccia più comoda per accedere a funzionalità più complesse o per adattare tali funzionalità a un particolare contesto o scopo.)))

# %%
clf7 = KerasClassifier(build_fn=build_model)

# %% [markdown]
# si utilizza la classe KerasClassifier di scikit-learn per creare un'istanza di un classificatore basato su una rete neurale creata con la libreria Keras. La funzione build_model() viene passata come argomento alla classe KerasClassifier tramite il parametro build_fn. Questo significa che la funzione build_model() viene chiamata per creare la struttura della rete neurale del classificatore. In altre parole, la classe KerasClassifier fornisce un'interfaccia tra Keras e scikit-learn, permettendo di utilizzare la potenza delle reti neurali in un ambiente di machine learning più ampio.

# %%
clf7.fit(X_train, y_train, epochs=200)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 58/58 [==============================] - 1s 2ms/step - loss: 1.7890 - accuracy: 0.3167
# Epoch 2/200
# 58/58 [==============================] - 0s 1ms/step - loss: 1.3365 - accuracy: 0.4951
# Epoch 3/200
# 58/58 [==============================] - 0s 2ms/step - loss: 1.1118 - accuracy: 0.6023
# Epoch 4/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.9556 - accuracy: 0.6532
# Epoch 5/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.8191 - accuracy: 0.7062
# Epoch 6/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.7205 - accuracy: 0.7505
# Epoch 7/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.6275 - accuracy: 0.7839
# Epoch 8/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.5583 - accuracy: 0.8178
# Epoch 9/200
# 58/58 [==============================] - 0s 1ms/step - loss: 0.4665 - accuracy: 0.8665
# Epoch 10/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.4078 - accuracy: 0.8720
# Epoch 11/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.3538 - accuracy: 0.9081
# Epoch 12/200
# 58/58 [==============================] - 0s 1ms/step - loss: 0.3091 - accuracy: 0.9234
# Epoch 13/200
# 58/58 [==============================] - 0s 1ms/step - loss: 0.2534 - accuracy: 0.9442
# Epoch 14/200
# 58/58 [==============================] - 0s 1ms/step - loss: 0.2254 - accuracy: 0.9535
# Epoch 15/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.1921 - accuracy: 0.9623
# Epoch 16/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.1910 - accuracy: 0.9557
# Epoch 17/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.1446 - accuracy: 0.9803
# Epoch 18/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.1268 - accuracy: 0.9814
# Epoch 19/200
# 58/58 [==============================] - 0s 1ms/step - loss: 0.1083 - accuracy: 0.9863
# Epoch 20/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0975 - accuracy: 0.9907
# Epoch 21/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.9918
# Epoch 22/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0709 - accuracy: 0.9934
# Epoch 23/200
# 58/58 [==============================] - 0s 1ms/step - loss: 0.0641 - accuracy: 0.9929
# Epoch 24/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0528 - accuracy: 0.9984
# Epoch 25/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0458 - accuracy: 0.9989
# Epoch 26/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0430 - accuracy: 0.9973
# Epoch 27/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0614 - accuracy: 0.9907
# Epoch 28/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0464 - accuracy: 0.9951
# Epoch 29/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0284 - accuracy: 0.9995
# Epoch 30/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 31/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 32/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 33/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 34/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 35/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9989
# Epoch 36/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 37/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 38/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 39/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 40/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 41/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 42/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 43/200
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 44/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 45/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 46/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 47/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 48/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 49/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 50/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 51/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 52/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 53/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 54/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 55/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 56/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 57/200
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 58/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 59/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 60/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 61/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 62/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 63/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 64/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 65/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 66/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 67/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 68/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 69/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 70/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 71/200
# 58/58 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 72/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 73/200
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 74/200
# 58/58 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 75/200
# 58/58 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 76/200
# 58/58 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 77/200
# 58/58 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 78/200
# 58/58 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 79/200
# 58/58 [==============================] - 0s 5ms/step - loss: 9.6178e-04 - accuracy: 1.0000
# Epoch 80/200
# 58/58 [==============================] - 0s 6ms/step - loss: 9.2338e-04 - accuracy: 1.0000
# Epoch 81/200
# 58/58 [==============================] - 0s 3ms/step - loss: 8.9946e-04 - accuracy: 1.0000
# Epoch 82/200
# 58/58 [==============================] - 0s 2ms/step - loss: 8.4754e-04 - accuracy: 1.0000
# Epoch 83/200
# 58/58 [==============================] - 0s 6ms/step - loss: 8.0643e-04 - accuracy: 1.0000
# Epoch 84/200
# 58/58 [==============================] - 0s 3ms/step - loss: 7.9326e-04 - accuracy: 1.0000
# Epoch 85/200
# 58/58 [==============================] - 0s 3ms/step - loss: 7.4310e-04 - accuracy: 1.0000
# Epoch 86/200
# 58/58 [==============================] - 0s 2ms/step - loss: 7.2251e-04 - accuracy: 1.0000
# Epoch 87/200
# 58/58 [==============================] - 0s 2ms/step - loss: 6.8647e-04 - accuracy: 1.0000
# Epoch 88/200
# 58/58 [==============================] - 0s 4ms/step - loss: 6.6857e-04 - accuracy: 1.0000
# Epoch 89/200
# 58/58 [==============================] - 0s 4ms/step - loss: 6.3690e-04 - accuracy: 1.0000
# Epoch 90/200
# 58/58 [==============================] - 0s 5ms/step - loss: 6.0893e-04 - accuracy: 1.0000
# Epoch 91/200
# 58/58 [==============================] - 0s 3ms/step - loss: 5.7836e-04 - accuracy: 1.0000
# Epoch 92/200
# 58/58 [==============================] - 0s 4ms/step - loss: 5.6481e-04 - accuracy: 1.0000
# Epoch 93/200
# 58/58 [==============================] - 0s 3ms/step - loss: 5.3476e-04 - accuracy: 1.0000
# Epoch 94/200
# 58/58 [==============================] - 0s 4ms/step - loss: 5.1757e-04 - accuracy: 1.0000
# Epoch 95/200
# 58/58 [==============================] - 0s 5ms/step - loss: 5.1904e-04 - accuracy: 1.0000
# Epoch 96/200
# 58/58 [==============================] - 0s 4ms/step - loss: 4.7784e-04 - accuracy: 1.0000
# Epoch 97/200
# 58/58 [==============================] - 0s 3ms/step - loss: 4.6033e-04 - accuracy: 1.0000
# Epoch 98/200
# 58/58 [==============================] - 0s 5ms/step - loss: 4.3719e-04 - accuracy: 1.0000
# Epoch 99/200
# 58/58 [==============================] - 0s 4ms/step - loss: 4.2075e-04 - accuracy: 1.0000
# Epoch 100/200
# 58/58 [==============================] - 0s 4ms/step - loss: 4.0476e-04 - accuracy: 1.0000
# Epoch 101/200
# 58/58 [==============================] - 0s 5ms/step - loss: 3.9129e-04 - accuracy: 1.0000
# Epoch 102/200
# 58/58 [==============================] - 0s 4ms/step - loss: 3.8301e-04 - accuracy: 1.0000
# Epoch 103/200
# 58/58 [==============================] - 0s 5ms/step - loss: 3.5925e-04 - accuracy: 1.0000
# Epoch 104/200
# 58/58 [==============================] - 0s 4ms/step - loss: 3.5444e-04 - accuracy: 1.0000
# Epoch 105/200
# 58/58 [==============================] - 0s 4ms/step - loss: 3.3708e-04 - accuracy: 1.0000
# Epoch 106/200
# 58/58 [==============================] - 0s 6ms/step - loss: 3.2181e-04 - accuracy: 1.0000
# Epoch 107/200
# 58/58 [==============================] - 0s 4ms/step - loss: 3.0974e-04 - accuracy: 1.0000
# Epoch 108/200
# 58/58 [==============================] - 0s 3ms/step - loss: 2.9603e-04 - accuracy: 1.0000
# Epoch 109/200
# 58/58 [==============================] - 0s 4ms/step - loss: 2.8692e-04 - accuracy: 1.0000
# Epoch 110/200
# 58/58 [==============================] - 0s 5ms/step - loss: 2.7751e-04 - accuracy: 1.0000
# Epoch 111/200
# 58/58 [==============================] - 0s 4ms/step - loss: 2.6608e-04 - accuracy: 1.0000
# Epoch 112/200
# 58/58 [==============================] - 0s 3ms/step - loss: 2.5536e-04 - accuracy: 1.0000
# Epoch 113/200
# 58/58 [==============================] - 0s 4ms/step - loss: 2.5674e-04 - accuracy: 1.0000
# Epoch 114/200
# 58/58 [==============================] - 0s 4ms/step - loss: 2.3773e-04 - accuracy: 1.0000
# Epoch 115/200
# 58/58 [==============================] - 0s 3ms/step - loss: 2.2920e-04 - accuracy: 1.0000
# Epoch 116/200
# 58/58 [==============================] - 0s 4ms/step - loss: 2.2023e-04 - accuracy: 1.0000
# Epoch 117/200
# 58/58 [==============================] - 0s 4ms/step - loss: 2.1421e-04 - accuracy: 1.0000
# Epoch 118/200
# 58/58 [==============================] - 0s 4ms/step - loss: 2.0763e-04 - accuracy: 1.0000
# Epoch 119/200
# 58/58 [==============================] - 0s 6ms/step - loss: 1.9618e-04 - accuracy: 1.0000
# Epoch 120/200
# 58/58 [==============================] - 0s 6ms/step - loss: 1.9027e-04 - accuracy: 1.0000
# Epoch 121/200
# 58/58 [==============================] - 0s 3ms/step - loss: 1.8455e-04 - accuracy: 1.0000
# Epoch 122/200
# 58/58 [==============================] - 0s 8ms/step - loss: 1.7678e-04 - accuracy: 1.0000
# Epoch 123/200
# 58/58 [==============================] - 0s 6ms/step - loss: 1.7139e-04 - accuracy: 1.0000
# Epoch 124/200
# 58/58 [==============================] - 1s 10ms/step - loss: 1.6375e-04 - accuracy: 1.0000
# Epoch 125/200
# 58/58 [==============================] - 1s 9ms/step - loss: 1.6043e-04 - accuracy: 1.0000
# Epoch 126/200
# 58/58 [==============================] - 0s 7ms/step - loss: 1.5416e-04 - accuracy: 1.0000
# Epoch 127/200
# 58/58 [==============================] - 0s 3ms/step - loss: 1.4664e-04 - accuracy: 1.0000
# Epoch 128/200
# 58/58 [==============================] - 0s 4ms/step - loss: 1.4068e-04 - accuracy: 1.0000
# Epoch 129/200
# 58/58 [==============================] - 0s 4ms/step - loss: 1.3696e-04 - accuracy: 1.0000
# Epoch 130/200
# 58/58 [==============================] - 0s 4ms/step - loss: 1.3191e-04 - accuracy: 1.0000
# Epoch 131/200
# 58/58 [==============================] - 0s 5ms/step - loss: 1.2669e-04 - accuracy: 1.0000
# Epoch 132/200
# 58/58 [==============================] - 0s 5ms/step - loss: 1.2410e-04 - accuracy: 1.0000
# Epoch 133/200
# 58/58 [==============================] - 0s 5ms/step - loss: 1.1840e-04 - accuracy: 1.0000
# Epoch 134/200
# 58/58 [==============================] - 0s 4ms/step - loss: 1.1360e-04 - accuracy: 1.0000
# Epoch 135/200
# 58/58 [==============================] - 0s 4ms/step - loss: 1.1066e-04 - accuracy: 1.0000
# Epoch 136/200
# 58/58 [==============================] - 0s 6ms/step - loss: 1.0674e-04 - accuracy: 1.0000
# Epoch 137/200
# 58/58 [==============================] - 0s 5ms/step - loss: 1.0212e-04 - accuracy: 1.0000
# Epoch 138/200
# 58/58 [==============================] - 0s 3ms/step - loss: 9.9558e-05 - accuracy: 1.0000
# Epoch 139/200
# 58/58 [==============================] - 0s 5ms/step - loss: 9.5287e-05 - accuracy: 1.0000
# Epoch 140/200
# 58/58 [==============================] - 0s 6ms/step - loss: 9.1395e-05 - accuracy: 1.0000
# Epoch 141/200
# 58/58 [==============================] - 0s 6ms/step - loss: 8.8665e-05 - accuracy: 1.0000
# Epoch 142/200
# 58/58 [==============================] - 0s 5ms/step - loss: 8.7219e-05 - accuracy: 1.0000
# Epoch 143/200
# 58/58 [==============================] - 0s 4ms/step - loss: 8.2805e-05 - accuracy: 1.0000
# Epoch 144/200
# 58/58 [==============================] - 0s 5ms/step - loss: 7.9684e-05 - accuracy: 1.0000
# Epoch 145/200
# 58/58 [==============================] - 0s 4ms/step - loss: 7.6636e-05 - accuracy: 1.0000
# Epoch 146/200
# 58/58 [==============================] - 0s 4ms/step - loss: 7.3909e-05 - accuracy: 1.0000
# Epoch 147/200
# 58/58 [==============================] - 0s 6ms/step - loss: 7.2305e-05 - accuracy: 1.0000
# Epoch 148/200
# 58/58 [==============================] - 0s 4ms/step - loss: 7.0209e-05 - accuracy: 1.0000
# Epoch 149/200
# 58/58 [==============================] - 0s 5ms/step - loss: 6.6855e-05 - accuracy: 1.0000
# Epoch 150/200
# 58/58 [==============================] - 0s 6ms/step - loss: 6.4632e-05 - accuracy: 1.0000
# Epoch 151/200
# 58/58 [==============================] - 0s 3ms/step - loss: 6.2539e-05 - accuracy: 1.0000
# Epoch 152/200
# 58/58 [==============================] - 0s 5ms/step - loss: 6.0292e-05 - accuracy: 1.0000
# Epoch 153/200
# 58/58 [==============================] - 0s 5ms/step - loss: 5.8402e-05 - accuracy: 1.0000
# Epoch 154/200
# 58/58 [==============================] - 0s 4ms/step - loss: 5.5817e-05 - accuracy: 1.0000
# Epoch 155/200
# 58/58 [==============================] - 0s 3ms/step - loss: 5.3720e-05 - accuracy: 1.0000
# Epoch 156/200
# 58/58 [==============================] - 0s 3ms/step - loss: 5.1640e-05 - accuracy: 1.0000
# Epoch 157/200
# 58/58 [==============================] - 0s 2ms/step - loss: 5.0507e-05 - accuracy: 1.0000
# Epoch 158/200
# 58/58 [==============================] - 0s 4ms/step - loss: 4.8563e-05 - accuracy: 1.0000
# Epoch 159/200
# 58/58 [==============================] - 0s 6ms/step - loss: 4.6957e-05 - accuracy: 1.0000
# Epoch 160/200
# 58/58 [==============================] - 0s 5ms/step - loss: 4.5529e-05 - accuracy: 1.0000
# Epoch 161/200
# 58/58 [==============================] - 0s 3ms/step - loss: 4.5739e-05 - accuracy: 1.0000
# Epoch 162/200
# 58/58 [==============================] - 0s 4ms/step - loss: 4.2290e-05 - accuracy: 1.0000
# Epoch 163/200
# 58/58 [==============================] - 0s 5ms/step - loss: 4.0873e-05 - accuracy: 1.0000
# Epoch 164/200
# 58/58 [==============================] - 0s 7ms/step - loss: 3.9786e-05 - accuracy: 1.0000
# Epoch 165/200
# 58/58 [==============================] - 0s 8ms/step - loss: 3.8251e-05 - accuracy: 1.0000
# Epoch 166/200
# 58/58 [==============================] - 1s 11ms/step - loss: 3.6729e-05 - accuracy: 1.0000
# Epoch 167/200
# 58/58 [==============================] - 0s 7ms/step - loss: 3.5853e-05 - accuracy: 1.0000
# Epoch 168/200
# 58/58 [==============================] - 0s 7ms/step - loss: 3.4191e-05 - accuracy: 1.0000
# Epoch 169/200
# 58/58 [==============================] - 0s 4ms/step - loss: 3.3342e-05 - accuracy: 1.0000
# Epoch 170/200
# 58/58 [==============================] - 0s 4ms/step - loss: 3.2320e-05 - accuracy: 1.0000
# Epoch 171/200
# 58/58 [==============================] - 0s 4ms/step - loss: 3.0856e-05 - accuracy: 1.0000
# Epoch 172/200
# 58/58 [==============================] - 0s 5ms/step - loss: 2.9992e-05 - accuracy: 1.0000
# Epoch 173/200
# 58/58 [==============================] - 0s 4ms/step - loss: 2.8906e-05 - accuracy: 1.0000
# Epoch 174/200
# 58/58 [==============================] - 0s 3ms/step - loss: 2.7996e-05 - accuracy: 1.0000
# Epoch 175/200
# 58/58 [==============================] - 0s 3ms/step - loss: 2.7382e-05 - accuracy: 1.0000
# Epoch 176/200
# 58/58 [==============================] - 0s 6ms/step - loss: 2.6069e-05 - accuracy: 1.0000
# Epoch 177/200
# 58/58 [==============================] - 0s 6ms/step - loss: 2.5182e-05 - accuracy: 1.0000
# Epoch 178/200
# 58/58 [==============================] - 0s 3ms/step - loss: 2.4954e-05 - accuracy: 1.0000
# Epoch 179/200
# 58/58 [==============================] - 0s 3ms/step - loss: 2.3693e-05 - accuracy: 1.0000
# Epoch 180/200
# 58/58 [==============================] - 0s 3ms/step - loss: 2.2968e-05 - accuracy: 1.0000
# Epoch 181/200
# 58/58 [==============================] - 0s 5ms/step - loss: 2.2063e-05 - accuracy: 1.0000
# Epoch 182/200
# 58/58 [==============================] - 0s 4ms/step - loss: 2.1240e-05 - accuracy: 1.0000
# Epoch 183/200
# 58/58 [==============================] - 0s 4ms/step - loss: 2.0621e-05 - accuracy: 1.0000
# Epoch 184/200
# 58/58 [==============================] - 0s 4ms/step - loss: 2.0067e-05 - accuracy: 1.0000
# Epoch 185/200
# 58/58 [==============================] - 0s 3ms/step - loss: 1.9096e-05 - accuracy: 1.0000
# Epoch 186/200
# 58/58 [==============================] - 0s 3ms/step - loss: 1.8783e-05 - accuracy: 1.0000
# Epoch 187/200
# 58/58 [==============================] - 0s 6ms/step - loss: 1.7977e-05 - accuracy: 1.0000
# Epoch 188/200
# 58/58 [==============================] - 0s 6ms/step - loss: 1.7388e-05 - accuracy: 1.0000
# Epoch 189/200
# 58/58 [==============================] - 0s 5ms/step - loss: 1.6829e-05 - accuracy: 1.0000
# Epoch 190/200
# 58/58 [==============================] - 0s 3ms/step - loss: 1.6613e-05 - accuracy: 1.0000
# Epoch 191/200
# 58/58 [==============================] - 0s 2ms/step - loss: 1.5613e-05 - accuracy: 1.0000
# Epoch 192/200
# 58/58 [==============================] - 0s 2ms/step - loss: 1.5108e-05 - accuracy: 1.0000
# Epoch 193/200
# 58/58 [==============================] - 0s 2ms/step - loss: 1.4868e-05 - accuracy: 1.0000
# Epoch 194/200
# 58/58 [==============================] - 0s 3ms/step - loss: 1.4078e-05 - accuracy: 1.0000
# Epoch 195/200
# 58/58 [==============================] - 0s 3ms/step - loss: 1.3690e-05 - accuracy: 1.0000
# Epoch 196/200
# 58/58 [==============================] - 0s 4ms/step - loss: 1.3516e-05 - accuracy: 1.0000
# Epoch 197/200
# 58/58 [==============================] - 0s 4ms/step - loss: 1.2823e-05 - accuracy: 1.0000
# Epoch 198/200
# 58/58 [==============================] - 0s 6ms/step - loss: 1.2379e-05 - accuracy: 1.0000
# Epoch 199/200
# 58/58 [==============================] - 0s 4ms/step - loss: 1.1956e-05 - accuracy: 1.0000
# Epoch 200/200
# 58/58 [==============================] - 0s 4ms/step - loss: 1.1738e-05 - accuracy: 1.0000
# KerasClassifier(
# 	model=None
# 	build_fn=<function build_model at 0x7ff66e74bac0>
# 	warm_start=False
# 	random_state=None
# 	optimizer=rmsprop
# 	loss=None
# 	metrics=None
# 	batch_size=None
# 	validation_batch_size=None
# 	verbose=1
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=1
# 	class_weight=None
# )

# %%
clf7.model_.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_49 (Dense)            (None, 128)               20864
#
#  dense_50 (Dense)            (None, 64)                8256
#
#  dense_51 (Dense)            (None, 8)                 520
#
# =================================================================
# Total params: 29,640
# Trainable params: 29,640
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = clf7.history_
plt.plot(history['accuracy'], label='Train')
plt.plot(history['val_accuracy'], label='Val')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# Questa serie di codice plotta la curva di accuratezza del modello durante l'addestramento (train) e la validazione (val) in funzione del numero di epoche. In particolare, history contiene le metriche (ad esempio l'accuratezza) raccolte durante l'addestramento del modello e, usando il metodo plot di matplotlib, queste metriche vengono visualizzate in un grafico con l'accuratezza sulle ordinate e il numero di epoche sulle ascisse. La curva dell'accuratezza di train viene rappresentata in blu, mentre quella di validation in arancione. In questo modo, si può verificare l'andamento dell'accuratezza in entrambe le fasi e individuare eventuali problemi di overfitting o underfitting.

# %%
plt.plot(history['loss'], label='Train')
plt.plot(history['val_loss'], label='Val')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy')
plt.legend()
plt.show()

# %% [markdown]
# Questo codice visualizza i grafici dell'andamento della funzione di loss (cross-entropy) e dell'accuratezza durante l'addestramento del modello con l'ottimizzazione dei parametri sui dati di training (Train) e sui dati di validation (Val).
#
# La funzione di loss è un indicatore dell'errore del modello durante la fase di addestramento, mentre l'accuratezza è il rapporto tra le predizioni corrette e il totale delle predizioni effettuate dal modello.
#
# Questi grafici possono aiutare a monitorare la fase di addestramento del modello, verificando se il modello sta apprendendo bene dai dati di training e se sta generalizzando correttamente ai dati di validation.

# %%
y_pred = clf7.predict(X_test).astype(int)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# 20/20 [==============================] - 0s 928us/step
# Accuracy 0.4983974358974359
# F1-score [0.6440678  0.55721393 0.49122807 0.49162011 0.42937853 0.35294118
#  0.42051282 0.41025641]
#               precision    recall  f1-score   support
#
#            0       0.54      0.79      0.64        96
#            1       0.53      0.58      0.56        96
#            2       0.42      0.58      0.49        48
#            3       0.53      0.46      0.49        96
#            4       0.47      0.40      0.43        96
#            5       0.60      0.25      0.35        48
#            6       0.41      0.43      0.42        96
#            7       0.53      0.33      0.41        48
#
#     accuracy                           0.50       624
#    macro avg       0.51      0.48      0.47       624
# weighted avg       0.50      0.50      0.49       624

# %% [markdown]
# Il codice qui sopra sta facendo la previsione delle etichette di classe per il set di test X_test, utilizzando il classificatore clf addestrato precedentemente.
#
# In particolare, la funzione predict restituisce un array di etichette di classe predette, che vengono poi convertite in numeri interi mediante il metodo astype(int).
#
# Successivamente, vengono calcolate alcune metriche di valutazione delle prestazioni del modello, tra cui l'accuracy, l'F1-score e la classificazione report. L'accuracy rappresenta la frazione di campioni correttamente classificati, mentre l'F1-score è una media pesata tra la precision e la recall. Il classification report fornisce una serie di metriche di valutazione delle prestazioni per ogni classe di etichette.

# %%
clf8 = KerasClassifier(build_fn=build_model)
#Il codice sta creando un oggetto "KerasClassifier" che utilizza una funzione "build_model" definita precedentemente per costruire un modello di rete neurale.
#L'oggetto creato può essere utilizzato per addestrare il modello sul dataset di training e per effettuare delle previsioni sul dataset di test

# %%
clf8.fit(X_train, y_train, validation_split=0.2, epochs=1000)
# Out:
# Epoch 1/1000
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# 46/46 [==============================] - 1s 5ms/step - loss: 1.8673 - accuracy: 0.2982 - val_loss: 1.7061 - val_accuracy: 0.3169
# Epoch 2/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.3776 - accuracy: 0.4877 - val_loss: 1.5392 - val_accuracy: 0.4235
# Epoch 3/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.1487 - accuracy: 0.5958 - val_loss: 1.5892 - val_accuracy: 0.4098
# Epoch 4/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.9643 - accuracy: 0.6628 - val_loss: 1.6424 - val_accuracy: 0.3934
# Epoch 5/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.8253 - accuracy: 0.7237 - val_loss: 1.8359 - val_accuracy: 0.3852
# Epoch 6/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.7042 - accuracy: 0.7832 - val_loss: 1.8446 - val_accuracy: 0.4044
# Epoch 7/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6036 - accuracy: 0.8092 - val_loss: 1.9132 - val_accuracy: 0.4071
# Epoch 8/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5154 - accuracy: 0.8488 - val_loss: 2.0253 - val_accuracy: 0.4098
# Epoch 9/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.4459 - accuracy: 0.8714 - val_loss: 2.1779 - val_accuracy: 0.3880
# Epoch 10/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3736 - accuracy: 0.9049 - val_loss: 2.0713 - val_accuracy: 0.4208
# Epoch 11/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3305 - accuracy: 0.9193 - val_loss: 2.4931 - val_accuracy: 0.3907
# Epoch 12/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2766 - accuracy: 0.9350 - val_loss: 2.4995 - val_accuracy: 0.4044
# Epoch 13/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2362 - accuracy: 0.9542 - val_loss: 2.5003 - val_accuracy: 0.4290
# Epoch 14/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2045 - accuracy: 0.9596 - val_loss: 2.6976 - val_accuracy: 0.3852
# Epoch 15/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1734 - accuracy: 0.9679 - val_loss: 2.7197 - val_accuracy: 0.4180
# Epoch 16/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.1460 - accuracy: 0.9836 - val_loss: 2.8106 - val_accuracy: 0.3934
# Epoch 17/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.1260 - accuracy: 0.9829 - val_loss: 2.8266 - val_accuracy: 0.4180
# Epoch 18/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.1112 - accuracy: 0.9891 - val_loss: 3.1166 - val_accuracy: 0.3989
# Epoch 19/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0855 - accuracy: 0.9952 - val_loss: 3.2475 - val_accuracy: 0.3880
# Epoch 20/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0713 - accuracy: 0.9986 - val_loss: 3.3756 - val_accuracy: 0.3907
# Epoch 21/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 0.9986 - val_loss: 3.2294 - val_accuracy: 0.3962
# Epoch 22/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0546 - accuracy: 0.9973 - val_loss: 3.4454 - val_accuracy: 0.3907
# Epoch 23/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0451 - accuracy: 1.0000 - val_loss: 3.5943 - val_accuracy: 0.3852
# Epoch 24/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0386 - accuracy: 1.0000 - val_loss: 3.4507 - val_accuracy: 0.3934
# Epoch 25/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 3.5472 - val_accuracy: 0.4071
# Epoch 26/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0295 - accuracy: 1.0000 - val_loss: 3.7227 - val_accuracy: 0.3962
# Epoch 27/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 0.9993 - val_loss: 3.7192 - val_accuracy: 0.4044
# Epoch 28/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 3.8002 - val_accuracy: 0.3989
# Epoch 29/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 3.7018 - val_accuracy: 0.4126
# Epoch 30/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 3.8559 - val_accuracy: 0.4016
# Epoch 31/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 4.0331 - val_accuracy: 0.3989
# Epoch 32/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 4.0756 - val_accuracy: 0.3934
# Epoch 33/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 4.0826 - val_accuracy: 0.3989
# Epoch 34/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 4.0519 - val_accuracy: 0.4126
# Epoch 35/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 4.1591 - val_accuracy: 0.4016
# Epoch 36/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 4.2403 - val_accuracy: 0.3962
# Epoch 37/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 4.2824 - val_accuracy: 0.3962
# Epoch 38/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 4.2960 - val_accuracy: 0.4098
# Epoch 39/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 4.3794 - val_accuracy: 0.4071
# Epoch 40/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 4.3769 - val_accuracy: 0.4044
# Epoch 41/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 4.5139 - val_accuracy: 0.3934
# Epoch 42/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 4.4962 - val_accuracy: 0.4098
# Epoch 43/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 4.5632 - val_accuracy: 0.3962
# Epoch 44/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 4.5550 - val_accuracy: 0.4016
# Epoch 45/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 4.6593 - val_accuracy: 0.4016
# Epoch 46/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 4.6545 - val_accuracy: 0.4044
# Epoch 47/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 4.6567 - val_accuracy: 0.4126
# Epoch 48/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 4.7429 - val_accuracy: 0.4071
# Epoch 49/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 4.7065 - val_accuracy: 0.4098
# Epoch 50/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 4.7212 - val_accuracy: 0.4098
# Epoch 51/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 4.8195 - val_accuracy: 0.4098
# Epoch 52/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 4.8683 - val_accuracy: 0.4044
# Epoch 53/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 4.8949 - val_accuracy: 0.4071
# Epoch 54/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 4.8983 - val_accuracy: 0.4044
# Epoch 55/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 4.9452 - val_accuracy: 0.4016
# Epoch 56/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 4.9637 - val_accuracy: 0.4126
# Epoch 57/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 4.9650 - val_accuracy: 0.4071
# Epoch 58/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 5.0588 - val_accuracy: 0.4071
# Epoch 59/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 5.0494 - val_accuracy: 0.4126
# Epoch 60/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 5.0834 - val_accuracy: 0.4044
# Epoch 61/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 5.1015 - val_accuracy: 0.4098
# Epoch 62/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 5.1481 - val_accuracy: 0.4153
# Epoch 63/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 5.1620 - val_accuracy: 0.4098
# Epoch 64/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 5.1769 - val_accuracy: 0.4098
# Epoch 65/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 5.2325 - val_accuracy: 0.4071
# Epoch 66/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 5.2379 - val_accuracy: 0.4126
# Epoch 67/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 5.2583 - val_accuracy: 0.4071
# Epoch 68/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 5.2993 - val_accuracy: 0.4044
# Epoch 69/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 5.2995 - val_accuracy: 0.4071
# Epoch 70/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 5.3268 - val_accuracy: 0.4098
# Epoch 71/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 5.3818 - val_accuracy: 0.4071
# Epoch 72/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 5.4177 - val_accuracy: 0.4071
# Epoch 73/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 5.4217 - val_accuracy: 0.4044
# Epoch 74/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 5.4802 - val_accuracy: 0.4016
# Epoch 75/1000
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 5.4797 - val_accuracy: 0.4016
# Epoch 76/1000
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 5.4708 - val_accuracy: 0.4153
# Epoch 77/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 5.5485 - val_accuracy: 0.3989
# Epoch 78/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 5.5570 - val_accuracy: 0.4044
# Epoch 79/1000
# 46/46 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 5.5887 - val_accuracy: 0.4098
# Epoch 80/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 9.8847e-04 - accuracy: 1.0000 - val_loss: 5.6175 - val_accuracy: 0.4071
# Epoch 81/1000
# 46/46 [==============================] - 0s 5ms/step - loss: 9.4093e-04 - accuracy: 1.0000 - val_loss: 5.6301 - val_accuracy: 0.4071
# Epoch 82/1000
# 46/46 [==============================] - 0s 7ms/step - loss: 9.0707e-04 - accuracy: 1.0000 - val_loss: 5.6380 - val_accuracy: 0.4098
# Epoch 83/1000
# 46/46 [==============================] - 0s 5ms/step - loss: 8.7911e-04 - accuracy: 1.0000 - val_loss: 5.7013 - val_accuracy: 0.4071
# Epoch 84/1000
# 46/46 [==============================] - 0s 5ms/step - loss: 8.4512e-04 - accuracy: 1.0000 - val_loss: 5.7008 - val_accuracy: 0.4126
# Epoch 85/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 8.1173e-04 - accuracy: 1.0000 - val_loss: 5.7304 - val_accuracy: 0.4071
# Epoch 86/1000
# 46/46 [==============================] - 0s 5ms/step - loss: 7.7769e-04 - accuracy: 1.0000 - val_loss: 5.7541 - val_accuracy: 0.4071
# Epoch 87/1000
# 46/46 [==============================] - 0s 5ms/step - loss: 7.5163e-04 - accuracy: 1.0000 - val_loss: 5.7774 - val_accuracy: 0.4098
# Epoch 88/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 7.2668e-04 - accuracy: 1.0000 - val_loss: 5.7975 - val_accuracy: 0.4098
# Epoch 89/1000
# 46/46 [==============================] - 0s 5ms/step - loss: 6.9851e-04 - accuracy: 1.0000 - val_loss: 5.7978 - val_accuracy: 0.4098
# Epoch 90/1000
# 46/46 [==============================] - 0s 10ms/step - loss: 6.7065e-04 - accuracy: 1.0000 - val_loss: 5.8561 - val_accuracy: 0.4016
# Epoch 91/1000
# 46/46 [==============================] - 0s 5ms/step - loss: 6.4515e-04 - accuracy: 1.0000 - val_loss: 5.8201 - val_accuracy: 0.4126
# Epoch 92/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 6.2889e-04 - accuracy: 1.0000 - val_loss: 5.8821 - val_accuracy: 0.4098
# Epoch 93/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 5.9919e-04 - accuracy: 1.0000 - val_loss: 5.9005 - val_accuracy: 0.4071
# Epoch 94/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 5.8000e-04 - accuracy: 1.0000 - val_loss: 5.9291 - val_accuracy: 0.4098
# Epoch 95/1000
# 46/46 [==============================] - 0s 5ms/step - loss: 5.6030e-04 - accuracy: 1.0000 - val_loss: 5.9288 - val_accuracy: 0.4098
# Epoch 96/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 5.4193e-04 - accuracy: 1.0000 - val_loss: 5.9552 - val_accuracy: 0.4071
# Epoch 97/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 5.2655e-04 - accuracy: 1.0000 - val_loss: 5.9936 - val_accuracy: 0.4071
# Epoch 98/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 5.0325e-04 - accuracy: 1.0000 - val_loss: 6.0063 - val_accuracy: 0.4098
# Epoch 99/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.8815e-04 - accuracy: 1.0000 - val_loss: 6.0155 - val_accuracy: 0.4098
# Epoch 100/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 4.7069e-04 - accuracy: 1.0000 - val_loss: 6.0641 - val_accuracy: 0.4098
# Epoch 101/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 4.5371e-04 - accuracy: 1.0000 - val_loss: 6.0716 - val_accuracy: 0.4071
# Epoch 102/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 4.4112e-04 - accuracy: 1.0000 - val_loss: 6.0697 - val_accuracy: 0.4098
# Epoch 103/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 4.2292e-04 - accuracy: 1.0000 - val_loss: 6.1257 - val_accuracy: 0.4071
# Epoch 104/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 4.1097e-04 - accuracy: 1.0000 - val_loss: 6.1307 - val_accuracy: 0.4098
# Epoch 105/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.9695e-04 - accuracy: 1.0000 - val_loss: 6.1401 - val_accuracy: 0.4098
# Epoch 106/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.8636e-04 - accuracy: 1.0000 - val_loss: 6.1518 - val_accuracy: 0.4098
# Epoch 107/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.7683e-04 - accuracy: 1.0000 - val_loss: 6.1783 - val_accuracy: 0.4071
# Epoch 108/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.5878e-04 - accuracy: 1.0000 - val_loss: 6.2097 - val_accuracy: 0.4098
# Epoch 109/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.4781e-04 - accuracy: 1.0000 - val_loss: 6.2157 - val_accuracy: 0.4098
# Epoch 110/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.3708e-04 - accuracy: 1.0000 - val_loss: 6.2464 - val_accuracy: 0.4098
# Epoch 111/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.2483e-04 - accuracy: 1.0000 - val_loss: 6.2697 - val_accuracy: 0.4098
# Epoch 112/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.1515e-04 - accuracy: 1.0000 - val_loss: 6.2870 - val_accuracy: 0.4098
# Epoch 113/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.0508e-04 - accuracy: 1.0000 - val_loss: 6.3297 - val_accuracy: 0.4098
# Epoch 114/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.9501e-04 - accuracy: 1.0000 - val_loss: 6.3206 - val_accuracy: 0.4098
# Epoch 115/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.8685e-04 - accuracy: 1.0000 - val_loss: 6.3400 - val_accuracy: 0.4098
# Epoch 116/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.7798e-04 - accuracy: 1.0000 - val_loss: 6.3660 - val_accuracy: 0.4098
# Epoch 117/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.7090e-04 - accuracy: 1.0000 - val_loss: 6.3809 - val_accuracy: 0.4098
# Epoch 118/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.6201e-04 - accuracy: 1.0000 - val_loss: 6.4017 - val_accuracy: 0.4098
# Epoch 119/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.5165e-04 - accuracy: 1.0000 - val_loss: 6.4333 - val_accuracy: 0.4098
# Epoch 120/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.4303e-04 - accuracy: 1.0000 - val_loss: 6.4496 - val_accuracy: 0.4098
# Epoch 121/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.3615e-04 - accuracy: 1.0000 - val_loss: 6.4720 - val_accuracy: 0.4098
# Epoch 122/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.3082e-04 - accuracy: 1.0000 - val_loss: 6.4726 - val_accuracy: 0.4098
# Epoch 123/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.2343e-04 - accuracy: 1.0000 - val_loss: 6.5065 - val_accuracy: 0.4098
# Epoch 124/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.1653e-04 - accuracy: 1.0000 - val_loss: 6.5193 - val_accuracy: 0.4098
# Epoch 125/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.0863e-04 - accuracy: 1.0000 - val_loss: 6.5603 - val_accuracy: 0.4098
# Epoch 126/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.0453e-04 - accuracy: 1.0000 - val_loss: 6.5532 - val_accuracy: 0.4098
# Epoch 127/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.9667e-04 - accuracy: 1.0000 - val_loss: 6.5646 - val_accuracy: 0.4098
# Epoch 128/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.9079e-04 - accuracy: 1.0000 - val_loss: 6.6000 - val_accuracy: 0.4098
# Epoch 129/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.8610e-04 - accuracy: 1.0000 - val_loss: 6.6369 - val_accuracy: 0.4126
# Epoch 130/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.8030e-04 - accuracy: 1.0000 - val_loss: 6.6347 - val_accuracy: 0.4098
# Epoch 131/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.7422e-04 - accuracy: 1.0000 - val_loss: 6.6692 - val_accuracy: 0.4098
# Epoch 132/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.6978e-04 - accuracy: 1.0000 - val_loss: 6.6659 - val_accuracy: 0.4098
# Epoch 133/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.6392e-04 - accuracy: 1.0000 - val_loss: 6.6915 - val_accuracy: 0.4126
# Epoch 134/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.5993e-04 - accuracy: 1.0000 - val_loss: 6.6991 - val_accuracy: 0.4098
# Epoch 135/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.5461e-04 - accuracy: 1.0000 - val_loss: 6.7386 - val_accuracy: 0.4098
# Epoch 136/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.4937e-04 - accuracy: 1.0000 - val_loss: 6.7445 - val_accuracy: 0.4126
# Epoch 137/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.4674e-04 - accuracy: 1.0000 - val_loss: 6.7537 - val_accuracy: 0.4098
# Epoch 138/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.4109e-04 - accuracy: 1.0000 - val_loss: 6.7827 - val_accuracy: 0.4098
# Epoch 139/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.3677e-04 - accuracy: 1.0000 - val_loss: 6.8037 - val_accuracy: 0.4098
# Epoch 140/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.3311e-04 - accuracy: 1.0000 - val_loss: 6.8016 - val_accuracy: 0.4098
# Epoch 141/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.2970e-04 - accuracy: 1.0000 - val_loss: 6.8300 - val_accuracy: 0.4071
# Epoch 142/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.2508e-04 - accuracy: 1.0000 - val_loss: 6.8620 - val_accuracy: 0.4098
# Epoch 143/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.2164e-04 - accuracy: 1.0000 - val_loss: 6.8680 - val_accuracy: 0.4071
# Epoch 144/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.1735e-04 - accuracy: 1.0000 - val_loss: 6.9050 - val_accuracy: 0.4098
# Epoch 145/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.1511e-04 - accuracy: 1.0000 - val_loss: 6.9037 - val_accuracy: 0.4071
# Epoch 146/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.1144e-04 - accuracy: 1.0000 - val_loss: 6.9268 - val_accuracy: 0.4098
# Epoch 147/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.0881e-04 - accuracy: 1.0000 - val_loss: 6.9144 - val_accuracy: 0.4071
# Epoch 148/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.0526e-04 - accuracy: 1.0000 - val_loss: 6.9649 - val_accuracy: 0.4098
# Epoch 149/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.0203e-04 - accuracy: 1.0000 - val_loss: 6.9707 - val_accuracy: 0.4071
# Epoch 150/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 9.8715e-05 - accuracy: 1.0000 - val_loss: 6.9926 - val_accuracy: 0.4071
# Epoch 151/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 9.6295e-05 - accuracy: 1.0000 - val_loss: 7.0091 - val_accuracy: 0.4071
# Epoch 152/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 9.4086e-05 - accuracy: 1.0000 - val_loss: 7.0329 - val_accuracy: 0.4044
# Epoch 153/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 9.0797e-05 - accuracy: 1.0000 - val_loss: 7.0479 - val_accuracy: 0.4098
# Epoch 154/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 8.8068e-05 - accuracy: 1.0000 - val_loss: 7.0611 - val_accuracy: 0.4071
# Epoch 155/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 8.5552e-05 - accuracy: 1.0000 - val_loss: 7.0733 - val_accuracy: 0.4044
# Epoch 156/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 8.3668e-05 - accuracy: 1.0000 - val_loss: 7.1126 - val_accuracy: 0.4044
# Epoch 157/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 8.0651e-05 - accuracy: 1.0000 - val_loss: 7.1109 - val_accuracy: 0.4071
# Epoch 158/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 7.8822e-05 - accuracy: 1.0000 - val_loss: 7.1357 - val_accuracy: 0.4071
# Epoch 159/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 7.7176e-05 - accuracy: 1.0000 - val_loss: 7.1423 - val_accuracy: 0.4044
# Epoch 160/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 7.5097e-05 - accuracy: 1.0000 - val_loss: 7.1772 - val_accuracy: 0.4098
# Epoch 161/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 7.2019e-05 - accuracy: 1.0000 - val_loss: 7.1965 - val_accuracy: 0.4044
# Epoch 162/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 7.0290e-05 - accuracy: 1.0000 - val_loss: 7.2260 - val_accuracy: 0.4098
# Epoch 163/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 6.8222e-05 - accuracy: 1.0000 - val_loss: 7.2316 - val_accuracy: 0.4071
# Epoch 164/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6097e-05 - accuracy: 1.0000 - val_loss: 7.2482 - val_accuracy: 0.4044
# Epoch 165/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 6.4382e-05 - accuracy: 1.0000 - val_loss: 7.2621 - val_accuracy: 0.4071
# Epoch 166/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 6.2301e-05 - accuracy: 1.0000 - val_loss: 7.2672 - val_accuracy: 0.4044
# Epoch 167/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 6.0934e-05 - accuracy: 1.0000 - val_loss: 7.3253 - val_accuracy: 0.4071
# Epoch 168/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 5.9044e-05 - accuracy: 1.0000 - val_loss: 7.3091 - val_accuracy: 0.4044
# Epoch 169/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 5.7767e-05 - accuracy: 1.0000 - val_loss: 7.3371 - val_accuracy: 0.4044
# Epoch 170/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 5.6077e-05 - accuracy: 1.0000 - val_loss: 7.3379 - val_accuracy: 0.4044
# Epoch 171/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 5.4271e-05 - accuracy: 1.0000 - val_loss: 7.3799 - val_accuracy: 0.4071
# Epoch 172/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 5.2888e-05 - accuracy: 1.0000 - val_loss: 7.3810 - val_accuracy: 0.4071
# Epoch 173/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 5.1108e-05 - accuracy: 1.0000 - val_loss: 7.4123 - val_accuracy: 0.4071
# Epoch 174/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.9967e-05 - accuracy: 1.0000 - val_loss: 7.4203 - val_accuracy: 0.4071
# Epoch 175/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.8761e-05 - accuracy: 1.0000 - val_loss: 7.4471 - val_accuracy: 0.4044
# Epoch 176/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.7079e-05 - accuracy: 1.0000 - val_loss: 7.4608 - val_accuracy: 0.4071
# Epoch 177/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.5902e-05 - accuracy: 1.0000 - val_loss: 7.4861 - val_accuracy: 0.4071
# Epoch 178/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.4692e-05 - accuracy: 1.0000 - val_loss: 7.4956 - val_accuracy: 0.4098
# Epoch 179/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.3261e-05 - accuracy: 1.0000 - val_loss: 7.5261 - val_accuracy: 0.4098
# Epoch 180/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.2243e-05 - accuracy: 1.0000 - val_loss: 7.5206 - val_accuracy: 0.4071
# Epoch 181/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.0673e-05 - accuracy: 1.0000 - val_loss: 7.5347 - val_accuracy: 0.4098
# Epoch 182/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.9753e-05 - accuracy: 1.0000 - val_loss: 7.5703 - val_accuracy: 0.4071
# Epoch 183/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.8893e-05 - accuracy: 1.0000 - val_loss: 7.5883 - val_accuracy: 0.4071
# Epoch 184/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.7860e-05 - accuracy: 1.0000 - val_loss: 7.6020 - val_accuracy: 0.4126
# Epoch 185/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.6628e-05 - accuracy: 1.0000 - val_loss: 7.6089 - val_accuracy: 0.4126
# Epoch 186/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.5720e-05 - accuracy: 1.0000 - val_loss: 7.6270 - val_accuracy: 0.4071
# Epoch 187/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.4816e-05 - accuracy: 1.0000 - val_loss: 7.6801 - val_accuracy: 0.4153
# Epoch 188/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.3828e-05 - accuracy: 1.0000 - val_loss: 7.6758 - val_accuracy: 0.4098
# Epoch 189/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.2979e-05 - accuracy: 1.0000 - val_loss: 7.6952 - val_accuracy: 0.4126
# Epoch 190/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.1991e-05 - accuracy: 1.0000 - val_loss: 7.6964 - val_accuracy: 0.4126
# Epoch 191/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.1060e-05 - accuracy: 1.0000 - val_loss: 7.7178 - val_accuracy: 0.4098
# Epoch 192/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.0216e-05 - accuracy: 1.0000 - val_loss: 7.7291 - val_accuracy: 0.4098
# Epoch 193/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.9240e-05 - accuracy: 1.0000 - val_loss: 7.7514 - val_accuracy: 0.4098
# Epoch 194/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.8566e-05 - accuracy: 1.0000 - val_loss: 7.7831 - val_accuracy: 0.4126
# Epoch 195/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.7911e-05 - accuracy: 1.0000 - val_loss: 7.7906 - val_accuracy: 0.4098
# Epoch 196/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.7109e-05 - accuracy: 1.0000 - val_loss: 7.8141 - val_accuracy: 0.4153
# Epoch 197/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.6312e-05 - accuracy: 1.0000 - val_loss: 7.8244 - val_accuracy: 0.4098
# Epoch 198/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.5645e-05 - accuracy: 1.0000 - val_loss: 7.8512 - val_accuracy: 0.4126
# Epoch 199/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.4915e-05 - accuracy: 1.0000 - val_loss: 7.8723 - val_accuracy: 0.4126
# Epoch 200/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.4304e-05 - accuracy: 1.0000 - val_loss: 7.8744 - val_accuracy: 0.4098
# Epoch 201/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.3650e-05 - accuracy: 1.0000 - val_loss: 7.9039 - val_accuracy: 0.4126
# Epoch 202/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.3074e-05 - accuracy: 1.0000 - val_loss: 7.8986 - val_accuracy: 0.4098
# Epoch 203/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.2385e-05 - accuracy: 1.0000 - val_loss: 7.9253 - val_accuracy: 0.4153
# Epoch 204/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1887e-05 - accuracy: 1.0000 - val_loss: 7.9502 - val_accuracy: 0.4126
# Epoch 205/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1170e-05 - accuracy: 1.0000 - val_loss: 7.9675 - val_accuracy: 0.4098
# Epoch 206/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.0689e-05 - accuracy: 1.0000 - val_loss: 7.9742 - val_accuracy: 0.4153
# Epoch 207/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.0041e-05 - accuracy: 1.0000 - val_loss: 7.9972 - val_accuracy: 0.4126
# Epoch 208/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.9684e-05 - accuracy: 1.0000 - val_loss: 8.0071 - val_accuracy: 0.4098
# Epoch 209/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.9048e-05 - accuracy: 1.0000 - val_loss: 8.0304 - val_accuracy: 0.4126
# Epoch 210/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.8495e-05 - accuracy: 1.0000 - val_loss: 8.0660 - val_accuracy: 0.4153
# Epoch 211/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.7991e-05 - accuracy: 1.0000 - val_loss: 8.0911 - val_accuracy: 0.4153
# Epoch 212/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.7492e-05 - accuracy: 1.0000 - val_loss: 8.0812 - val_accuracy: 0.4098
# Epoch 213/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.7005e-05 - accuracy: 1.0000 - val_loss: 8.1224 - val_accuracy: 0.4126
# Epoch 214/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.6547e-05 - accuracy: 1.0000 - val_loss: 8.1181 - val_accuracy: 0.4126
# Epoch 215/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.6163e-05 - accuracy: 1.0000 - val_loss: 8.1449 - val_accuracy: 0.4153
# Epoch 216/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.5737e-05 - accuracy: 1.0000 - val_loss: 8.1266 - val_accuracy: 0.4126
# Epoch 217/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.5333e-05 - accuracy: 1.0000 - val_loss: 8.1782 - val_accuracy: 0.4126
# Epoch 218/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.4795e-05 - accuracy: 1.0000 - val_loss: 8.1917 - val_accuracy: 0.4126
# Epoch 219/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.4442e-05 - accuracy: 1.0000 - val_loss: 8.2172 - val_accuracy: 0.4153
# Epoch 220/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.4130e-05 - accuracy: 1.0000 - val_loss: 8.2093 - val_accuracy: 0.4098
# Epoch 221/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.3911e-05 - accuracy: 1.0000 - val_loss: 8.2268 - val_accuracy: 0.4098
# Epoch 222/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.3387e-05 - accuracy: 1.0000 - val_loss: 8.2747 - val_accuracy: 0.4126
# Epoch 223/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.3140e-05 - accuracy: 1.0000 - val_loss: 8.2644 - val_accuracy: 0.4153
# Epoch 224/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.2654e-05 - accuracy: 1.0000 - val_loss: 8.3103 - val_accuracy: 0.4153
# Epoch 225/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.2358e-05 - accuracy: 1.0000 - val_loss: 8.2975 - val_accuracy: 0.4153
# Epoch 226/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.2013e-05 - accuracy: 1.0000 - val_loss: 8.3246 - val_accuracy: 0.4153
# Epoch 227/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.1704e-05 - accuracy: 1.0000 - val_loss: 8.3429 - val_accuracy: 0.4126
# Epoch 228/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.1406e-05 - accuracy: 1.0000 - val_loss: 8.3562 - val_accuracy: 0.4153
# Epoch 229/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.1023e-05 - accuracy: 1.0000 - val_loss: 8.3648 - val_accuracy: 0.4126
# Epoch 230/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.0763e-05 - accuracy: 1.0000 - val_loss: 8.3846 - val_accuracy: 0.4098
# Epoch 231/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.0554e-05 - accuracy: 1.0000 - val_loss: 8.3972 - val_accuracy: 0.4098
# Epoch 232/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.0193e-05 - accuracy: 1.0000 - val_loss: 8.4226 - val_accuracy: 0.4126
# Epoch 233/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 9.9940e-06 - accuracy: 1.0000 - val_loss: 8.4340 - val_accuracy: 0.4098
# Epoch 234/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 9.6954e-06 - accuracy: 1.0000 - val_loss: 8.4606 - val_accuracy: 0.4153
# Epoch 235/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 9.4086e-06 - accuracy: 1.0000 - val_loss: 8.4779 - val_accuracy: 0.4153
# Epoch 236/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 9.1879e-06 - accuracy: 1.0000 - val_loss: 8.5076 - val_accuracy: 0.4153
# Epoch 237/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 8.9666e-06 - accuracy: 1.0000 - val_loss: 8.5219 - val_accuracy: 0.4126
# Epoch 238/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 8.6978e-06 - accuracy: 1.0000 - val_loss: 8.5380 - val_accuracy: 0.4153
# Epoch 239/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 8.4761e-06 - accuracy: 1.0000 - val_loss: 8.5472 - val_accuracy: 0.4153
# Epoch 240/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 8.2933e-06 - accuracy: 1.0000 - val_loss: 8.5468 - val_accuracy: 0.4098
# Epoch 241/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 8.0598e-06 - accuracy: 1.0000 - val_loss: 8.6098 - val_accuracy: 0.4153
# Epoch 242/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 7.8058e-06 - accuracy: 1.0000 - val_loss: 8.5873 - val_accuracy: 0.4126
# Epoch 243/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 7.6303e-06 - accuracy: 1.0000 - val_loss: 8.6344 - val_accuracy: 0.4153
# Epoch 244/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 7.4017e-06 - accuracy: 1.0000 - val_loss: 8.6355 - val_accuracy: 0.4126
# Epoch 245/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 7.2701e-06 - accuracy: 1.0000 - val_loss: 8.6446 - val_accuracy: 0.4153
# Epoch 246/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 7.0696e-06 - accuracy: 1.0000 - val_loss: 8.6663 - val_accuracy: 0.4153
# Epoch 247/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 6.8259e-06 - accuracy: 1.0000 - val_loss: 8.6839 - val_accuracy: 0.4126
# Epoch 248/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 6.6706e-06 - accuracy: 1.0000 - val_loss: 8.6966 - val_accuracy: 0.4153
# Epoch 249/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 6.4991e-06 - accuracy: 1.0000 - val_loss: 8.7295 - val_accuracy: 0.4153
# Epoch 250/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 6.3752e-06 - accuracy: 1.0000 - val_loss: 8.7438 - val_accuracy: 0.4153
# Epoch 251/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 6.1474e-06 - accuracy: 1.0000 - val_loss: 8.7495 - val_accuracy: 0.4153
# Epoch 252/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 5.9673e-06 - accuracy: 1.0000 - val_loss: 8.7740 - val_accuracy: 0.4153
# Epoch 253/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 5.8207e-06 - accuracy: 1.0000 - val_loss: 8.7918 - val_accuracy: 0.4153
# Epoch 254/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 5.6962e-06 - accuracy: 1.0000 - val_loss: 8.8020 - val_accuracy: 0.4153
# Epoch 255/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 5.5226e-06 - accuracy: 1.0000 - val_loss: 8.8088 - val_accuracy: 0.4153
# Epoch 256/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 5.3725e-06 - accuracy: 1.0000 - val_loss: 8.8373 - val_accuracy: 0.4153
# Epoch 257/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 5.2315e-06 - accuracy: 1.0000 - val_loss: 8.8490 - val_accuracy: 0.4153
# Epoch 258/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 5.0722e-06 - accuracy: 1.0000 - val_loss: 8.8802 - val_accuracy: 0.4153
# Epoch 259/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.9529e-06 - accuracy: 1.0000 - val_loss: 8.8771 - val_accuracy: 0.4126
# Epoch 260/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.8544e-06 - accuracy: 1.0000 - val_loss: 8.9032 - val_accuracy: 0.4153
# Epoch 261/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 4.6941e-06 - accuracy: 1.0000 - val_loss: 8.9283 - val_accuracy: 0.4153
# Epoch 262/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.5942e-06 - accuracy: 1.0000 - val_loss: 8.9294 - val_accuracy: 0.4153
# Epoch 263/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.4422e-06 - accuracy: 1.0000 - val_loss: 8.9364 - val_accuracy: 0.4153
# Epoch 264/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.3446e-06 - accuracy: 1.0000 - val_loss: 8.9729 - val_accuracy: 0.4153
# Epoch 265/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.2110e-06 - accuracy: 1.0000 - val_loss: 8.9972 - val_accuracy: 0.4153
# Epoch 266/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.1403e-06 - accuracy: 1.0000 - val_loss: 9.0025 - val_accuracy: 0.4153
# Epoch 267/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.0065e-06 - accuracy: 1.0000 - val_loss: 9.0248 - val_accuracy: 0.4153
# Epoch 268/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.9040e-06 - accuracy: 1.0000 - val_loss: 9.0595 - val_accuracy: 0.4153
# Epoch 269/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.8001e-06 - accuracy: 1.0000 - val_loss: 9.0521 - val_accuracy: 0.4153
# Epoch 270/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.7277e-06 - accuracy: 1.0000 - val_loss: 9.0842 - val_accuracy: 0.4153
# Epoch 271/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.6101e-06 - accuracy: 1.0000 - val_loss: 9.0974 - val_accuracy: 0.4153
# Epoch 272/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.5285e-06 - accuracy: 1.0000 - val_loss: 9.0994 - val_accuracy: 0.4153
# Epoch 273/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.4262e-06 - accuracy: 1.0000 - val_loss: 9.1246 - val_accuracy: 0.4153
# Epoch 274/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.3082e-06 - accuracy: 1.0000 - val_loss: 9.1452 - val_accuracy: 0.4153
# Epoch 275/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.2458e-06 - accuracy: 1.0000 - val_loss: 9.1522 - val_accuracy: 0.4153
# Epoch 276/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.1568e-06 - accuracy: 1.0000 - val_loss: 9.1852 - val_accuracy: 0.4153
# Epoch 277/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.0852e-06 - accuracy: 1.0000 - val_loss: 9.1893 - val_accuracy: 0.4153
# Epoch 278/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 3.0197e-06 - accuracy: 1.0000 - val_loss: 9.2107 - val_accuracy: 0.4153
# Epoch 279/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.9241e-06 - accuracy: 1.0000 - val_loss: 9.2331 - val_accuracy: 0.4153
# Epoch 280/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.8365e-06 - accuracy: 1.0000 - val_loss: 9.2556 - val_accuracy: 0.4153
# Epoch 281/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.7781e-06 - accuracy: 1.0000 - val_loss: 9.2538 - val_accuracy: 0.4153
# Epoch 282/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.6956e-06 - accuracy: 1.0000 - val_loss: 9.2758 - val_accuracy: 0.4153
# Epoch 283/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.6238e-06 - accuracy: 1.0000 - val_loss: 9.3048 - val_accuracy: 0.4153
# Epoch 284/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.5531e-06 - accuracy: 1.0000 - val_loss: 9.2913 - val_accuracy: 0.4153
# Epoch 285/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.4821e-06 - accuracy: 1.0000 - val_loss: 9.3208 - val_accuracy: 0.4153
# Epoch 286/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.4338e-06 - accuracy: 1.0000 - val_loss: 9.3468 - val_accuracy: 0.4153
# Epoch 287/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.3740e-06 - accuracy: 1.0000 - val_loss: 9.3488 - val_accuracy: 0.4153
# Epoch 288/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.3079e-06 - accuracy: 1.0000 - val_loss: 9.3899 - val_accuracy: 0.4153
# Epoch 289/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.2368e-06 - accuracy: 1.0000 - val_loss: 9.3823 - val_accuracy: 0.4153
# Epoch 290/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.1816e-06 - accuracy: 1.0000 - val_loss: 9.4115 - val_accuracy: 0.4153
# Epoch 291/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.1468e-06 - accuracy: 1.0000 - val_loss: 9.4178 - val_accuracy: 0.4153
# Epoch 292/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.0691e-06 - accuracy: 1.0000 - val_loss: 9.4534 - val_accuracy: 0.4153
# Epoch 293/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.0212e-06 - accuracy: 1.0000 - val_loss: 9.4548 - val_accuracy: 0.4153
# Epoch 294/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.9762e-06 - accuracy: 1.0000 - val_loss: 9.4625 - val_accuracy: 0.4153
# Epoch 295/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.9303e-06 - accuracy: 1.0000 - val_loss: 9.4924 - val_accuracy: 0.4153
# Epoch 296/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.8763e-06 - accuracy: 1.0000 - val_loss: 9.5141 - val_accuracy: 0.4153
# Epoch 297/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.8338e-06 - accuracy: 1.0000 - val_loss: 9.5314 - val_accuracy: 0.4153
# Epoch 298/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.7764e-06 - accuracy: 1.0000 - val_loss: 9.5330 - val_accuracy: 0.4153
# Epoch 299/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.7357e-06 - accuracy: 1.0000 - val_loss: 9.5585 - val_accuracy: 0.4153
# Epoch 300/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.6851e-06 - accuracy: 1.0000 - val_loss: 9.5910 - val_accuracy: 0.4153
# Epoch 301/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.6454e-06 - accuracy: 1.0000 - val_loss: 9.6100 - val_accuracy: 0.4153
# Epoch 302/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.6137e-06 - accuracy: 1.0000 - val_loss: 9.6085 - val_accuracy: 0.4153
# Epoch 303/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.5623e-06 - accuracy: 1.0000 - val_loss: 9.6432 - val_accuracy: 0.4153
# Epoch 304/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.5293e-06 - accuracy: 1.0000 - val_loss: 9.6452 - val_accuracy: 0.4153
# Epoch 305/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.4804e-06 - accuracy: 1.0000 - val_loss: 9.6580 - val_accuracy: 0.4153
# Epoch 306/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.4650e-06 - accuracy: 1.0000 - val_loss: 9.6837 - val_accuracy: 0.4153
# Epoch 307/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.4155e-06 - accuracy: 1.0000 - val_loss: 9.6787 - val_accuracy: 0.4153
# Epoch 308/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.3701e-06 - accuracy: 1.0000 - val_loss: 9.7260 - val_accuracy: 0.4153
# Epoch 309/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.3347e-06 - accuracy: 1.0000 - val_loss: 9.7246 - val_accuracy: 0.4153
# Epoch 310/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 1.3074e-06 - accuracy: 1.0000 - val_loss: 9.7583 - val_accuracy: 0.4153
# Epoch 311/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.2727e-06 - accuracy: 1.0000 - val_loss: 9.7752 - val_accuracy: 0.4153
# Epoch 312/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.2388e-06 - accuracy: 1.0000 - val_loss: 9.7866 - val_accuracy: 0.4153
# Epoch 313/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.2104e-06 - accuracy: 1.0000 - val_loss: 9.7822 - val_accuracy: 0.4153
# Epoch 314/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.1786e-06 - accuracy: 1.0000 - val_loss: 9.8156 - val_accuracy: 0.4153
# Epoch 315/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.1423e-06 - accuracy: 1.0000 - val_loss: 9.8344 - val_accuracy: 0.4153
# Epoch 316/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.1189e-06 - accuracy: 1.0000 - val_loss: 9.8494 - val_accuracy: 0.4153
# Epoch 317/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.0894e-06 - accuracy: 1.0000 - val_loss: 9.8527 - val_accuracy: 0.4153
# Epoch 318/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.0624e-06 - accuracy: 1.0000 - val_loss: 9.8671 - val_accuracy: 0.4153
# Epoch 319/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.0360e-06 - accuracy: 1.0000 - val_loss: 9.8880 - val_accuracy: 0.4153
# Epoch 320/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.0081e-06 - accuracy: 1.0000 - val_loss: 9.9099 - val_accuracy: 0.4153
# Epoch 321/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 9.8164e-07 - accuracy: 1.0000 - val_loss: 9.9277 - val_accuracy: 0.4153
# Epoch 322/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 9.6011e-07 - accuracy: 1.0000 - val_loss: 9.9489 - val_accuracy: 0.4153
# Epoch 323/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 9.3378e-07 - accuracy: 1.0000 - val_loss: 9.9586 - val_accuracy: 0.4153
# Epoch 324/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 9.1029e-07 - accuracy: 1.0000 - val_loss: 10.0017 - val_accuracy: 0.4153
# Epoch 325/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 8.8486e-07 - accuracy: 1.0000 - val_loss: 10.0117 - val_accuracy: 0.4153
# Epoch 326/1000
# ...
# Epoch 896/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.3576e-07 - accuracy: 1.0000 - val_loss: 14.0025 - val_accuracy: 0.3907
# Epoch 897/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.3348e-07 - accuracy: 1.0000 - val_loss: 14.0057 - val_accuracy: 0.3907
# Epoch 898/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.3071e-07 - accuracy: 1.0000 - val_loss: 14.0109 - val_accuracy: 0.3907
# Epoch 899/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.2777e-07 - accuracy: 1.0000 - val_loss: 14.0135 - val_accuracy: 0.3907
# Epoch 900/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.2590e-07 - accuracy: 1.0000 - val_loss: 14.0231 - val_accuracy: 0.3907
# Epoch 901/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.2369e-07 - accuracy: 1.0000 - val_loss: 14.0225 - val_accuracy: 0.3907
# Epoch 902/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.2214e-07 - accuracy: 1.0000 - val_loss: 14.0307 - val_accuracy: 0.3934
# Epoch 903/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.1970e-07 - accuracy: 1.0000 - val_loss: 14.0354 - val_accuracy: 0.3934
# Epoch 904/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.1717e-07 - accuracy: 1.0000 - val_loss: 14.0384 - val_accuracy: 0.3934
# Epoch 905/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.1513e-07 - accuracy: 1.0000 - val_loss: 14.0405 - val_accuracy: 0.3934
# Epoch 906/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.1301e-07 - accuracy: 1.0000 - val_loss: 14.0445 - val_accuracy: 0.3934
# Epoch 907/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.1130e-07 - accuracy: 1.0000 - val_loss: 14.0496 - val_accuracy: 0.3934
# Epoch 908/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.0967e-07 - accuracy: 1.0000 - val_loss: 14.0465 - val_accuracy: 0.3934
# Epoch 909/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.0771e-07 - accuracy: 1.0000 - val_loss: 14.0558 - val_accuracy: 0.3934
# Epoch 910/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.0600e-07 - accuracy: 1.0000 - val_loss: 14.0538 - val_accuracy: 0.3934
# Epoch 911/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.0372e-07 - accuracy: 1.0000 - val_loss: 14.0552 - val_accuracy: 0.3907
# Epoch 912/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.0184e-07 - accuracy: 1.0000 - val_loss: 14.0650 - val_accuracy: 0.3907
# Epoch 913/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.0029e-07 - accuracy: 1.0000 - val_loss: 14.0689 - val_accuracy: 0.3907
# Epoch 914/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 9.8499e-08 - accuracy: 1.0000 - val_loss: 14.0706 - val_accuracy: 0.3907
# Epoch 915/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 9.6623e-08 - accuracy: 1.0000 - val_loss: 14.0779 - val_accuracy: 0.3907
# Epoch 916/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 9.4829e-08 - accuracy: 1.0000 - val_loss: 14.0830 - val_accuracy: 0.3907
# Epoch 917/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 9.3035e-08 - accuracy: 1.0000 - val_loss: 14.0846 - val_accuracy: 0.3907
# Epoch 918/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 9.1731e-08 - accuracy: 1.0000 - val_loss: 14.0949 - val_accuracy: 0.3907
# Epoch 919/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 8.9529e-08 - accuracy: 1.0000 - val_loss: 14.0923 - val_accuracy: 0.3907
# Epoch 920/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 8.8225e-08 - accuracy: 1.0000 - val_loss: 14.0981 - val_accuracy: 0.3907
# Epoch 921/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 8.6023e-08 - accuracy: 1.0000 - val_loss: 14.1053 - val_accuracy: 0.3907
# Epoch 922/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 8.4474e-08 - accuracy: 1.0000 - val_loss: 14.1110 - val_accuracy: 0.3934
# Epoch 923/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 8.3903e-08 - accuracy: 1.0000 - val_loss: 14.1129 - val_accuracy: 0.3934
# Epoch 924/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 8.2272e-08 - accuracy: 1.0000 - val_loss: 14.1189 - val_accuracy: 0.3934
# Epoch 925/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 8.0071e-08 - accuracy: 1.0000 - val_loss: 14.1196 - val_accuracy: 0.3934
# Epoch 926/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 7.8522e-08 - accuracy: 1.0000 - val_loss: 14.1255 - val_accuracy: 0.3934
# Epoch 927/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 7.7462e-08 - accuracy: 1.0000 - val_loss: 14.1257 - val_accuracy: 0.3934
# Epoch 928/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 7.5994e-08 - accuracy: 1.0000 - val_loss: 14.1256 - val_accuracy: 0.3934
# Epoch 929/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 7.4771e-08 - accuracy: 1.0000 - val_loss: 14.1298 - val_accuracy: 0.3934
# Epoch 930/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 7.3385e-08 - accuracy: 1.0000 - val_loss: 14.1314 - val_accuracy: 0.3907
# Epoch 931/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 7.1917e-08 - accuracy: 1.0000 - val_loss: 14.1363 - val_accuracy: 0.3934
# Epoch 932/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 7.1346e-08 - accuracy: 1.0000 - val_loss: 14.1476 - val_accuracy: 0.3907
# Epoch 933/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 6.9471e-08 - accuracy: 1.0000 - val_loss: 14.1497 - val_accuracy: 0.3934
# Epoch 934/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7595e-08 - accuracy: 1.0000 - val_loss: 14.1531 - val_accuracy: 0.3934
# Epoch 935/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 6.7269e-08 - accuracy: 1.0000 - val_loss: 14.1592 - val_accuracy: 0.3934
# Epoch 936/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 6.6535e-08 - accuracy: 1.0000 - val_loss: 14.1579 - val_accuracy: 0.3934
# Epoch 937/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 6.4171e-08 - accuracy: 1.0000 - val_loss: 14.1702 - val_accuracy: 0.3934
# Epoch 938/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 6.2703e-08 - accuracy: 1.0000 - val_loss: 14.1722 - val_accuracy: 0.3934
# Epoch 939/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 6.1398e-08 - accuracy: 1.0000 - val_loss: 14.1742 - val_accuracy: 0.3934
# Epoch 940/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 6.0175e-08 - accuracy: 1.0000 - val_loss: 14.1897 - val_accuracy: 0.3934
# Epoch 941/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 5.9360e-08 - accuracy: 1.0000 - val_loss: 14.1888 - val_accuracy: 0.3934
# Epoch 942/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 5.8545e-08 - accuracy: 1.0000 - val_loss: 14.1944 - val_accuracy: 0.3934
# Epoch 943/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 5.7403e-08 - accuracy: 1.0000 - val_loss: 14.1997 - val_accuracy: 0.3934
# Epoch 944/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 5.6832e-08 - accuracy: 1.0000 - val_loss: 14.2003 - val_accuracy: 0.3934
# Epoch 945/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 5.6017e-08 - accuracy: 1.0000 - val_loss: 14.2162 - val_accuracy: 0.3934
# Epoch 946/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 5.4060e-08 - accuracy: 1.0000 - val_loss: 14.2193 - val_accuracy: 0.3934
# Epoch 947/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 5.3000e-08 - accuracy: 1.0000 - val_loss: 14.2193 - val_accuracy: 0.3934
# Epoch 948/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 5.1206e-08 - accuracy: 1.0000 - val_loss: 14.2272 - val_accuracy: 0.3934
# Epoch 949/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 5.1043e-08 - accuracy: 1.0000 - val_loss: 14.2348 - val_accuracy: 0.3934
# Epoch 950/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.9983e-08 - accuracy: 1.0000 - val_loss: 14.2352 - val_accuracy: 0.3934
# Epoch 951/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 4.9086e-08 - accuracy: 1.0000 - val_loss: 14.2439 - val_accuracy: 0.3934
# Epoch 952/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 4.7700e-08 - accuracy: 1.0000 - val_loss: 14.2490 - val_accuracy: 0.3934
# Epoch 953/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.7374e-08 - accuracy: 1.0000 - val_loss: 14.2449 - val_accuracy: 0.3934
# Epoch 954/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 4.5906e-08 - accuracy: 1.0000 - val_loss: 14.2608 - val_accuracy: 0.3934
# Epoch 955/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 4.5417e-08 - accuracy: 1.0000 - val_loss: 14.2624 - val_accuracy: 0.3934
# Epoch 956/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 4.4194e-08 - accuracy: 1.0000 - val_loss: 14.2699 - val_accuracy: 0.3934
# Epoch 957/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.3134e-08 - accuracy: 1.0000 - val_loss: 14.2718 - val_accuracy: 0.3934
# Epoch 958/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 4.1992e-08 - accuracy: 1.0000 - val_loss: 14.2787 - val_accuracy: 0.3962
# Epoch 959/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 4.0932e-08 - accuracy: 1.0000 - val_loss: 14.2835 - val_accuracy: 0.3962
# Epoch 960/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 4.0117e-08 - accuracy: 1.0000 - val_loss: 14.2882 - val_accuracy: 0.3962
# Epoch 961/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 3.9383e-08 - accuracy: 1.0000 - val_loss: 14.2883 - val_accuracy: 0.3962
# Epoch 962/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 3.8894e-08 - accuracy: 1.0000 - val_loss: 14.3016 - val_accuracy: 0.3962
# Epoch 963/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.7426e-08 - accuracy: 1.0000 - val_loss: 14.3039 - val_accuracy: 0.3962
# Epoch 964/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.6366e-08 - accuracy: 1.0000 - val_loss: 14.3054 - val_accuracy: 0.3962
# Epoch 965/1000
# 46/46 [==============================] - 0s 5ms/step - loss: 3.5714e-08 - accuracy: 1.0000 - val_loss: 14.3166 - val_accuracy: 0.3962
# Epoch 966/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.4654e-08 - accuracy: 1.0000 - val_loss: 14.3237 - val_accuracy: 0.3962
# Epoch 967/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 3.4246e-08 - accuracy: 1.0000 - val_loss: 14.3306 - val_accuracy: 0.3962
# Epoch 968/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 3.2778e-08 - accuracy: 1.0000 - val_loss: 14.3358 - val_accuracy: 0.3962
# Epoch 969/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.2126e-08 - accuracy: 1.0000 - val_loss: 14.3487 - val_accuracy: 0.3962
# Epoch 970/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 3.1882e-08 - accuracy: 1.0000 - val_loss: 14.3528 - val_accuracy: 0.3962
# Epoch 971/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 3.0251e-08 - accuracy: 1.0000 - val_loss: 14.3522 - val_accuracy: 0.3962
# Epoch 972/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 2.9843e-08 - accuracy: 1.0000 - val_loss: 14.3653 - val_accuracy: 0.3962
# Epoch 973/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 3.0006e-08 - accuracy: 1.0000 - val_loss: 14.3668 - val_accuracy: 0.3962
# Epoch 974/1000
# 46/46 [==============================] - 0s 4ms/step - loss: 2.8212e-08 - accuracy: 1.0000 - val_loss: 14.3772 - val_accuracy: 0.3962
# Epoch 975/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.8212e-08 - accuracy: 1.0000 - val_loss: 14.3798 - val_accuracy: 0.3962
# Epoch 976/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.7560e-08 - accuracy: 1.0000 - val_loss: 14.3926 - val_accuracy: 0.3962
# Epoch 977/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.6418e-08 - accuracy: 1.0000 - val_loss: 14.4019 - val_accuracy: 0.3962
# Epoch 978/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.5685e-08 - accuracy: 1.0000 - val_loss: 14.4042 - val_accuracy: 0.3962
# Epoch 979/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.4625e-08 - accuracy: 1.0000 - val_loss: 14.4096 - val_accuracy: 0.3934
# Epoch 980/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.4625e-08 - accuracy: 1.0000 - val_loss: 14.4111 - val_accuracy: 0.3934
# Epoch 981/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.4135e-08 - accuracy: 1.0000 - val_loss: 14.4204 - val_accuracy: 0.3934
# Epoch 982/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.3728e-08 - accuracy: 1.0000 - val_loss: 14.4221 - val_accuracy: 0.3934
# Epoch 983/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.2994e-08 - accuracy: 1.0000 - val_loss: 14.4233 - val_accuracy: 0.3934
# Epoch 984/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.2178e-08 - accuracy: 1.0000 - val_loss: 14.4406 - val_accuracy: 0.3934
# Epoch 985/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.1852e-08 - accuracy: 1.0000 - val_loss: 14.4322 - val_accuracy: 0.3934
# Epoch 986/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1363e-08 - accuracy: 1.0000 - val_loss: 14.4422 - val_accuracy: 0.3934
# Epoch 987/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.1037e-08 - accuracy: 1.0000 - val_loss: 14.4564 - val_accuracy: 0.3934
# Epoch 988/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 2.0548e-08 - accuracy: 1.0000 - val_loss: 14.4642 - val_accuracy: 0.3934
# Epoch 989/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 2.0385e-08 - accuracy: 1.0000 - val_loss: 14.4703 - val_accuracy: 0.3934
# Epoch 990/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.9569e-08 - accuracy: 1.0000 - val_loss: 14.4809 - val_accuracy: 0.3934
# Epoch 991/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.8754e-08 - accuracy: 1.0000 - val_loss: 14.4792 - val_accuracy: 0.3934
# Epoch 992/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.7938e-08 - accuracy: 1.0000 - val_loss: 14.4960 - val_accuracy: 0.3934
# Epoch 993/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.8020e-08 - accuracy: 1.0000 - val_loss: 14.4975 - val_accuracy: 0.3934
# Epoch 994/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.7123e-08 - accuracy: 1.0000 - val_loss: 14.5134 - val_accuracy: 0.3934
# Epoch 995/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.6960e-08 - accuracy: 1.0000 - val_loss: 14.5199 - val_accuracy: 0.3934
# Epoch 996/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.6226e-08 - accuracy: 1.0000 - val_loss: 14.5279 - val_accuracy: 0.3934
# Epoch 997/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.5003e-08 - accuracy: 1.0000 - val_loss: 14.5447 - val_accuracy: 0.3934
# Epoch 998/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.4840e-08 - accuracy: 1.0000 - val_loss: 14.5440 - val_accuracy: 0.3934
# Epoch 999/1000
# 46/46 [==============================] - 0s 3ms/step - loss: 1.4269e-08 - accuracy: 1.0000 - val_loss: 14.5493 - val_accuracy: 0.3934
# Epoch 1000/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 1.4351e-08 - accuracy: 1.0000 - val_loss: 14.5618 - val_accuracy: 0.3934
# KerasClassifier(
# 	model=None
# 	build_fn=<function build_model at 0x7ff66e74bac0>
# 	warm_start=False
# 	random_state=None
# 	optimizer=rmsprop
# 	loss=None
# 	metrics=None
# 	batch_size=None
# 	validation_batch_size=None
# 	verbose=1
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=1
# 	class_weight=None
# )

# %% [markdown]
# Questa istruzione addestra il modello clf sui dati di addestramento X_train e y_train per 1000 epoche con una suddivisione del 20% dei dati di addestramento per la validazione. Ciò significa che il modello viene addestrato su 80% dei dati di addestramento e poi valutato sulla restante 20% per ogni epoca. Durante l'addestramento, il modello cerca di minimizzare la funzione di perdita e aggiornare i pesi dei suoi strati per migliorare la precisione delle previsioni sul set di addestramento. L'output di questa istruzione è un oggetto history contenente i valori della funzione di perdita e della precisione del modello durante l'addestramento e la validazione per ogni epoca.

# %%
y_pred = clf8.predict(X_test).astype(int)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

# %% [markdown]
# Questo codice utilizza il classificatore Keras precedentemente addestrato per fare delle previsioni sui dati di test X_test. Le previsioni vengono salvate in y_pred.
#
# Successivamente, il codice stampa la precisione (accuracy), il punteggio F1 (F1-score) e una relazione di classificazione (classification report) per le previsioni fatte dal modello. La precisione rappresenta la percentuale di istanze correttamente classificate rispetto al numero totale di istanze nel set di test. Il punteggio F1 rappresenta la media armonica tra precisione e richiamo (recall) per ciascuna classe. Il report di classificazione fornisce ulteriori metriche di valutazione come precisione, richiamo e supporto per ciascuna classe.

# %%
plt.plot(history['loss'], label='Train')
plt.plot(history['val_loss'], label='Val')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy')
plt.legend()
plt.show()

# %%
plt.plot(history['accuracy'], label='Train')
plt.plot(history['val_accuracy'], label='Val')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy')
plt.legend()
plt.show()

# %% [markdown]
# #EARLY STOPPING

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# testo con model 1

# %%
es = EarlyStopping(monitor='val_accuracy', patience=50, verbose=True)
mc = ModelCheckpoint('best_model_NOREG.h5', monitor='val_accuracy', save_best_only=True)

clf9 = KerasClassifier(build_model_1, callbacks=[es, mc])
history4 = model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100,
                      batch_size=10, callbacks=[es,mc]).history
# Out:
# <ipython-input-36-129555fec7a8>:4: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   clf = KerasClassifier(build_model_1, callbacks=[es, mc])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-129555fec7a8> in <cell line: 5>()
#       3
#       4 clf = KerasClassifier(build_model_1, callbacks=[es, mc])
# ----> 5 history4 = model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100,
#       6                       batch_size=10, callbacks=[es,mc]).history
#
# NameError: name 'X_val' is not defined

# %%
test_loss_4, test_acc_4 = clf9.evaluate(X_test, y_test)

print('Loss %f, Accuracy %f' % (test_loss_1, test_acc_1))
print('Loss %f, Accuracy %f' % (test_loss_2, test_acc_2))
print('Loss %f, Accuracy %f' % (test_loss_3, test_acc_3))
print('Loss %f, Accuracy %f' % (test_loss_4, test_acc_4))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-427b849b26ca> in <cell line: 1>()
# ----> 1 test_loss_4, test_acc_4 = clf.evaluate(X_test, y_test)
#       2
#       3 print('Loss %f, Accuracy %f' % (test_loss_1, test_acc_1))
#       4 print('Loss %f, Accuracy %f' % (test_loss_2, test_acc_2))
#       5 print('Loss %f, Accuracy %f' % (test_loss_3, test_acc_3))
#
# AttributeError: 'KerasClassifier' object has no attribute 'evaluate'

# %% [markdown]
# In questo codice, stiamo definendo una nuova istanza di EarlyStopping e una di ModelCheckpoint, due callbacks di Keras che verranno utilizzati durante l'addestramento del modello.
#
# L'istanza di EarlyStopping viene utilizzata per interrompere l'addestramento quando la metrica monitorata (in questo caso "val_accuracy", l'accuratezza sul set di validazione) smette di migliorare per un certo numero di epoche consecutive (in questo caso 50), in modo da evitare di continuare ad addestrare un modello che sta iniziando a overfitting.
#
# L'istanza di ModelCheckpoint viene utilizzata per salvare il modello con la migliore accuratezza sul set di validazione durante l'addestramento (in questo caso nel file "best_model_NOREG.h5"), in modo da poterlo poi utilizzare per fare previsioni su nuovi dati.
#
# Infine, stiamo definendo un nuovo classificatore Keras, che utilizza la funzione build_model definita in precedenza e viene configurato per utilizzare le callbacks EarlyStopping e ModelCheckpoint.

# %%
clf9.fit(X_train, y_train, validation_split=0.2, epochs=500)

# %%
y_pred = clf9.predict(X_test).astype(int)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

# %% [markdown]
# ##L2 REGULARIZATION

# %%
from keras.regularizers import l2, l1

def build_L2_model():
    model = Sequential()


    n_feature = X_train.shape[1]
    model.add(Dense(7, activation='relu', input_shape=(n_feature,), kernel_regularizer=l2(0.01)))
    model.add(Dense(5, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(Dense(3, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(Dense(1, activation='sigmoid', kernel_regularizer=l2(0.01)))


    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['F1'])

    return model

# %% [markdown]
# La funzione build_L2_model() definisce un modello di rete neurale artificiale con regolarizzazione L2 (Ridge Regression) per evitare l'overfitting. In questo modello, ci sono quattro strati nascosti, ciascuno con 100 nodi con funzione di attivazione ReLU. Viene anche aggiunto un layer di output con un numero di nodi uguale al numero di classi da predire. La funzione di attivazione del layer di output è l'identità.
#
# La regolarizzazione L2 viene applicata al primo strato nascosto utilizzando il parametro kernel_regularizer che viene impostato su l2(0.001). Ciò significa che viene aggiunto un termine di regolarizzazione L2 alla funzione di perdita della rete, con un fattore di regolarizzazione di 0.001, che punisce i pesi elevati nella funzione di perdita, in modo che il modello appreso da dati di addestramento generalizzi meglio su nuovi dati di test.

# %%
mc = ModelCheckpoint('best_model_L2.h5', monitor='val_accuracy', save_best_only=True)

L2_model = KerasClassifier(build_L2_model, callbacks=[es,mc])
L2_model.fit(X_train, y_train, validation_split=0.2, epochs=500)
# Out:
# Epoch 1/500
# <ipython-input-47-0858c7534878>:3: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   L2_model = KerasClassifier(build_L2_model, callbacks=[es,mc])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-0858c7534878> in <cell line: 4>()
#       2
#       3 L2_model = KerasClassifier(build_L2_model, callbacks=[es,mc])
# ----> 4 L2_model.fit(X_train, y_train, validation_split=0.2, epochs=500)
#
# /usr/local/lib/python3.10/dist-packages/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     246             raise ValueError("Invalid shape for y: " + str(y.shape))
#     247         self.n_classes_ = len(self.classes_)
# --> 248         return super().fit(x, y, **kwargs)
#     249
#     250     def predict(self, x, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     173         fit_args.update(kwargs)
#     174
# --> 175         history = self.model.fit(x, y, **fit_args)
#     176
#     177         return history
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1284, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1268, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1249, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1055, in train_step
#         return self.compute_metrics(x, y, y_pred, sample_weight)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1149, in compute_metrics
#         self.compiled_metrics.update_state(y, y_pred, sample_weight)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/compile_utils.py", line 577, in update_state
#         self.build(y_pred, y_true)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/compile_utils.py", line 483, in build
#         self._metrics = tf.__internal__.nest.map_structure_up_to(
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/compile_utils.py", line 631, in _get_metric_objects
#         return [self._get_metric_object(m, y_t, y_p) for m in metrics]
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/compile_utils.py", line 631, in <listcomp>
#         return [self._get_metric_object(m, y_t, y_p) for m in metrics]
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/compile_utils.py", line 650, in _get_metric_object
#         metric_obj = metrics_mod.get(metric)
#     File "/usr/local/lib/python3.10/dist-packages/keras/metrics/__init__.py", line 204, in get
#         return deserialize(str(identifier))
#     File "/usr/local/lib/python3.10/dist-packages/keras/metrics/__init__.py", line 158, in deserialize
#         return deserialize_keras_object(
#     File "/usr/local/lib/python3.10/dist-packages/keras/saving/legacy/serialization.py", line 543, in deserialize_keras_object
#         raise ValueError(
#
#     ValueError: Unknown metric function: 'F1'. Please ensure you are using a `keras.utils.custom_object_scope` and that this object is included in the scope. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.

# %% [markdown]
# Questo codice addestra un modello di rete neurale con una regolarizzazione L2. La regolarizzazione L2 è una tecnica di regolarizzazione che consiste nell'aggiungere un termine di penalità alla funzione di perdita del modello. In questo caso, viene definito un modello che utilizza la regolarizzazione L2 con un valore di regolarizzazione pari a 0.001.
#
# Viene poi creato un oggetto ModelCheckpoint che salverà solo il modello con la migliore accuratezza sulla validation set. Successivamente, il modello viene creato utilizzando il costruttore KerasClassifier, che avvolge il modello definito in build_L2_model in un oggetto scikit-learn compatibile. Infine, il modello viene addestrato utilizzando i dati di addestramento e di validation forniti da X_train e y_train con una suddivisione del 20% dei dati di addestramento utilizzati come validation set. Viene usata una EarlyStopping per fermare l'addestramento del modello quando la performance del modello smette di migliorare.

# %%
history = L2_model.history_
plt.plot(history['loss'], label='Train')
plt.plot(history['val_loss'], label='Val')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-9d114011c20c> in <cell line: 1>()
# ----> 1 history = L2_model.history_
#       2 plt.plot(history['loss'], label='Train')
#       3 plt.plot(history['val_loss'], label='Val')
#       4 plt.xlabel('Epochs')
#       5 plt.ylabel('Cross-Entropy')
#
# AttributeError: 'KerasClassifier' object has no attribute 'history_'

# %% [markdown]
# Il codice sopra plotta la curva di training e di validation della cross-entropy in base alle epoche durante l'addestramento della rete neurale con regolarizzazione L2. La funzione plt.plot() viene utilizzata per tracciare i valori della perdita di addestramento e di validazione nel corso delle epoche sull'asse y, mentre l'asse x rappresenta il numero di epoche. La funzione plt.xlabel() e plt.ylabel() vengono utilizzate per aggiungere le etichette degli assi x e y rispettivamente. Infine, la funzione plt.legend() viene utilizzata per mostrare una legenda che differenzia le curve di addestramento e validazione.

# %%
plt.plot(history['accuracy'], label='Train')
plt.plot(history['val_accuracy'], label='Val')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ##DROP OUT

# %% [markdown]
# Il dropout è una tecnica di regolarizzazione utilizzata durante l'addestramento di reti neurali. Durante il dropout, alcune unità di output (cioè neuroni) sono casualmente escluse dal processo di apprendimento in modo da ridurre l'overfitting. In pratica, durante l'addestramento, ogni volta che viene eseguita una propagazione in avanti attraverso la rete, alcuni neuroni vengono selezionati casualmente e temporaneamente "disattivati" (ovvero impostati a zero) con una certa probabilità. Questa tecnica aumenta la robustezza e la generalizzazione della rete neurale, impedendole di concentrarsi troppo sui singoli esempi di addestramento e di imparare in modo più generale i pattern dei dati di addestramento.

# %%
from keras.layers import Dropout

def build_DROPOUT_model():
    # define the model
    model = Sequential()

    n_feature = X_train.shape[1]
    h_dim=100
    model.add(Dense(7, activation='relu', input_shape=(n_feature,)))
    model.add(Dropout(0.2))
    model.add(Dense(5, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(3, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='sigmoid'))

    #compile the model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['F1'])

    return model

# %% [markdown]
# Questo codice definisce una nuova architettura di rete neurale che utilizza anche la regolarizzazione Dropout.
# La funzione build_DROPOUT_model() definisce il modello sequenziale con una serie di strati Dense con attivazione 'relu', a cui segue uno strato Dropout.
# In questo caso, lo strato Dropout viene aggiunto dopo il terzo strato Dense con l'obiettivo di ridurre l'overfitting.
# Infine, viene definito uno strato Dense di uscita con attivazione lineare e viene compilato il modello con la funzione di loss 'sparse_categorical_crossentropy' e l'ottimizzatore 'adam'.
#
# h_dim è il numero di unità (neuroni) nella hidden layer.
#
# activation='relu' indica che la funzione di attivazione utilizzata per questa layer è la ReLU.
#
# input_shape=(n_feature,) indica la forma dell'input (ovvero il numero di features) che viene dato in input alla prima hidden layer. In questo caso, (n_feature,) indica che l'input è un vettore di n_feature features.

# %%
mc = ModelCheckpoint('best_model_DROPOUT.h5', monitor='val_accuracy', save_best_only=True)

DROPOUT_model = KerasClassifier(build_DROPOUT_model, callbacks=[es,mc])
DROPOUT_model.fit(X_train, y_train, validation_split=0.2, epochs=500)
# Out:
# Epoch 1/500
# <ipython-input-50-9daf620c6ca8>:3: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   DROPOUT_model = KerasClassifier(build_DROPOUT_model, callbacks=[es,mc])
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return dispatch_target(*args, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-9daf620c6ca8> in <cell line: 4>()
#       2
#       3 DROPOUT_model = KerasClassifier(build_DROPOUT_model, callbacks=[es,mc])
# ----> 4 DROPOUT_model.fit(X_train, y_train, validation_split=0.2, epochs=500)
#
# /usr/local/lib/python3.10/dist-packages/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     246             raise ValueError("Invalid shape for y: " + str(y.shape))
#     247         self.n_classes_ = len(self.classes_)
# --> 248         return super().fit(x, y, **kwargs)
#     249
#     250     def predict(self, x, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     173         fit_args.update(kwargs)
#     174
# --> 175         history = self.model.fit(x, y, **fit_args)
#     176
#     177         return history
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1284, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1268, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1249, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1051, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1109, in compute_loss
#         return self.compiled_loss(
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/compile_utils.py", line 265, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/usr/local/lib/python3.10/dist-packages/keras/losses.py", line 142, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/usr/local/lib/python3.10/dist-packages/keras/losses.py", line 268, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/losses.py", line 1984, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "/usr/local/lib/python3.10/dist-packages/keras/backend.py", line 5559, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 8) and (None, 1) are incompatible

# %%
mc = ModelCheckpoint('best_model_DROPOUT.h5', monitor='val_loss', save_best_only=True)

DROPOUT_model = build_DROPOUT_model()
h_DROPOUT = DROPOUT_model.fit(X_train, y_train, validation_data=(X_val, y_val),
                              epochs=1000, batch_size=10, callbacks=[es,mc]).history

                #MODELLO DI CAVALIERI
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-15aab38986dc> in <cell line: 4>()
#       2
#       3 DROPOUT_model = build_DROPOUT_model()
# ----> 4 h_DROPOUT = DROPOUT_model.fit(X_train, y_train, validation_data=(X_val, y_val),
#       5                               epochs=1000, batch_size=10, callbacks=[es,mc]).history
#       6
#
# NameError: name 'X_val' is not defined

# %%
print('Loss %f, Accuracy %f' % (loss_NOREG, acc_NOREG))
print('Loss %f, Accuracy %f' % (loss_L2, acc_L2))
print('Loss %f, Accuracy %f' % (loss_DROPOUT, acc_DROPOUT))

    #MODELLO DI CAVALIERI
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-87e399ff93a6> in <cell line: 1>()
# ----> 1 print('Loss %f, Accuracy %f' % (loss_NOREG, acc_NOREG))
#       2 print('Loss %f, Accuracy %f' % (loss_L2, acc_L2))
#       3 print('Loss %f, Accuracy %f' % (loss_DROPOUT, acc_DROPOUT))
#       4
#       5     #MODELLO DI CAVALIERI
#
# NameError: name 'loss_NOREG' is not defined

# %% [markdown]
# In questo codice si sta costruendo una nuova architettura di rete neurale chiamata "DROPOUT_model". La principale differenza rispetto alle reti neurali precedenti è l'utilizzo del layer di Dropout, che ha lo scopo di ridurre l'overfitting della rete.
#
# In particolare, la funzione "build_DROPOUT_model" costruisce la rete neurale aggiungendo un layer di Dropout dopo il terzo layer completamente connesso, con un tasso di dropout del 10%. Il resto della rete neurale è simile a quella costruita in precedenza, con tre layer completamente connessi di 100 unità ciascuno.
#
# In seguito, si utilizza la classe "KerasClassifier" per creare un'istanza del modello appena costruito. Si utilizzano gli stessi callback utilizzati in precedenza, vale a dire "EarlyStopping" e "ModelCheckpoint", per monitorare l'accuratezza del modello sulla validation set e salvare solo il modello che fornisce la migliore accuratezza sul validation set.
#
# Infine, si addestra il modello utilizzando il metodo "fit" sulla porzione di training set, specificando una validation split del 20% e un massimo di 500 epoche.

# %%
history = DROPOUT_model.history_
plt.plot(history['loss'], label='Train')
plt.plot(history['val_loss'], label='Val')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-92bc0f44b237> in <cell line: 1>()
# ----> 1 history = DROPOUT_model.history_
#       2 plt.plot(history['loss'], label='Train')
#       3 plt.plot(history['val_loss'], label='Val')
#       4 plt.xlabel('Epochs')
#       5 plt.ylabel('Cross-Entropy')
#
# AttributeError: 'Sequential' object has no attribute 'history_'

# %%
plt.plot(history['accuracy'], label='Train')
plt.plot(history['val_accuracy'], label='Val')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ##MODEL COMPARISON

# %%
# laod best models and test them
from keras.models import load_model

best_NOREG_model = load_model('best_model_NOREG.h5')
best_L2_model = load_model('best_model_L2.h5')
best_DROPOUT_model = load_model('best_model_DROPOUT.h5')

loss_NOREG, acc_NOREG = best_NOREG_model.evaluate(X_test, y_test)
loss_L2, acc_L2 = best_L2_model.evaluate(X_test, y_test)
loss_DROPOUT, acc_DROPOUT = best_DROPOUT_model.evaluate(X_test, y_test)

# %% [markdown]
# Certo, ecco una spiegazione riga per riga del codice:
#
# 1. Viene importata la funzione `load_model` dal modulo `models` di Keras.
# 2. Viene caricato il modello migliore ottenuto senza l'utilizzo di regolarizzazione l2 e salvato come file `best_model_NOREG.h5`.
# 3. Viene caricato il modello migliore ottenuto con l'utilizzo di regolarizzazione l2 e salvato come file `best_model_L2.h5`.
# 4. Viene caricato il modello migliore ottenuto con l'utilizzo di dropout e salvato come file `best_model_DROPOUT.h5`.
# 5. Vengono calcolati i valori di loss e accuracy per il modello `best_NOREG_model` usando il metodo `evaluate` con i dati di test `X_test` e `y_test`.
# 6. Vengono calcolati i valori di loss e accuracy per il modello `best_L2_model` usando il metodo `evaluate` con i dati di test `X_test` e `y_test`.
# 7. Vengono calcolati i valori di loss e accuracy per il modello `best_DROPOUT_model` usando il metodo `evaluate` con i dati di test `X_test` e `y_test`.
#
# In sostanza, questo codice serve per valutare le prestazioni dei tre modelli migliori ottenuti durante il training: il modello senza regolarizzazione, il modello con regolarizzazione L2 e il modello con dropout. In particolare, viene valutata l'accuratezza (accuracy) e la perdita (loss) di ciascuno di questi modelli sui dati di test, che rappresentano dati mai visti durante il training e quindi servono per valutare la capacità di generalizzazione dei modelli.

# %%
print('Loss %f, Accuracy %f' % (loss_NOREG, acc_NOREG))
print('Loss %f, Accuracy %f' % (loss_L2, acc_L2))
print('Loss %f, Accuracy %f' % (loss_DROPOUT, acc_DROPOUT))

# %% [markdown]
# #HYPER-PARAMETER TUNING

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
def build_model(meta, hidden_layer_sizes, activation):
    n_features_in_ = meta["n_features_in_"]
    n_classes_ = meta["n_classes_"]
    model = keras.models.Sequential()
    model.add(keras.layers.Input(shape=(n_features_in_,)))
    for hidden_layer_size in hidden_layer_sizes:
        model.add(keras.layers.Dense(hidden_layer_size, activation=activation))
    model.add(keras.layers.Dense(n_classes_, activation="softmax"))
    return model

# %% [markdown]
# Certo, ecco una spiegazione riga per riga del codice:
#
# - `def build_model(meta, hidden_layer_sizes, activation):` Inizia la definizione di una funzione chiamata `build_model`, che ha tre parametri di input: `meta`, `hidden_layer_sizes`, e `activation`.
#
# - `n_features_in_ = meta["n_features_in_"]` Questa riga estrae il valore `n_features_in_` dal dizionario `meta` che è stato passato come input alla funzione e lo assegna alla variabile `n_features_in_`.
#
# - `n_classes_ = meta["n_classes_"]` Questa riga estrae il valore `n_classes_` dal dizionario `meta` che è stato passato come input alla funzione e lo assegna alla variabile `n_classes_`.
#
# - `model = keras.models.Sequential()` Questa riga crea un oggetto `Sequential` di Keras, che rappresenta un modello di rete neurale sequenziale.
#
# - `model.add(keras.layers.Input(shape=(n_features_in_,)))` Questa riga aggiunge un layer di input alla rete neurale con il numero di input corrispondente a `n_features_in_`.
#
# - `for hidden_layer_size in hidden_layer_sizes:` Questa riga inizia un ciclo `for` che scorre tutti gli elementi della lista `hidden_layer_sizes` che è stata passata come parametro di input.
#
# - `model.add(keras.layers.Dense(hidden_layer_size, activation=activation))` Questa riga aggiunge un layer denso alla rete neurale con il numero di neuroni specificato dal parametro `hidden_layer_size` e la funzione di attivazione specificata dal parametro `activation`.
#
# - `model.add(keras.layers.Dense(n_classes_, activation="softmax"))` Questa riga aggiunge un ultimo layer denso alla rete neurale con il numero di neuroni corrispondente al numero di classi e una funzione di attivazione softmax, che produce una distribuzione di probabilità sulle classi.
#
# - `return model` Questa riga termina la definizione della funzione e restituisce l'oggetto `Sequential` creato all'inizio della funzione.
#
# `hidden_layer_sizes` indica l'elenco delle dimensioni dei livelli nascosti del modello, mentre `activation` specifica la funzione di attivazione da utilizzare in ogni livello nascosto.
#
# Nel codice, l'elenco delle dimensioni dei livelli nascosti viene utilizzato in un ciclo `for` per aggiungere i livelli nascosti al modello, mentre la funzione di attivazione viene specificata come parametro per ogni livello nascosto.
#
# In sostanza, `hidden_layer_sizes` e `activation` sono iperparametri del modello che possono essere regolati per ottimizzare le prestazioni del modello durante la fase di addestramento.

# %%
clf10= KerasClassifier(
    model=build_model,
    loss="sparse_categorical_crossentropy",
    verbose=False
)

# %%
# %%time
params = {
    'optimizer__learning_rate': [0.001, 0.01, 0.1, 1],
    'model__hidden_layer_sizes': [(100, 100, 100), (50, 50, 50), (10, 10, 10),
                                  (100, 50, 10), (10, 10, 10), (10, 10)],
    'model__activation': ['relu', 'tanh'],
    'optimizer': ["adam", "sgd"],
    'epochs': [10, 50, 100, 200]
}

gs = RandomizedSearchCV(clf10, params, scoring='accuracy', n_jobs=-1, verbose=True, n_iter=15, cv=3)

# %% [markdown]
# In questo codice stiamo definendo i parametri da utilizzare nella RandomizedSearchCV. In particolare:
#
# - `optimizer__learning_rate`: definisce una lista di valori di learning rate da testare per l'ottimizzatore;
# - `model__hidden_layer_sizes`: definisce una lista di tuple che rappresentano il numero di neuroni in ciascun strato nascosto della rete neurale;
# - `model__activation`: definisce una lista di funzioni di attivazione da testare;
# - `optimizer`: definisce una lista di ottimizzatori da testare;
# - `epochs`: definisce una lista di valori per il numero di epoche da utilizzare.
#
# Infine, viene creata una RandomizedSearchCV con i seguenti parametri:
#
# - `clf`: rappresenta l'oggetto KerasClassifier che abbiamo definito in precedenza;
# - `params`: rappresenta la lista di parametri da testare;
# - `scoring`: definisce la metrica di valutazione da utilizzare per scegliere il miglior modello;
# - `n_jobs`: definisce il numero di processi da utilizzare in parallelo (-1 significa utilizzare tutti i processori disponibili);
# - `verbose`: definisce il livello di dettaglio degli output durante l'esecuzione della ricerca;
# - `n_iter`: definisce il numero di combinazioni di parametri da testare;
# - `cv`: definisce la strategia di cross-validation da utilizzare durante la ricerca.

# %%
# %%time
gs.fit(X_train, y_train)

print(gs.best_score_, gs.best_params_)

# %% [markdown]
# Il codice sopra esegue una ricerca casuale per trovare i migliori iperparametri per un modello di apprendimento automatico. La ricerca casuale viene effettuata su una griglia di possibili combinazioni di iperparametri definiti nel dizionario `params`.
#
# La funzione `RandomizedSearchCV` effettua la ricerca casuale su questa griglia per un numero di iterazioni specificato dalla variabile `n_iter`. Per ogni combinazione di iperparametri, il modello viene addestrato utilizzando la funzione `fit` sulla porzione di training del set di dati.
#
# La combinazione di iperparametri che restituisce il punteggio più alto sulla metrica specificata in `scoring` viene selezionata come la migliore combinazione di iperparametri. Il punteggio migliore e i parametri migliori vengono quindi stampati a schermo.

# %%
y_pred = gs.predict(X_test).astype(int)
#Questa riga di codice usa il modello addestrato gs per fare delle previsioni sul set di
#dati di test X_test e assegna le previsioni alla variabile y_pred. Inoltre, il metodo astype(int)
#converte i risultati delle previsioni in numeri interi. Questo è importante perché il tipo di dati
#della variabile y_test (che contiene le vere etichette delle classi) è probabilmente intero, quindi
#i risultati delle previsioni devono essere coerenti con quel tipo di dati per poter confrontare le
#previsioni con le etichette reali.
print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
def build_model():

    n_feature = X_train.shape[1]
    model = Sequential()
    model.add(Dense(7, input_dim=n_feature, activation='relu'))
    model.add(Dense(5, activation='relu'))
    model.add(Dense(3, activation='relu'))
    model.add(Dense(1,activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
model7 = build_model()

history1 = model7.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=10).history
# Out:
# Epoch 1/50
# 183/183 [==============================] - 2s 4ms/step - loss: -8.1413 - accuracy: 0.1526 - val_loss: -37.4963 - val_accuracy: 0.1538
# Epoch 2/50
# 183/183 [==============================] - 0s 3ms/step - loss: -105.0206 - accuracy: 0.1532 - val_loss: -370.3535 - val_accuracy: 0.1538
# Epoch 3/50
# 183/183 [==============================] - 1s 4ms/step - loss: -659.7632 - accuracy: 0.1532 - val_loss: -1824.6887 - val_accuracy: 0.1538
# Epoch 4/50
# 183/183 [==============================] - 1s 3ms/step - loss: -2446.7393 - accuracy: 0.1532 - val_loss: -5748.9707 - val_accuracy: 0.1538
# Epoch 5/50
# 183/183 [==============================] - 1s 4ms/step - loss: -6693.4219 - accuracy: 0.1532 - val_loss: -14237.5020 - val_accuracy: 0.1538
# Epoch 6/50
# 183/183 [==============================] - 1s 3ms/step - loss: -14862.9365 - accuracy: 0.1532 - val_loss: -29272.8359 - val_accuracy: 0.1538
# Epoch 7/50
# 183/183 [==============================] - 1s 3ms/step - loss: -28500.1426 - accuracy: 0.1532 - val_loss: -52720.1250 - val_accuracy: 0.1538
# Epoch 8/50
# 183/183 [==============================] - 1s 4ms/step - loss: -49084.5508 - accuracy: 0.1532 - val_loss: -87330.5547 - val_accuracy: 0.1538
# Epoch 9/50
# 183/183 [==============================] - 1s 4ms/step - loss: -78373.9453 - accuracy: 0.1532 - val_loss: -135023.0312 - val_accuracy: 0.1538
# Epoch 10/50
# 183/183 [==============================] - 1s 3ms/step - loss: -117796.3047 - accuracy: 0.1532 - val_loss: -196559.4688 - val_accuracy: 0.1538
# Epoch 11/50
# 183/183 [==============================] - 0s 3ms/step - loss: -168454.5781 - accuracy: 0.1532 - val_loss: -276169.2188 - val_accuracy: 0.1538
# Epoch 12/50
# 183/183 [==============================] - 0s 2ms/step - loss: -232140.6875 - accuracy: 0.1532 - val_loss: -374188.5938 - val_accuracy: 0.1538
# Epoch 13/50
# 183/183 [==============================] - 1s 3ms/step - loss: -309700.6875 - accuracy: 0.1532 - val_loss: -492208.4688 - val_accuracy: 0.1538
# Epoch 14/50
# 183/183 [==============================] - 1s 3ms/step - loss: -403445.6250 - accuracy: 0.1532 - val_loss: -631900.6875 - val_accuracy: 0.1538
# Epoch 15/50
# 183/183 [==============================] - 1s 3ms/step - loss: -514868.2500 - accuracy: 0.1532 - val_loss: -799202.1875 - val_accuracy: 0.1538
# Epoch 16/50
# 183/183 [==============================] - 0s 3ms/step - loss: -645455.1875 - accuracy: 0.1532 - val_loss: -992660.9375 - val_accuracy: 0.1538
# Epoch 17/50
# 183/183 [==============================] - 1s 3ms/step - loss: -796978.8750 - accuracy: 0.1532 - val_loss: -1217861.7500 - val_accuracy: 0.1538
# Epoch 18/50
# 183/183 [==============================] - 0s 2ms/step - loss: -976709.4375 - accuracy: 0.1532 - val_loss: -1486503.7500 - val_accuracy: 0.1538
# Epoch 19/50
# 183/183 [==============================] - 0s 2ms/step - loss: -1185829.3750 - accuracy: 0.1532 - val_loss: -1790195.7500 - val_accuracy: 0.1538
# Epoch 20/50
# 183/183 [==============================] - 1s 3ms/step - loss: -1424198.8750 - accuracy: 0.1532 - val_loss: -2137239.5000 - val_accuracy: 0.1538
# Epoch 21/50
# 183/183 [==============================] - 1s 3ms/step - loss: -1693112.2500 - accuracy: 0.1532 - val_loss: -2529599.5000 - val_accuracy: 0.1538
# Epoch 22/50
# 183/183 [==============================] - 1s 3ms/step - loss: -1994245.6250 - accuracy: 0.1532 - val_loss: -2958404.2500 - val_accuracy: 0.1538
# Epoch 23/50
# 183/183 [==============================] - 0s 2ms/step - loss: -2330944.0000 - accuracy: 0.1532 - val_loss: -3443763.2500 - val_accuracy: 0.1538
# Epoch 24/50
# 183/183 [==============================] - 1s 3ms/step - loss: -2701314.5000 - accuracy: 0.1532 - val_loss: -3973415.7500 - val_accuracy: 0.1538
# Epoch 25/50
# 183/183 [==============================] - 1s 3ms/step - loss: -3106707.5000 - accuracy: 0.1532 - val_loss: -4558199.5000 - val_accuracy: 0.1538
# Epoch 26/50
# 183/183 [==============================] - 1s 3ms/step - loss: -3552136.7500 - accuracy: 0.1532 - val_loss: -5188786.0000 - val_accuracy: 0.1538
# Epoch 27/50
# 183/183 [==============================] - 1s 5ms/step - loss: -4039995.7500 - accuracy: 0.1532 - val_loss: -5872438.0000 - val_accuracy: 0.1538
# Epoch 28/50
# 183/183 [==============================] - 1s 4ms/step - loss: -4569705.0000 - accuracy: 0.1532 - val_loss: -6627097.0000 - val_accuracy: 0.1538
# Epoch 29/50
# 183/183 [==============================] - 1s 3ms/step - loss: -5144991.5000 - accuracy: 0.1532 - val_loss: -7440129.5000 - val_accuracy: 0.1538
# Epoch 30/50
# 183/183 [==============================] - 1s 4ms/step - loss: -5765117.0000 - accuracy: 0.1532 - val_loss: -8312899.5000 - val_accuracy: 0.1538
# Epoch 31/50
# 183/183 [==============================] - 1s 3ms/step - loss: -6433632.5000 - accuracy: 0.1532 - val_loss: -9256603.0000 - val_accuracy: 0.1538
# Epoch 32/50
# 183/183 [==============================] - 1s 3ms/step - loss: -7151625.5000 - accuracy: 0.1532 - val_loss: -10265021.0000 - val_accuracy: 0.1538
# Epoch 33/50
# 183/183 [==============================] - 1s 3ms/step - loss: -7920049.0000 - accuracy: 0.1532 - val_loss: -11337786.0000 - val_accuracy: 0.1538
# Epoch 34/50
# 183/183 [==============================] - 1s 3ms/step - loss: -8743868.0000 - accuracy: 0.1532 - val_loss: -12499806.0000 - val_accuracy: 0.1538
# Epoch 35/50
# 183/183 [==============================] - 1s 3ms/step - loss: -9627780.0000 - accuracy: 0.1532 - val_loss: -13727453.0000 - val_accuracy: 0.1538
# Epoch 36/50
# 183/183 [==============================] - 0s 2ms/step - loss: -10570296.0000 - accuracy: 0.1532 - val_loss: -15043042.0000 - val_accuracy: 0.1538
# Epoch 37/50
# 183/183 [==============================] - 0s 2ms/step - loss: -11572202.0000 - accuracy: 0.1532 - val_loss: -16442519.0000 - val_accuracy: 0.1538
# Epoch 38/50
# 183/183 [==============================] - 1s 4ms/step - loss: -12634782.0000 - accuracy: 0.1532 - val_loss: -17941244.0000 - val_accuracy: 0.1538
# Epoch 39/50
# 183/183 [==============================] - 1s 4ms/step - loss: -13762634.0000 - accuracy: 0.1532 - val_loss: -19498902.0000 - val_accuracy: 0.1538
# Epoch 40/50
# 183/183 [==============================] - 0s 3ms/step - loss: -14956524.0000 - accuracy: 0.1532 - val_loss: -21160044.0000 - val_accuracy: 0.1538
# Epoch 41/50
# 183/183 [==============================] - 1s 3ms/step - loss: -16218169.0000 - accuracy: 0.1532 - val_loss: -22909764.0000 - val_accuracy: 0.1538
# Epoch 42/50
# 183/183 [==============================] - 1s 4ms/step - loss: -17552598.0000 - accuracy: 0.1532 - val_loss: -24750734.0000 - val_accuracy: 0.1538
# Epoch 43/50
# 183/183 [==============================] - 1s 4ms/step - loss: -18961960.0000 - accuracy: 0.1532 - val_loss: -26724530.0000 - val_accuracy: 0.1538
# Epoch 44/50
# 183/183 [==============================] - 1s 3ms/step - loss: -20448328.0000 - accuracy: 0.1532 - val_loss: -28763136.0000 - val_accuracy: 0.1538
# Epoch 45/50
# 183/183 [==============================] - 1s 3ms/step - loss: -22011028.0000 - accuracy: 0.1532 - val_loss: -30914986.0000 - val_accuracy: 0.1538
# Epoch 46/50
# 183/183 [==============================] - 1s 3ms/step - loss: -23653778.0000 - accuracy: 0.1532 - val_loss: -33188926.0000 - val_accuracy: 0.1538
# Epoch 47/50
# 183/183 [==============================] - 1s 3ms/step - loss: -25374686.0000 - accuracy: 0.1532 - val_loss: -35585156.0000 - val_accuracy: 0.1538
# Epoch 48/50
# 183/183 [==============================] - 1s 5ms/step - loss: -27183664.0000 - accuracy: 0.1532 - val_loss: -38065636.0000 - val_accuracy: 0.1538
# Epoch 49/50
# 183/183 [==============================] - 1s 7ms/step - loss: -29087774.0000 - accuracy: 0.1532 - val_loss: -40691596.0000 - val_accuracy: 0.1538
# Epoch 50/50
# 183/183 [==============================] - 1s 3ms/step - loss: -31081468.0000 - accuracy: 0.1532 - val_loss: -43449064.0000 - val_accuracy: 0.1538

# %%
model8 = build_model()

history2 = model8.fit(X_train, y_train, validation_data=(X_test, y_test),epochs=50, batch_size=50).history
# Out:
# Epoch 1/50
# 37/37 [==============================] - 2s 14ms/step - loss: -0.0611 - accuracy: 0.1537 - val_loss: -0.8745 - val_accuracy: 0.1538
# Epoch 2/50
# 37/37 [==============================] - 0s 6ms/step - loss: -2.6279 - accuracy: 0.1532 - val_loss: -6.0071 - val_accuracy: 0.1538
# Epoch 3/50
# 37/37 [==============================] - 0s 4ms/step - loss: -7.8506 - accuracy: 0.1532 - val_loss: -16.2489 - val_accuracy: 0.1538
# Epoch 4/50
# 37/37 [==============================] - 0s 3ms/step - loss: -17.4295 - accuracy: 0.1532 - val_loss: -34.7563 - val_accuracy: 0.1538
# Epoch 5/50
# 37/37 [==============================] - 0s 4ms/step - loss: -34.3831 - accuracy: 0.1532 - val_loss: -66.9796 - val_accuracy: 0.1538
# Epoch 6/50
# 37/37 [==============================] - 0s 4ms/step - loss: -62.9914 - accuracy: 0.1532 - val_loss: -118.2594 - val_accuracy: 0.1538
# Epoch 7/50
# 37/37 [==============================] - 0s 3ms/step - loss: -107.7096 - accuracy: 0.1532 - val_loss: -195.4527 - val_accuracy: 0.1538
# Epoch 8/50
# 37/37 [==============================] - 0s 3ms/step - loss: -172.9488 - accuracy: 0.1532 - val_loss: -306.3146 - val_accuracy: 0.1538
# Epoch 9/50
# 37/37 [==============================] - 0s 3ms/step - loss: -265.4885 - accuracy: 0.1532 - val_loss: -456.9208 - val_accuracy: 0.1538
# Epoch 10/50
# 37/37 [==============================] - 0s 3ms/step - loss: -389.9487 - accuracy: 0.1532 - val_loss: -659.6606 - val_accuracy: 0.1538
# Epoch 11/50
# 37/37 [==============================] - 0s 5ms/step - loss: -553.4794 - accuracy: 0.1532 - val_loss: -924.7886 - val_accuracy: 0.1538
# Epoch 12/50
# 37/37 [==============================] - 0s 4ms/step - loss: -766.5360 - accuracy: 0.1532 - val_loss: -1256.1772 - val_accuracy: 0.1538
# Epoch 13/50
# 37/37 [==============================] - 0s 3ms/step - loss: -1034.0933 - accuracy: 0.1532 - val_loss: -1678.2472 - val_accuracy: 0.1538
# Epoch 14/50
# 37/37 [==============================] - 0s 3ms/step - loss: -1379.8706 - accuracy: 0.1532 - val_loss: -2216.2646 - val_accuracy: 0.1538
# Epoch 15/50
# 37/37 [==============================] - 0s 5ms/step - loss: -1824.0223 - accuracy: 0.1532 - val_loss: -2895.4956 - val_accuracy: 0.1538
# Epoch 16/50
# 37/37 [==============================] - 0s 3ms/step - loss: -2425.9690 - accuracy: 0.1532 - val_loss: -3918.9319 - val_accuracy: 0.1538
# Epoch 17/50
# 37/37 [==============================] - 0s 3ms/step - loss: -3300.1023 - accuracy: 0.1532 - val_loss: -5260.6162 - val_accuracy: 0.1538
# Epoch 18/50
# 37/37 [==============================] - 0s 3ms/step - loss: -4422.6851 - accuracy: 0.1532 - val_loss: -6942.1626 - val_accuracy: 0.1538
# Epoch 19/50
# 37/37 [==============================] - 0s 4ms/step - loss: -5843.0405 - accuracy: 0.1532 - val_loss: -9155.8799 - val_accuracy: 0.1538
# Epoch 20/50
# 37/37 [==============================] - 0s 4ms/step - loss: -7684.8223 - accuracy: 0.1532 - val_loss: -11853.0186 - val_accuracy: 0.1538
# Epoch 21/50
# 37/37 [==============================] - 0s 4ms/step - loss: -9926.4580 - accuracy: 0.1532 - val_loss: -15136.2002 - val_accuracy: 0.1538
# Epoch 22/50
# 37/37 [==============================] - 0s 5ms/step - loss: -12612.0361 - accuracy: 0.1532 - val_loss: -19042.9863 - val_accuracy: 0.1538
# Epoch 23/50
# 37/37 [==============================] - 0s 6ms/step - loss: -15750.1523 - accuracy: 0.1532 - val_loss: -23690.1484 - val_accuracy: 0.1538
# Epoch 24/50
# 37/37 [==============================] - 0s 6ms/step - loss: -19427.4238 - accuracy: 0.1532 - val_loss: -28909.8301 - val_accuracy: 0.1538
# Epoch 25/50
# 37/37 [==============================] - 0s 5ms/step - loss: -23653.8359 - accuracy: 0.1532 - val_loss: -34946.8672 - val_accuracy: 0.1538
# Epoch 26/50
# 37/37 [==============================] - 0s 6ms/step - loss: -28504.6914 - accuracy: 0.1532 - val_loss: -41792.6406 - val_accuracy: 0.1538
# Epoch 27/50
# 37/37 [==============================] - 0s 6ms/step - loss: -34029.5430 - accuracy: 0.1532 - val_loss: -49518.1133 - val_accuracy: 0.1538
# Epoch 28/50
# 37/37 [==============================] - 0s 6ms/step - loss: -40250.2578 - accuracy: 0.1532 - val_loss: -58191.5820 - val_accuracy: 0.1538
# Epoch 29/50
# 37/37 [==============================] - 0s 7ms/step - loss: -47127.4102 - accuracy: 0.1532 - val_loss: -68124.7734 - val_accuracy: 0.1538
# Epoch 30/50
# 37/37 [==============================] - 0s 5ms/step - loss: -54927.9258 - accuracy: 0.1532 - val_loss: -78835.1406 - val_accuracy: 0.1538
# Epoch 31/50
# 37/37 [==============================] - 0s 4ms/step - loss: -63494.2266 - accuracy: 0.1532 - val_loss: -90662.9062 - val_accuracy: 0.1538
# Epoch 32/50
# 37/37 [==============================] - 0s 4ms/step - loss: -72996.1250 - accuracy: 0.1532 - val_loss: -103568.1797 - val_accuracy: 0.1538
# Epoch 33/50
# 37/37 [==============================] - 0s 4ms/step - loss: -83346.6016 - accuracy: 0.1532 - val_loss: -118018.6562 - val_accuracy: 0.1538
# Epoch 34/50
# 37/37 [==============================] - 0s 4ms/step - loss: -94729.4609 - accuracy: 0.1532 - val_loss: -133578.9062 - val_accuracy: 0.1538
# Epoch 35/50
# 37/37 [==============================] - 0s 4ms/step - loss: -107049.3984 - accuracy: 0.1532 - val_loss: -150823.1719 - val_accuracy: 0.1538
# Epoch 36/50
# 37/37 [==============================] - 0s 4ms/step - loss: -120568.3672 - accuracy: 0.1532 - val_loss: -168905.6094 - val_accuracy: 0.1538
# Epoch 37/50
# 37/37 [==============================] - 0s 4ms/step - loss: -135037.0000 - accuracy: 0.1532 - val_loss: -188707.4844 - val_accuracy: 0.1538
# Epoch 38/50
# 37/37 [==============================] - 0s 4ms/step - loss: -150688.8906 - accuracy: 0.1532 - val_loss: -210115.1875 - val_accuracy: 0.1538
# Epoch 39/50
# 37/37 [==============================] - 0s 4ms/step - loss: -167627.9844 - accuracy: 0.1532 - val_loss: -232983.9688 - val_accuracy: 0.1538
# Epoch 40/50
# 37/37 [==============================] - 0s 4ms/step - loss: -185688.7344 - accuracy: 0.1532 - val_loss: -257586.1250 - val_accuracy: 0.1538
# Epoch 41/50
# 37/37 [==============================] - 0s 3ms/step - loss: -205148.1250 - accuracy: 0.1532 - val_loss: -283811.5938 - val_accuracy: 0.1538
# Epoch 42/50
# 37/37 [==============================] - 0s 3ms/step - loss: -225822.3594 - accuracy: 0.1532 - val_loss: -312178.9062 - val_accuracy: 0.1538
# Epoch 43/50
# 37/37 [==============================] - 0s 3ms/step - loss: -247976.4844 - accuracy: 0.1532 - val_loss: -341789.5000 - val_accuracy: 0.1538
# Epoch 44/50
# 37/37 [==============================] - 0s 4ms/step - loss: -271620.5312 - accuracy: 0.1532 - val_loss: -372936.5312 - val_accuracy: 0.1538
# Epoch 45/50
# 37/37 [==============================] - 0s 5ms/step - loss: -296353.5312 - accuracy: 0.1532 - val_loss: -406592.7812 - val_accuracy: 0.1538
# Epoch 46/50
# 37/37 [==============================] - 0s 6ms/step - loss: -323000.3438 - accuracy: 0.1532 - val_loss: -442237.3750 - val_accuracy: 0.1538
# Epoch 47/50
# 37/37 [==============================] - 0s 6ms/step - loss: -351109.3125 - accuracy: 0.1532 - val_loss: -479743.6875 - val_accuracy: 0.1538
# Epoch 48/50
# 37/37 [==============================] - 0s 6ms/step - loss: -380830.1250 - accuracy: 0.1532 - val_loss: -518925.5000 - val_accuracy: 0.1538
# Epoch 49/50
# 37/37 [==============================] - 0s 6ms/step - loss: -411983.5312 - accuracy: 0.1532 - val_loss: -560993.6250 - val_accuracy: 0.1538
# Epoch 50/50
# 37/37 [==============================] - 0s 6ms/step - loss: -444853.6250 - accuracy: 0.1532 - val_loss: -605306.4375 - val_accuracy: 0.1538

# %%
plt.plot(history1['loss'], label='Loss 10')
plt.plot(history2['loss'], label='Loss 50')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy')
plt.legend()
plt.show()

# %%
test_loss_1, test_acc_1 = model7.evaluate(X_test, y_test)
test_loss_2, test_acc_2 = model8.evaluate(X_test, y_test)

print('Loss %f, Accuracy %f' % (test_loss_1, test_acc_1))
print('Loss %f, Accuracy %f' % (test_loss_2, test_acc_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-30d46e328043> in <cell line: 1>()
# ----> 1 test_loss_1, test_acc_1 = model1.evaluate(X_test, y_test)
#       2 test_loss_2, test_acc_2 = model2.evaluate(X_test, y_test)
#       3
#       4 print('Loss %f, Accuracy %f' % (test_loss_1, test_acc_1))
#       5 print('Loss %f, Accuracy %f' % (test_loss_2, test_acc_2))
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in tf__test_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1852, in test_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1836, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1824, in run_step  **
#         outputs = model.test_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1790, in test_step
#         self.compute_loss(x, y, y_pred, sample_weight)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1109, in compute_loss
#         return self.compiled_loss(
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/compile_utils.py", line 265, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/usr/local/lib/python3.10/dist-packages/keras/losses.py", line 142, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/usr/local/lib/python3.10/dist-packages/keras/losses.py", line 268, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/losses.py", line 2156, in binary_crossentropy
#         backend.binary_crossentropy(y_true, y_pred, from_logits=from_logits),
#     File "/usr/local/lib/python3.10/dist-packages/keras/backend.py", line 5707, in binary_crossentropy
#         return tf.nn.sigmoid_cross_entropy_with_logits(
#
#     ValueError: `logits` and `labels` must have the same shape, received ((None, 64) vs (None, 1)).

# %%
y_pred = model8.predict(X_test).astype(int)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# 20/20 [==============================] - 0s 2ms/step
# Accuracy 0.15384615384615385
# F1-score [0.         0.26666667 0.         0.         0.         0.
#  0.         0.        ]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        96
#            1       0.15      1.00      0.27        96
#            2       0.00      0.00      0.00        48
#            3       0.00      0.00      0.00        96
#            4       0.00      0.00      0.00        96
#            5       0.00      0.00      0.00        48
#            6       0.00      0.00      0.00        96
#            7       0.00      0.00      0.00        48
#
#     accuracy                           0.15       624
#    macro avg       0.02      0.12      0.03       624
# weighted avg       0.02      0.15      0.04       624
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import pydot
from keras.utils import plot_model
plot_model(model1)

# %%
plot_model(model8)

# %%
model9 = build_model()

history3 = model9.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=10).history
# Out:
# Epoch 1/100
# 183/183 [==============================] - 3s 9ms/step - loss: 0.5039 - accuracy: 0.1499 - val_loss: -1.6124 - val_accuracy: 0.1571
# Epoch 2/100
# 183/183 [==============================] - 2s 11ms/step - loss: -16.3072 - accuracy: 0.1532 - val_loss: -105.1977 - val_accuracy: 0.1538
# Epoch 3/100
# 183/183 [==============================] - 1s 3ms/step - loss: -356.3385 - accuracy: 0.1532 - val_loss: -1343.2646 - val_accuracy: 0.1538
# Epoch 4/100
# 183/183 [==============================] - 1s 3ms/step - loss: -2153.5842 - accuracy: 0.1532 - val_loss: -5785.9839 - val_accuracy: 0.1538
# Epoch 5/100
# 183/183 [==============================] - 0s 2ms/step - loss: -6886.2925 - accuracy: 0.1532 - val_loss: -15557.1299 - val_accuracy: 0.1538
# Epoch 6/100
# 183/183 [==============================] - 1s 3ms/step - loss: -16231.6260 - accuracy: 0.1532 - val_loss: -33148.8398 - val_accuracy: 0.1538
# Epoch 7/100
# 183/183 [==============================] - 0s 3ms/step - loss: -31986.3398 - accuracy: 0.1532 - val_loss: -61170.2578 - val_accuracy: 0.1538
# Epoch 8/100
# 183/183 [==============================] - 0s 2ms/step - loss: -55581.2969 - accuracy: 0.1532 - val_loss: -100765.3047 - val_accuracy: 0.1538
# Epoch 9/100
# 183/183 [==============================] - 1s 3ms/step - loss: -89136.8203 - accuracy: 0.1532 - val_loss: -155999.3906 - val_accuracy: 0.1538
# Epoch 10/100
# 183/183 [==============================] - 0s 3ms/step - loss: -134446.6562 - accuracy: 0.1532 - val_loss: -229108.8750 - val_accuracy: 0.1538
# Epoch 11/100
# 183/183 [==============================] - 0s 2ms/step - loss: -192955.2812 - accuracy: 0.1532 - val_loss: -321108.8750 - val_accuracy: 0.1538
# Epoch 12/100
# 183/183 [==============================] - 0s 2ms/step - loss: -266525.8750 - accuracy: 0.1532 - val_loss: -435271.3438 - val_accuracy: 0.1538
# Epoch 13/100
# 183/183 [==============================] - 1s 3ms/step - loss: -357093.7812 - accuracy: 0.1532 - val_loss: -572654.8750 - val_accuracy: 0.1538
# Epoch 14/100
# 183/183 [==============================] - 1s 3ms/step - loss: -466158.1562 - accuracy: 0.1532 - val_loss: -738392.4375 - val_accuracy: 0.1538
# Epoch 15/100
# 183/183 [==============================] - 0s 2ms/step - loss: -594174.0000 - accuracy: 0.1532 - val_loss: -928451.3750 - val_accuracy: 0.1538
# Epoch 16/100
# 183/183 [==============================] - 0s 2ms/step - loss: -742534.8750 - accuracy: 0.1532 - val_loss: -1150998.0000 - val_accuracy: 0.1538
# Epoch 17/100
# 183/183 [==============================] - 0s 2ms/step - loss: -914760.3750 - accuracy: 0.1532 - val_loss: -1406262.0000 - val_accuracy: 0.1538
# Epoch 18/100
# 183/183 [==============================] - 0s 3ms/step - loss: -1112555.3750 - accuracy: 0.1532 - val_loss: -1696627.7500 - val_accuracy: 0.1538
# Epoch 19/100
# 183/183 [==============================] - 1s 4ms/step - loss: -1336770.6250 - accuracy: 0.1532 - val_loss: -2023416.6250 - val_accuracy: 0.1538
# Epoch 20/100
# 183/183 [==============================] - 1s 4ms/step - loss: -1587079.2500 - accuracy: 0.1532 - val_loss: -2386889.5000 - val_accuracy: 0.1538
# Epoch 21/100
# 183/183 [==============================] - 1s 4ms/step - loss: -1866664.3750 - accuracy: 0.1532 - val_loss: -2792734.7500 - val_accuracy: 0.1538
# Epoch 22/100
# 183/183 [==============================] - 1s 3ms/step - loss: -2177446.0000 - accuracy: 0.1532 - val_loss: -3240984.2500 - val_accuracy: 0.1538
# Epoch 23/100
# 183/183 [==============================] - 1s 3ms/step - loss: -2520710.0000 - accuracy: 0.1532 - val_loss: -3735586.0000 - val_accuracy: 0.1538
# Epoch 24/100
# 183/183 [==============================] - 1s 4ms/step - loss: -2897806.2500 - accuracy: 0.1532 - val_loss: -4272182.0000 - val_accuracy: 0.1538
# Epoch 25/100
# 183/183 [==============================] - 1s 3ms/step - loss: -3311551.7500 - accuracy: 0.1532 - val_loss: -4866453.5000 - val_accuracy: 0.1538
# Epoch 26/100
# 183/183 [==============================] - 1s 3ms/step - loss: -3764095.7500 - accuracy: 0.1532 - val_loss: -5510859.5000 - val_accuracy: 0.1538
# Epoch 27/100
# 183/183 [==============================] - 1s 3ms/step - loss: -4254120.0000 - accuracy: 0.1532 - val_loss: -6204711.0000 - val_accuracy: 0.1538
# Epoch 28/100
# 183/183 [==============================] - 0s 2ms/step - loss: -4785083.5000 - accuracy: 0.1532 - val_loss: -6967621.0000 - val_accuracy: 0.1538
# Epoch 29/100
# 183/183 [==============================] - 1s 3ms/step - loss: -5360617.5000 - accuracy: 0.1532 - val_loss: -7776771.5000 - val_accuracy: 0.1538
# Epoch 30/100
# 183/183 [==============================] - 0s 2ms/step - loss: -5979903.5000 - accuracy: 0.1532 - val_loss: -8651899.0000 - val_accuracy: 0.1538
# Epoch 31/100
# 183/183 [==============================] - 0s 2ms/step - loss: -6644235.0000 - accuracy: 0.1532 - val_loss: -9590097.0000 - val_accuracy: 0.1538
# Epoch 32/100
# 183/183 [==============================] - 0s 2ms/step - loss: -7359022.0000 - accuracy: 0.1532 - val_loss: -10598613.0000 - val_accuracy: 0.1538
# Epoch 33/100
# 183/183 [==============================] - 1s 3ms/step - loss: -8122944.0000 - accuracy: 0.1532 - val_loss: -11668376.0000 - val_accuracy: 0.1538
# Epoch 34/100
# 183/183 [==============================] - 1s 4ms/step - loss: -8956831.0000 - accuracy: 0.1532 - val_loss: -12869410.0000 - val_accuracy: 0.1538
# Epoch 35/100
# 183/183 [==============================] - 1s 6ms/step - loss: -9871007.0000 - accuracy: 0.1532 - val_loss: -14147618.0000 - val_accuracy: 0.1538
# Epoch 36/100
# 183/183 [==============================] - 1s 6ms/step - loss: -10849049.0000 - accuracy: 0.1532 - val_loss: -15530540.0000 - val_accuracy: 0.1538
# Epoch 37/100
# 183/183 [==============================] - 1s 7ms/step - loss: -11892664.0000 - accuracy: 0.1532 - val_loss: -16987234.0000 - val_accuracy: 0.1538
# Epoch 38/100
# 183/183 [==============================] - 1s 4ms/step - loss: -13000078.0000 - accuracy: 0.1532 - val_loss: -18533472.0000 - val_accuracy: 0.1538
# Epoch 39/100
# 183/183 [==============================] - 1s 8ms/step - loss: -14171677.0000 - accuracy: 0.1532 - val_loss: -20180432.0000 - val_accuracy: 0.1538
# Epoch 40/100
# 183/183 [==============================] - 1s 6ms/step - loss: -15413773.0000 - accuracy: 0.1532 - val_loss: -21919408.0000 - val_accuracy: 0.1538
# Epoch 41/100
# 183/183 [==============================] - 1s 4ms/step - loss: -16731023.0000 - accuracy: 0.1532 - val_loss: -23736898.0000 - val_accuracy: 0.1538
# Epoch 42/100
# 183/183 [==============================] - 1s 4ms/step - loss: -18126154.0000 - accuracy: 0.1532 - val_loss: -25700640.0000 - val_accuracy: 0.1538
# Epoch 43/100
# 183/183 [==============================] - 0s 3ms/step - loss: -19604784.0000 - accuracy: 0.1532 - val_loss: -27766462.0000 - val_accuracy: 0.1538
# Epoch 44/100
# 183/183 [==============================] - 1s 5ms/step - loss: -21173848.0000 - accuracy: 0.1532 - val_loss: -29954366.0000 - val_accuracy: 0.1538
# Epoch 45/100
# 183/183 [==============================] - 1s 4ms/step - loss: -22832236.0000 - accuracy: 0.1532 - val_loss: -32258622.0000 - val_accuracy: 0.1538
# Epoch 46/100
# 183/183 [==============================] - 1s 4ms/step - loss: -24581854.0000 - accuracy: 0.1532 - val_loss: -34685864.0000 - val_accuracy: 0.1538
# Epoch 47/100
# 183/183 [==============================] - 1s 6ms/step - loss: -26423642.0000 - accuracy: 0.1532 - val_loss: -37237724.0000 - val_accuracy: 0.1538
# Epoch 48/100
# 183/183 [==============================] - 1s 5ms/step - loss: -28362112.0000 - accuracy: 0.1532 - val_loss: -39924576.0000 - val_accuracy: 0.1538
# Epoch 49/100
# 183/183 [==============================] - 1s 3ms/step - loss: -30393562.0000 - accuracy: 0.1532 - val_loss: -42715096.0000 - val_accuracy: 0.1538
# Epoch 50/100
# 183/183 [==============================] - 1s 3ms/step - loss: -32513262.0000 - accuracy: 0.1532 - val_loss: -45672340.0000 - val_accuracy: 0.1538
# Epoch 51/100
# 183/183 [==============================] - 1s 3ms/step - loss: -34729996.0000 - accuracy: 0.1532 - val_loss: -48714744.0000 - val_accuracy: 0.1538
# Epoch 52/100
# 183/183 [==============================] - 1s 4ms/step - loss: -37047956.0000 - accuracy: 0.1532 - val_loss: -51950012.0000 - val_accuracy: 0.1538
# Epoch 53/100
# 183/183 [==============================] - 1s 4ms/step - loss: -39467220.0000 - accuracy: 0.1532 - val_loss: -55268576.0000 - val_accuracy: 0.1538
# Epoch 54/100
# 183/183 [==============================] - 1s 3ms/step - loss: -41998268.0000 - accuracy: 0.1532 - val_loss: -58787480.0000 - val_accuracy: 0.1538
# Epoch 55/100
# 183/183 [==============================] - 0s 2ms/step - loss: -44643456.0000 - accuracy: 0.1532 - val_loss: -62431788.0000 - val_accuracy: 0.1538
# Epoch 56/100
# 183/183 [==============================] - 0s 2ms/step - loss: -47393104.0000 - accuracy: 0.1532 - val_loss: -66219756.0000 - val_accuracy: 0.1538
# Epoch 57/100
# 183/183 [==============================] - 1s 3ms/step - loss: -50266100.0000 - accuracy: 0.1532 - val_loss: -70189592.0000 - val_accuracy: 0.1538
# Epoch 58/100
# 183/183 [==============================] - 1s 5ms/step - loss: -53268428.0000 - accuracy: 0.1532 - val_loss: -74303816.0000 - val_accuracy: 0.1538
# Epoch 59/100
# 183/183 [==============================] - 1s 4ms/step - loss: -56393684.0000 - accuracy: 0.1532 - val_loss: -78586864.0000 - val_accuracy: 0.1538
# Epoch 60/100
# 183/183 [==============================] - 1s 3ms/step - loss: -59649708.0000 - accuracy: 0.1532 - val_loss: -83085000.0000 - val_accuracy: 0.1538
# Epoch 61/100
# 183/183 [==============================] - 1s 3ms/step - loss: -63037116.0000 - accuracy: 0.1532 - val_loss: -87733416.0000 - val_accuracy: 0.1538
# Epoch 62/100
# 183/183 [==============================] - 0s 2ms/step - loss: -66557792.0000 - accuracy: 0.1532 - val_loss: -92565376.0000 - val_accuracy: 0.1538
# Epoch 63/100
# 183/183 [==============================] - 1s 4ms/step - loss: -70214016.0000 - accuracy: 0.1532 - val_loss: -97574472.0000 - val_accuracy: 0.1538
# Epoch 64/100
# 183/183 [==============================] - 1s 4ms/step - loss: -74004760.0000 - accuracy: 0.1532 - val_loss: -102803472.0000 - val_accuracy: 0.1538
# Epoch 65/100
# 183/183 [==============================] - 1s 5ms/step - loss: -77954536.0000 - accuracy: 0.1532 - val_loss: -108222360.0000 - val_accuracy: 0.1538
# Epoch 66/100
# 183/183 [==============================] - 1s 6ms/step - loss: -82052320.0000 - accuracy: 0.1532 - val_loss: -113802360.0000 - val_accuracy: 0.1538
# Epoch 67/100
# 183/183 [==============================] - 1s 4ms/step - loss: -86285280.0000 - accuracy: 0.1532 - val_loss: -119648216.0000 - val_accuracy: 0.1538
# Epoch 68/100
# 183/183 [==============================] - 1s 4ms/step - loss: -90663008.0000 - accuracy: 0.1532 - val_loss: -125610952.0000 - val_accuracy: 0.1538
# Epoch 69/100
# 183/183 [==============================] - 1s 5ms/step - loss: -95187440.0000 - accuracy: 0.1532 - val_loss: -131739296.0000 - val_accuracy: 0.1538
# Epoch 70/100
# 183/183 [==============================] - 1s 4ms/step - loss: -99850920.0000 - accuracy: 0.1532 - val_loss: -138128160.0000 - val_accuracy: 0.1538
# Epoch 71/100
# 183/183 [==============================] - 1s 4ms/step - loss: -104705832.0000 - accuracy: 0.1532 - val_loss: -144854592.0000 - val_accuracy: 0.1538
# Epoch 72/100
# 183/183 [==============================] - 1s 4ms/step - loss: -109732736.0000 - accuracy: 0.1532 - val_loss: -151659888.0000 - val_accuracy: 0.1538
# Epoch 73/100
# 183/183 [==============================] - 1s 3ms/step - loss: -114920864.0000 - accuracy: 0.1532 - val_loss: -158801840.0000 - val_accuracy: 0.1538
# Epoch 74/100
# 183/183 [==============================] - 1s 4ms/step - loss: -120291760.0000 - accuracy: 0.1532 - val_loss: -166144368.0000 - val_accuracy: 0.1538
# Epoch 75/100
# 183/183 [==============================] - 1s 7ms/step - loss: -125841408.0000 - accuracy: 0.1532 - val_loss: -173692720.0000 - val_accuracy: 0.1538
# Epoch 76/100
# 183/183 [==============================] - 2s 9ms/step - loss: -131575336.0000 - accuracy: 0.1532 - val_loss: -181538816.0000 - val_accuracy: 0.1538
# Epoch 77/100
# 183/183 [==============================] - 1s 4ms/step - loss: -137491040.0000 - accuracy: 0.1532 - val_loss: -189557184.0000 - val_accuracy: 0.1538
# Epoch 78/100
# 183/183 [==============================] - 1s 4ms/step - loss: -143577504.0000 - accuracy: 0.1532 - val_loss: -197908224.0000 - val_accuracy: 0.1538
# Epoch 79/100
# 183/183 [==============================] - 1s 8ms/step - loss: -149840016.0000 - accuracy: 0.1532 - val_loss: -206407680.0000 - val_accuracy: 0.1538
# Epoch 80/100
# 183/183 [==============================] - 1s 5ms/step - loss: -156323120.0000 - accuracy: 0.1532 - val_loss: -215250080.0000 - val_accuracy: 0.1538
# Epoch 81/100
# 183/183 [==============================] - 1s 5ms/step - loss: -163008240.0000 - accuracy: 0.1532 - val_loss: -224427216.0000 - val_accuracy: 0.1538
# Epoch 82/100
# 183/183 [==============================] - 1s 4ms/step - loss: -169896112.0000 - accuracy: 0.1532 - val_loss: -233772240.0000 - val_accuracy: 0.1538
# Epoch 83/100
# 183/183 [==============================] - 1s 4ms/step - loss: -176952448.0000 - accuracy: 0.1532 - val_loss: -243386000.0000 - val_accuracy: 0.1538
# Epoch 84/100
# 183/183 [==============================] - 1s 4ms/step - loss: -184217536.0000 - accuracy: 0.1532 - val_loss: -253211824.0000 - val_accuracy: 0.1538
# Epoch 85/100
# 183/183 [==============================] - 1s 4ms/step - loss: -191710736.0000 - accuracy: 0.1532 - val_loss: -263386816.0000 - val_accuracy: 0.1538
# Epoch 86/100
# 183/183 [==============================] - 1s 4ms/step - loss: -199430368.0000 - accuracy: 0.1532 - val_loss: -274021888.0000 - val_accuracy: 0.1538
# Epoch 87/100
# 183/183 [==============================] - 0s 2ms/step - loss: -207356176.0000 - accuracy: 0.1532 - val_loss: -284629248.0000 - val_accuracy: 0.1538
# Epoch 88/100
# 183/183 [==============================] - 0s 3ms/step - loss: -215473168.0000 - accuracy: 0.1532 - val_loss: -295728832.0000 - val_accuracy: 0.1538
# Epoch 89/100
# 183/183 [==============================] - 1s 4ms/step - loss: -223830800.0000 - accuracy: 0.1532 - val_loss: -307118304.0000 - val_accuracy: 0.1538
# Epoch 90/100
# 183/183 [==============================] - 2s 10ms/step - loss: -232456672.0000 - accuracy: 0.1532 - val_loss: -318703936.0000 - val_accuracy: 0.1538
# Epoch 91/100
# 183/183 [==============================] - 2s 9ms/step - loss: -241310064.0000 - accuracy: 0.1532 - val_loss: -330904640.0000 - val_accuracy: 0.1538
# Epoch 92/100
# 183/183 [==============================] - 1s 6ms/step - loss: -250410608.0000 - accuracy: 0.1532 - val_loss: -343120448.0000 - val_accuracy: 0.1538
# Epoch 93/100
# 183/183 [==============================] - 1s 4ms/step - loss: -259742544.0000 - accuracy: 0.1532 - val_loss: -355850176.0000 - val_accuracy: 0.1538
# Epoch 94/100
# 183/183 [==============================] - 1s 3ms/step - loss: -269317728.0000 - accuracy: 0.1532 - val_loss: -368783712.0000 - val_accuracy: 0.1538
# Epoch 95/100
# 183/183 [==============================] - 0s 2ms/step - loss: -279128768.0000 - accuracy: 0.1532 - val_loss: -382271328.0000 - val_accuracy: 0.1538
# Epoch 96/100
# 183/183 [==============================] - 1s 3ms/step - loss: -289224416.0000 - accuracy: 0.1532 - val_loss: -395873376.0000 - val_accuracy: 0.1538
# Epoch 97/100
# 183/183 [==============================] - 1s 4ms/step - loss: -299565408.0000 - accuracy: 0.1532 - val_loss: -409840192.0000 - val_accuracy: 0.1538
# Epoch 98/100
# 183/183 [==============================] - 1s 6ms/step - loss: -310191680.0000 - accuracy: 0.1532 - val_loss: -424218752.0000 - val_accuracy: 0.1538
# Epoch 99/100
# 183/183 [==============================] - 1s 4ms/step - loss: -321109504.0000 - accuracy: 0.1532 - val_loss: -439181664.0000 - val_accuracy: 0.1538
# Epoch 100/100
# 183/183 [==============================] - 1s 4ms/step - loss: -332320288.0000 - accuracy: 0.1532 - val_loss: -454262720.0000 - val_accuracy: 0.1538

# %%
print('Train: Loss %f, Accuracy %f' % (history1['loss'][49], history1['accuracy'][49]))
print('Val: Loss %f, Accuracy %f' % (history1['val_loss'][49], history1['val_accuracy'][49]))
# Out:
# Train: Loss -17211282.000000, Accuracy 0.191466
# Val: Loss -25419514.000000, Accuracy 0.174679

# %%
print('Train: Loss %f, Accuracy %f' % (history2['loss'][49], history2['accuracy'][49]))
print('Val: Loss %f, Accuracy %f' % (history2['val_loss'][49], history2['val_accuracy'][49]))
# Out:
# Train: Loss -342285.656250, Accuracy 0.153173
# Val: Loss -448431.656250, Accuracy 0.153846

# %%
print('Train: Loss %f, Accuracy %f' % (history3['loss'][99], history3['accuracy'][99]))
print('Val: Loss %f, Accuracy %f' % (history3['val_loss'][99], history3['val_accuracy'][99]))
# Out:
# Train: Loss -332320288.000000, Accuracy 0.153173
# Val: Loss -454262720.000000, Accuracy 0.153846

# %%
test_loss_3, test_acc_3 = model9.evaluate(X_test, y_test)

print('Loss %f, Accuracy %f' % (test_loss_1, test_acc_1))
print('Loss %f, Accuracy %f' % (test_loss_2, test_acc_2))
print('Loss %f, Accuracy %f' % (test_loss_3, test_acc_3))
plot_model(model9)
# Out:
# 20/20 [==============================] - 0s 1ms/step - loss: -454262720.0000 - accuracy: 0.1538
# Loss -25419518.000000, Accuracy 0.174679
# Loss 0.271255, Accuracy 0.171474
# Loss -454262720.000000, Accuracy 0.153846

# %%
test_loss_3, test_acc_3 = model9.evaluate(X_test, y_test)
# Out:
# 20/20 [==============================] - 0s 3ms/step - loss: -454262720.0000 - accuracy: 0.1538

# %%
plt.plot(history3['loss'], label='Train')
plt.plot(history3['val_loss'], label='Val')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy')
plt.legend()
plt.show()

# %%
scores = cross_val_score(model9, X_train, y_train, cv=10)
print('Accuracy: %0.4f (+/- %0.3f)' % (scores.mean(), scores.std()))

scores = cross_val_score(model9, X_train, y_train, cv=10, scoring='f1_macro')
print('F1-score: %0.4f (+/- %0.3f)' % (scores.mean(), scores.std()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-5d3e63a5136e> in <cell line: 1>()
# ----> 1 scores = cross_val_score(model3, X_train, y_train, cv=10)
#       2 print('Accuracy: %0.4f (+/- %0.3f)' % (scores.mean(), scores.std()))
#       3
#       4 scores = cross_val_score(model3, X_train, y_train, cv=10, scoring='f1_macro')
#       5 print('F1-score: %0.4f (+/- %0.3f)' % (scores.mean(), scores.std()))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     511     """
#     512     # To ensure multimetric format is not supported
# --> 513     scorer = check_scoring(estimator, scoring=scoring)
#     514
#     515     cv_results = cross_validate(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_scorer.py in check_scoring(estimator, scoring, allow_none)
#     501             return None
#     502         else:
# --> 503             raise TypeError(
#     504                 "If no scoring is specified, the estimator passed should "
#     505                 "have a 'score' method. The estimator %r does not." % estimator
#
# TypeError: If no scoring is specified, the estimator passed should have a 'score' method. The estimator <keras.engine.sequential.Sequential object at 0x7eff7bcfb520> does not.

# %%
from ann_visualizer.visualize import ann_viz;
#Build your model here
ann_viz(model9,view=True, filename="net.gv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-cc504962d4c9> in <cell line: 1>()
# ----> 1 from ann_visualizer.visualize import ann_viz;
#       2 #Build your model here
#       3 ann_viz(model3,view=True, filename="net.gv")
#
# ModuleNotFoundError: No module named 'ann_visualizer'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
